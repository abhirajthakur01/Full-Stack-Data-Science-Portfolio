# %%
import pandas as pd
import numpy as np

# %%
# Creating Dataframe
list = [['Geek', 25], ['is', 30], 
       ['for', 26], ['Geeksforgeeks', 22]]
#df = pd.DataFrame(list, columns=['Tag','Number'])
df = pd.DataFrame(list, columns=['Tag','Number'], index=['a','b','c','d'])
print(df)

list2 = [['Geek1', 28, 'Analyst'],
        ['Geek2', 35, 'Manager'],
        ['Geek3', 29, 'Developer']]
columns = ['Name', 'Age', 'Occupation']

df2 = pd.DataFrame(data=list2,  columns=columns)
print(df2)

df3 = pd.DataFrame(data=list2,  columns=columns, dtype=float)
print(df3)
# Out:
#              Tag  Number
# a           Geek      25
# b             is      30
# c            for      26
# d  Geeksforgeeks      22
#     Name  Age Occupation
# 0  Geek1   28    Analyst
# 1  Geek2   35    Manager
# 2  Geek3   29  Developer
#     Name   Age Occupation
# 0  Geek1  28.0    Analyst
# 1  Geek2  35.0    Manager
# 2  Geek3  29.0  Developer

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      object
#  1   Age         3 non-null      float64
#  2   Occupation  3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
data = {'Category':['Array', 'Stack', 'Queue'],
        'Marks':[20, 21, 19]}
df4 = pd.DataFrame(data)
print(df4)
print(df4.transpose())
# Out:
#   Category  Marks
# 0    Array     20
# 1    Stack     21
# 2    Queue     19
#               0      1      2
# Category  Array  Stack  Queue
# Marks        20     21     19

# %%
data = {'Area':['Array', 'Stack', 'Queue'],
        'Student_1':[20, 21, 19], 'Student_2':[15, 20, 14]} 
df5 = pd.DataFrame(data,index=['Cat_1','Cat_2','Cat_3'])
print(df5)

data = {'Area':['Array', 'Stack', 'Queue'],
        'Student_1':[20, 21, 19], 'Student_2':[15, 20, 14]} 
df6 = pd.DataFrame(data,index=['Cat_1','Cat_2','Cat_3'], columns=['A','Area','B','C'])
print(df6)
# Out:
#         Area  Student_1  Student_2
# Cat_1  Array         20         15
# Cat_2  Stack         21         20
# Cat_3  Queue         19         14
#          A   Area    B    C
# Cat_1  NaN  Array  NaN  NaN
# Cat_2  NaN  Stack  NaN  NaN
# Cat_3  NaN  Queue  NaN  NaN

# %%
# Creating a dataframe with missing values from a list 

data1 = [['Geek1', 28, 'Engineer'],
        ['Geek2', None, 'Data Scientist'],
        ['Geek3', 32,None]]
columns = ['Name','Age','Occupation']
df7 = pd.DataFrame(data1,columns=columns)
print(df7)
#print(df7.replace({None:np.nan})) # Replacing None with NaN for Missing value
# Out:
#     Name   Age      Occupation
# 0  Geek1  28.0        Engineer
# 1  Geek2   NaN  Data Scientist
# 2  Geek3  32.0            None

# %%
# Creating a dataframe using list of tuples
data = [('Peter', 18, 7),
        ('Riff', 15, 6),
        ('John', 17, 8),
        ('Michel', 18, 7),
        ('Sheli', 17, 5) ]
df8 = pd.DataFrame(data, columns=['Name','Age','Score'])
print(df8)
# Out:
#      Name  Age  Score
# 0   Peter   18      7
# 1    Riff   15      6
# 2    John   17      8
# 3  Michel   18      7
# 4   Sheli   17      5

# %%
print(df8.size)
print(df8.shape)
print(df8.ndim)
# Out:
# 15
# (5, 3)
# 2

# %%
cars = pd.read_csv("Automobile_data.csv")

# %%
print(cars)
# Out:
#           company   body-style  length engine-type  avg-mileage
# 0     alfa-romero  convertible   168.8        dohc           21
# 1     alfa-romero    hatchback   171.2        ohcv           19
# 2            audi        sedan   176.6         ohc           24
# 3            audi        sedan   176.6         ohc           18
# 4            audi        sedan   177.3         ohc           19
# 5            audi        wagon   192.7         ohc           19
# 6             bmw        sedan   176.8         ohc           23
# 7             bmw        sedan   176.8         ohc           23
# 8             bmw        sedan   176.8         ohc           21
# 9             bmw        sedan   189.0         ohc           16
# 10            bmw        sedan   193.8         ohc           16
# 11            bmw        sedan   197.0         ohc           15
# 12      chevrolet    hatchback   141.1         ohc           47
# 13      chevrolet    hatchback   155.9         ohc           38
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   company      60 non-null     object
#  1   body-style   60 non-null     object
#  2   length       60 non-null     float64
#  3   engine-type  60 non-null     object
#  4   avg-mileage  60 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
cars.describe()
# Out:
#            length  avg-mileage
# count   60.000000    60.000000
# mean   173.170000    25.883333
# std     14.128914     8.174146
# min    141.100000    13.000000
# 25%    159.100000    19.000000
# 50%    171.450000    25.000000
# 75%    179.125000    31.000000
# max    208.100000    47.000000

# %% [markdown]
# ## Dataframe attribute

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
cars.columns
# Out:
# Index(['company', 'body-style', 'length', 'engine-type', 'avg-mileage'], dtype='object')

# %%
cars.dtypes
# Out:
# company         object
# body-style      object
# length         float64
# engine-type     object
# avg-mileage      int64
# dtype: object

# %%
cars.values
# Out:
# array([['alfa-romero', 'convertible', 168.8, 'dohc', 21],
#        ['alfa-romero', 'hatchback', 171.2, 'ohcv', 19],
#        ['audi', 'sedan', 176.6, 'ohc', 24],
#        ['audi', 'sedan', 176.6, 'ohc', 18],
#        ['audi', 'sedan', 177.3, 'ohc', 19],
#        ['audi', 'wagon', 192.7, 'ohc', 19],
#        ['bmw', 'sedan', 176.8, 'ohc', 23],
#        ['bmw', 'sedan', 176.8, 'ohc', 23],
#        ['bmw', 'sedan', 176.8, 'ohc', 21],
#        ['bmw', 'sedan', 189.0, 'ohc', 16],
#        ['bmw', 'sedan', 193.8, 'ohc', 16],
#        ['bmw', 'sedan', 197.0, 'ohc', 15],
#        ['chevrolet', 'hatchback', 141.1, 'ohc', 47],
#        ['chevrolet', 'hatchback', 155.9, 'ohc', 38],
#        ['chevrolet', 'sedan', 158.8, 'ohc', 38],
#        ['dodge', 'hatchback', 157.3, 'ohc', 31],
#        ['dodge', 'hatchback', 157.3, 'ohc', 31],
#        ['honda', 'wagon', 157.1, 'ohc', 30],
#        ['honda', 'sedan', 175.4, 'ohc', 24],
#        ['honda', 'sedan', 169.1, 'ohc', 25],
# ...

# %%
cars.empty
# Out:
# False

# %%
cars.size
# Out:
# 300

# %%
cars.shape
# Out:
# (60, 5)

# %%
# Create DataFrame from dict
student_dict = {'Name': ['Joe', 'Nat', 'Harry'], 'Age': [20, 21, 19], 'Marks': [85.10, 77.80, 91.54]}

student_df = pd.DataFrame(student_dict)

print("DataFrame : ", student_df)

print("DataFrame Index : ", student_df.index)
print("DataFrame Columns : ", student_df.columns)

print("DataFrame Column types : ", student_df.dtypes)

print("DataFrame is empty? : ", student_df.empty)

print("DataFrame Shape : ", student_df.shape)
print("DataFrame Size : ", student_df.size)

print("DataFrame Values : ", student_df.values)
# Out:
# DataFrame :      Name  Age  Marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# DataFrame Index :  RangeIndex(start=0, stop=3, step=1)
# DataFrame Columns :  Index(['Name', 'Age', 'Marks'], dtype='object')
# DataFrame Column types :  Name      object
# Age        int64
# Marks    float64
# dtype: object
# DataFrame is empty? :  False
# DataFrame Shape :  (3, 3)
# DataFrame Size :  9
# DataFrame Values :  [['Joe' 20 85.1]
#  ['Nat' 21 77.8]
#  ['Harry' 19 91.54]]

# %% [markdown]
# ## Dataframe functions

# %%
# Create DataFrame from dict
student_dict = {'Name': ['Joe', 'Nat', 'Harry'], 'Age': [20, 21, 19], 'Marks': [85.10, 77.80, 91.54]}

student_df = pd.DataFrame(student_dict)

# display dataframe
print("DataFrame : ", student_df)

# select top 2 rows
print(student_df.head(2))

# select bottom 2 rows
print(student_df.tail(2))

# select value at row index 0 and column 'Name'
print(student_df.at[0, 'Name'])

# select value at first row and first column
print(student_df.iat[0, 0])

# select values of 'Name' column
print(student_df.get('Name'))

# select values from row index 0 to 2 and 'Name' column
print(student_df.loc[0:2, ['Name']])

# select values from row index 0 to 2(exclusive) and column position 0 to 2(exclusive)
print(student_df.iloc[0:2, 0:2])
# Out:
# DataFrame :      Name  Age  Marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
#   Name  Age  Marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#     Name  Age  Marks
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# Joe
# Joe
# 0      Joe
# 1      Nat
# 2    Harry
# Name: Name, dtype: object
#     Name
# 0    Joe
# 1    Nat
# 2  Harry
#   Name  Age
# 0  Joe   20
# 1  Nat   21

# %% [markdown]
# ## Insert columns

# %%
import numpy as np
import pandas as pd

# %%
# Create dataframe from dict

student_dict = {'Name':['Joe','Nat','Harry'],
                'Age':[20,21,19],
               'Marks':[85.10,77.80,91.54]}
student_df = pd.DataFrame(student_dict)
print(student_df)

student_df['Branch'] = 'Computer Science and Engineering'
print(student_df)

#insert new column in dataframe and display

student_df.insert(loc=2, column='Class',value='A')
print(student_df)
# Out:
#     Name  Age  Marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
#     Name  Age  Marks                            Branch
# 0    Joe   20  85.10  Computer Science and Engineering
# 1    Nat   21  77.80  Computer Science and Engineering
# 2  Harry   19  91.54  Computer Science and Engineering
#     Name  Age Class  Marks                            Branch
# 0    Joe   20     A  85.10  Computer Science and Engineering
# 1    Nat   21     A  77.80  Computer Science and Engineering
# 2  Harry   19     A  91.54  Computer Science and Engineering

# %% [markdown]
# ## Drop Single Column

# %%
import pandas as pd

# %%
student_dict = {'name':['Joe','Nat'], 'age':[20,21], 'marks':[85.10,77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)

#drop column
student_df = student_df.drop(columns='age')
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  marks
# 0  Joe   85.1
# 1  Nat   77.8

# %%
student_dict = {'name':['Joe','Nat'], 'age':[20,21], 'marks':[85.10,77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)

#drop column using del 
del student_df['age']
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  marks
# 0  Joe   85.1
# 1  Nat   77.8

# %% [markdown]
# ## Drop multiple columns

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df.columns.values)

# drop 2 columns at a time
student_df = student_df.drop(columns=['age', 'marks'])

print(student_df.columns.values)
# Out:
# ['name' 'age' 'marks']
# ['name']

# %%
#Using drop with axis='columns' or axis=1
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df.columns.values)
print(student_df)

student_df = student_ 
print(student_df.columns.values)
print(student_df)
# Out:
# ['name' 'age' 'marks']
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       5 print(student_df.columns.values)
#       6 print(student_df)
# ----> 8 student_df = student_
#       9 print(student_df.columns.values)
#      10 print(student_df)
#
# NameError: name 'student_' is not defined

# %%
#Using drop with axis='columns' or axis=1
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df.columns.values)
print(student_df)

student_df = student_df.drop(['age','name'], axis='columns')
print(student_df.columns.values)

print(student_df)
# Out:
# ['name' 'age' 'marks']
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# ['marks']
#    marks
# 0   85.1
# 1   77.8

# %%
# Drop column using inplace

import pandas as pd

student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df)

# drop columns in place
student_df.drop(columns=['age', 'marks'], inplace=False)
print(student_df)

student_df.drop(columns=['age', 'marks'], inplace=True)
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name
# 0  Joe
# 1  Nat

# %%
## Drop column by suppressing errors

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df)

student_df = student_df.drop(columns='salary',errors='ignore') # No change in the student_df
print(student_df)

student_df = student_df.drop(columns='salary') # KeyError: "['salary'] not found in axis"
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-d67992e34a8a> in <module>
#       7 print(student_df)
#       8
# ----> 9 student_df = student_df.drop(columns='salary') # KeyError: "['salary'] not found in axis"
#      10 print(student_df)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
# ...

# %% [markdown]
# ## Drop the last column

# %%
student_dict = {"name":["Joe","Nat"], "age":[20,21],"marks":[85.10,77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)

# find position of the last columns and drop
pos = len(student_df.columns)-1
print(pos)

student_df = student_df.drop(columns=student_df.columns[pos])
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# 2
#   name  age
# 0  Joe   20
# 1  Nat   21

# %%
student_dict = {"name":["Joe","Nat"], "age":[20,21],"marks":[85.10,77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)

student_df = student_df.drop(columns=student_df.columns[-1])
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  age
# 0  Joe   20
# 1  Nat   21

# %% [markdown]
# ## Drop range of columns using iloc

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)
print(student_df.columns)
print(student_df.values)

student_df = student_df.drop(columns=student_df.iloc[:,1:3])
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# Index(['name', 'age', 'marks'], dtype='object')
# [['Joe' 20 85.1]
#  ['Nat' 21 77.8]]
#   name
# 0  Joe
# 1  Nat

# %% [markdown]
# ## Drop first n columns

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80], "class": ["A", "B"],
                "city": ["London", "Zurich"]}
student_df = pd.DataFrame(student_dict)
print(student_df)

print(student_df.drop(columns=student_df.iloc[:,range(2)]))
print(student_df)

print(student_df.drop(columns=student_df.iloc[:,range(2)],inplace=True))
print(student_df)
# Out:
#   name  age  marks class    city
# 0  Joe   20   85.1     A  London
# 1  Nat   21   77.8     B  Zurich
#    marks class    city
# 0   85.1     A  London
# 1   77.8     B  Zurich
#   name  age  marks class    city
# 0  Joe   20   85.1     A  London
# 1  Nat   21   77.8     B  Zurich
# None
#    marks class    city
# 0   85.1     A  London
# 1   77.8     B  Zurich

# %% [markdown]
# ## Drop all the columns using loc

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df)

student_df = student_df.drop(columns=student_df.loc[:])
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}

student_df = pd.DataFrame(student_dict)
print(student_df)

student_df = student_df.drop(columns=student_df.iloc[:,:])
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
## Drop column using pandas DataFrame.pop() function(it can not delete multiple columns)

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)

student_df.pop('age')
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  marks
# 0  Joe   85.1
# 1  Nat   77.8

# %%
## Drop column using pandas DataFrame delete(it can not delete multiple columns)

# %%
student_dict = {"name": ["Joe", "Nat"], "age": [20, 21], "marks": [85.10, 77.80]}
student_df = pd.DataFrame(student_dict)
print(student_df)

del student_df['age']
print(student_df)
# Out:
#   name  age  marks
# 0  Joe   20   85.1
# 1  Nat   21   77.8
#   name  marks
# 0  Joe   85.1
# 1  Nat   77.8

# %%
mo = pd.read_excel('mobile_not_seeded_30_1_2024.xlsx')

# %%
type(mo)
# Out:
# pandas.core.frame.DataFrame

# %%
mo.head(5)
# Out:
#     district                       block   fps_id     rc_id  units scheme
# 0    Khandwa      Nagar Praishad, MUNDI   1312001  20327341      1    PHH
# 1  Singrauli      Nagar Nigam, SINGROULI  5008007  20333201      4    PHH
# 2    Khandwa    Janpad Panchayat, HARSUD  1305010  23263540      2    PHH
# 3      Sidhi  Janpad Panchayat, MAJHAULI  1504054  23972011      1    PHH
# 4    Khandwa    Janpad Panchayat, PUNASA  1303021  28446598      4    PHH

# %%
mo.shape
# Out:
# (939109, 6)

# %%
mo.columns
# Out:
# Index(['district', 'block', 'fps_id', 'rc_id', 'units', 'scheme'], dtype='object')

# %%
m1 = mo.groupby(['district','block','fps_id'],as_index=False)['rc_id'].count()

# %%
m1.sort_values(['district','rc_id'],ascending=[True,False])
# Out:
#       district                       block   fps_id  rc_id
# 199       Agar    Janpad Panchayat, SUSNER  1907026    181
# 131       Agar  Janpad Panchayat, NALKHEDA  1908005    108
# 70        Agar     Janpad Panchayat, BAROD  1906013    106
# 228       Agar    Janpad Panchayat, SUSNER  5103018     92
# 266       Agar     Nagar Praishad, SUSNER   1917002     86
# ...        ...                         ...      ...    ...
# 27074  Vidisha    Janpad Panchayat, Sironj  2706054      1
# 27092  Vidisha    Janpad Panchayat, Sironj  2706092      1
# 27134  Vidisha   Janpad Panchayat, Vidisha  2701011      1
# 27154  Vidisha   Janpad Panchayat, Vidisha  2701031      1
# 27159  Vidisha   Janpad Panchayat, Vidisha  2701036      1
#
# [27288 rows x 4 columns]

# %%
status = pd.read_excel('status.xlsx')

# %%
status.head()
# Out:
#     fps_id  Total_Cards  Status
# 0  1905003          355  Online
# 1  1905004          483  Online
# 2  1905005          264  Online
# 3  1905006          359  Online
# 4  1905007          685  Online

# %%
Final = pd.merge(m1,status, on='fps_id',how='left')

# %%
Final['Remain'] = Final['rc_id']/Final['Total_Cards']*100

# %%
Final['Remain'] = round(Final['Remain'],0)

# %%
Final.sort_values(['district','Remain'],ascending=[True,False]).to_excel('FInal Not Seeded.xlsx')

# %% [markdown]
# ## Drop Duplicates in Pandas DataFrame

# %% [markdown]
# ### Drop duplicates but keep first

# %%
import numpy as np
import pandas as pd

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
#create dataframe
student_df = pd.DataFrame(student_dict)
print(student_df)

#drop duplicate rows
student_df = student_df.drop_duplicates()
print('\n')
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54

# %% [markdown]
# ### Drop Duplicates but Keep Last

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
#create dataframe
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')
#drop duplicate rows
student_df = student_df.drop_duplicates(keep='last')
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80

# %% [markdown]
# ### Drop all duplicates

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
#create dataframe
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')
#drop duplicate rows
student_df = student_df.drop_duplicates(keep=False)
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 2  Harry   19  91.54

# %% [markdown]
# ## Drop duplicates from defined columns

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
# create dataframe from dict
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')

student_df = student_df.drop_duplicates(subset=['age','marks'])
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54

# %% [markdown]
# ## Drop duplicates in place

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
# create dataframe from dict
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')

student_df.drop_duplicates(inplace=False)
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
# create dataframe from dict
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')

student_df.drop_duplicates(inplace=True)
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54

# %% [markdown]
# ## Drop duplicates and reset the index

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
# create dataframe from dict
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')

student_df = student_df.drop_duplicates(keep='last',ignore_index=False)
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80

# %%
student_dict = {'name': ["Joe", "Nat", "Harry", "Joe", "Nat"],
               'age': [20, 21, 19, 20, 21],
               'marks': [85.10, 77.80, 91.54, 85.10, 77.80] }
# create dataframe from dict
student_df = pd.DataFrame(student_dict)
print(student_df)
print('\n')

student_df = student_df.drop_duplicates(keep='last',ignore_index=True)
print(student_df)
# Out:
#     name  age  marks
# 0    Joe   20  85.10
# 1    Nat   21  77.80
# 2  Harry   19  91.54
# 3    Joe   20  85.10
# 4    Nat   21  77.80
#
#
#     name  age  marks
# 0  Harry   19  91.54
# 1    Joe   20  85.10
# 2    Nat   21  77.80

# %% [markdown]
# ## Creating a Dataframe to drop Rows

# %%
df = pd.read_csv('nba.csv')

# %%
df.shape
# Out:
# (458, 9)

# %%
df.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
df.Age.unique()
# Out:
# array([25., 27., 22., 29., 21., 24., 20., 26., 28., 32., 23., 30., 33.,
#        34., 37., 36., 31., 38., 39., 19., 35., 40., nan])

# %%
df.Age.value_counts()
# Out:
# Age
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 20.0    19
# 21.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: count, dtype: int64

# %% [markdown]
# #### Delete Rows Based on Multiple Conditions on a Column Using drop()

# %%
# Delete all rows with column 'Age' has value 20 to 25 
indexAge = df[(df.Age>=20) & (df.Age<=25)].index

# %%
indexAge
# Out:
# Index([  0,   1,   3,   6,   7,   8,   9,  10,  13,  16,
#        ...
#        438, 441, 443, 444, 445, 446, 447, 449, 452, 454],
#       dtype='int64', length=197)

# %%
len(indexAge)
# Out:
# 197

# %%
df.drop(indexAge, inplace=True)

# %%
df.Age.unique()
# Out:
# array([27., 29., 26., 28., 32., 30., 33., 34., 37., 36., 31., 38., 39.,
#        19., 35., 40., nan])

# %%
df.Age.value_counts()
# Out:
# Age
# 27.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 31.0    22
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: count, dtype: int64

# %%
# Delete rows where the 'Name' is 'John Holland' or the 'Position' is 'SG'
indexAge = df[(df.Name =='John Holland')| (df.Position == 'SG')].index
df.drop(indexAge, inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 11   Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 14    Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
# 19    Jarrett Jack   Brooklyn Nets     2.0       PG  32.0    6-3   200.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#             College      Salary
# 4               NaN   5000000.0
# ...

# %%
df.sort_values('Name')
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 152     Aaron Brooks         Chicago Bulls     0.0       PG  31.0    6-0
# 312       Al Horford         Atlanta Hawks    15.0        C  30.0   6-10
# 330     Al Jefferson     Charlotte Hornets    25.0        C  31.0   6-10
# 273   Alex Stepheson     Memphis Grizzlies    35.0       PF  28.0   6-10
# 275    Alexis Ajinca  New Orleans Pelicans    42.0        C  28.0    7-2
# ..               ...                   ...     ...      ...   ...    ...
# 25       Willie Reed         Brooklyn Nets    33.0       PF  26.0   6-10
# 386  Wilson Chandler        Denver Nuggets    21.0       SF  29.0    6-8
# 271    Zach Randolph     Memphis Grizzlies    50.0       PF  34.0    6-9
# 237    Zaza Pachulia      Dallas Mavericks    27.0        C  32.0   6-11
# 457              NaN                   NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 152   161.0          Oregon   2250000.0
# ...
