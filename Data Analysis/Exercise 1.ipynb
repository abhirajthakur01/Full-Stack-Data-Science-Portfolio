# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("alphabet_stock_data.csv")

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# 4    1186.510010  2387300
# ..           ...      ...
# 122  1428.290039  1450200
# 123  1444.959961  1323000
# 124  1464.520020  2007900
# 125  1469.329956   978200
# 126  1469.599976  1700600
#
# [127 rows x 7 columns]

# %%
df.shape
# Out:
# (127, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.size
# Out:
# 889

# %%
df.empty
# Out:
# False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=127, step=1)

# %%
len(df.index)
# Out:
# 127

# %%
len(df.columns)
# Out:
# 7

# %%
df.plot('Date',['Low','High'])
plt.xticks(rotation=45)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140.]),
#  [Text(-20.0, 0, '2020-09-02'),
#   Text(0.0, 0, '2020-04-01'),
#   Text(20.0, 0, '2020-04-30'),
#   Text(40.0, 0, '2020-05-29'),
#   Text(60.0, 0, '2020-06-26'),
#   Text(80.0, 0, '2020-07-27'),
#   Text(100.0, 0, '2020-08-24'),
#   Text(120.0, 0, '2020-09-22'),
#   Text(140.0, 0, '')])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       127 non-null    object
#  1   Open       127 non-null    float64
#  2   High       127 non-null    float64
#  3   Low        127 non-null    float64
#  4   Close      127 non-null    float64
#  5   Adj Close  127 non-null    float64
#  6   Volume     127 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
df.Date=pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       127 non-null    datetime64[ns]
#  1   Open       127 non-null    float64
#  2   High       127 non-null    float64
#  3   Low        127 non-null    float64
#  4   Close      127 non-null    float64
#  5   Adj Close  127 non-null    float64
#  6   Volume     127 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 7.1 KB

# %%
df.plot('Date',['Low','High'])
plt.xticks(rotation=45)
# Out:
# (array([18353., 18383., 18414., 18444., 18475., 18506., 18536.]),
#  [Text(18353.0, 0, '2020-04'),
#   Text(18383.0, 0, '2020-05'),
#   Text(18414.0, 0, '2020-06'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18475.0, 0, '2020-08'),
#   Text(18506.0, 0, '2020-09'),
#   Text(18536.0, 0, '2020-10')])

# %%
start_date=pd.to_datetime("2020-06-01")
end_date=pd.to_datetime("2020-09-01")

# %%
new_date=(df.Date>=start_date)&(df.Date<=end_date)

# %%
new_date
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# Name: Date, Length: 127, dtype: bool

# %%
df1=df.loc[new_date]
df1
# Out:
#           Date         Open         High          Low        Close  \
# 41  2020-06-01  1418.390015  1437.959961  1418.000000  1431.819946
# 42  2020-06-02  1430.550049  1439.609985  1418.829956  1439.219971
# 43  2020-06-03  1438.300049  1446.552002  1429.776978  1436.380005
# 44  2020-06-04  1430.400024  1438.959961  1404.729980  1412.180054
# 45  2020-06-05  1413.170044  1445.050049  1406.000000  1438.390015
# ..         ...          ...          ...          ...          ...
# 102 2020-08-26  1608.000000  1659.219971  1603.599976  1652.380005
# 103 2020-08-27  1653.680054  1655.000000  1625.750000  1634.329956
# 104 2020-08-28  1633.489990  1647.170044  1630.750000  1644.410034
# 105 2020-08-31  1647.890015  1647.964966  1630.310059  1634.180054
# 106 2020-09-01  1636.630005  1665.729980  1632.219971  1660.709961
#
#        Adj Close   Volume
# 41   1431.819946  1217100
# 42   1439.219971  1278100
# 43   1436.380005  1256200
# 44   1412.180054  1484300
# 45   1438.390015  1734900
# ..           ...      ...
# 102  1652.380005  3993400
# 103  1634.329956  1861600
# 104  1644.410034  1499800
# 105  1634.180054  1823400
# 106  1660.709961  1826700
#
# [66 rows x 7 columns]

# %%
df1.Close.plot()
# Out:
# <Axes: >

# %%
df1.shape
# Out:
# (66, 7)

# %%
df1.set_index('Date',inplace=True)

# %%
df1.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df1[['Open','Close']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-09-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(x='Date', y=['Open', 'Close']);
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 30-09-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-04-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='bar',x='Date', y='Volume');
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 30-09-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-04-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='bar',x='Date', y=['Open','Close']);
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 30-09-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-04-15')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='bar',x='Date', y=['Open','Close'],stacked=True);
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 15-04-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-04-15')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='barh',x='Date', y=['Open','Close'],stacked=True);
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 15-04-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-04-15')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='hist',x='Date', y=['Open','High','Low', 'Close'],stacked=True);
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 15-04-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-9-15')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='hist',x='Date', y=['Open','High','Low', 'Close'],stacked=True);
plt.suptitle('Opening/Closing stock prices of Alphabet Inc.,\n 01-04-2020 to 15-04-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()

# %%
start_date = pd.to_datetime('2020-4-1')
end_date = pd.to_datetime('2020-04-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df2 = df.loc[new_df]
plt.figure(figsize=(10,10))
df2.plot(kind='hist', orientation = 'horizontal',x='Date', y='Open', cumulative = True);
plt.suptitle('Opening stock prices of Alphabet Inc.,\n 01-04-2020 to 30-09-2020', fontsize=12, color='black')
plt.xlabel("Date",fontsize=12, color='black')
plt.ylabel("$ price", fontsize=12, color='black')
plt.show()
