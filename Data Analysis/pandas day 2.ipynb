# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('RegularSeasonCompactResults.csv')

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # To check the top 5 rows of tke data

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %% [markdown]
# # To check the top 10 rows of tke data

# %%
df.head(10)
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0
# 5    1985      25   1218      79   1337      78    H      0
# 6    1985      25   1228      64   1226      44    N      0
# 7    1985      25   1242      58   1268      56    N      0
# 8    1985      25   1260      98   1133      80    H      0
# 9    1985      25   1305      97   1424      89    H      0

# %% [markdown]
# # To check the last 5 rows of tke data

# %%
df.tail()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %%
df.tail(10)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145279    2016     131   1392      80   1436      74    H      0
# 145280    2016     131   1401      71   1261      38    N      0
# 145281    2016     131   1419      82   1426      71    N      0
# 145282    2016     131   1433      76   1172      54    N      0
# 145283    2016     131   1451      62   1285      59    N      0
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %%
df.head(150)
# Out:
#      Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0      1985      20   1228      81   1328      64    N      0
# 1      1985      25   1106      77   1354      70    H      0
# 2      1985      25   1112      63   1223      56    H      0
# 3      1985      25   1165      70   1432      54    H      0
# 4      1985      25   1192      86   1447      74    H      0
# ..      ...     ...    ...     ...    ...     ...  ...    ...
# 145    1985      32   1151      64   1122      54    H      0
# 146    1985      32   1155      90   1144      55    H      0
# 147    1985      32   1185      85   1152      76    H      0
# 148    1985      32   1196      68   1199      65    A      0
# 149    1985      32   1201      61   1453      46    H      0
#
# [150 rows x 8 columns]

# %% [markdown]
# # to check the no of rows by indexing

# %%
df[10:20]
# Out:
#     Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 10    1985      25   1307     103   1288      71    H      0
# 11    1985      25   1344      75   1438      71    N      0
# 12    1985      25   1374      91   1411      72    H      0
# 13    1985      25   1412      70   1397      65    N      0
# 14    1985      25   1417      87   1225      58    H      0
# 15    1985      26   1116      65   1368      62    H      0
# 16    1985      26   1120      92   1391      50    H      0
# 17    1985      26   1135      65   1306      60    A      0
# 18    1985      26   1143      58   1388      53    H      0
# 19    1985      26   1153      50   1184      48    H      0

# %%
df[55:61]
# Out:
#     Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 55    1985      27   1268      72   1397      49    N      0
# 56    1985      27   1314      81   1200      65    N      0
# 57    1985      27   1323      67   1264      56    H      0
# 58    1985      27   1412      50   1242      46    N      0
# 59    1985      27   1458      93   1288      78    H      0
# 60    1985      28   1104      81   1137      56    H      0

# %% [markdown]
# # to check the shape of the data

# %%
df.shape
# Out:
# (145289, 8)

# %% [markdown]
# # to get the list of the columns

# %%
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %% [markdown]
# # to get the info about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145289 entries, 0 to 145288
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Season  145289 non-null  int64
#  1   Daynum  145289 non-null  int64
#  2   Wteam   145289 non-null  int64
#  3   Wscore  145289 non-null  int64
#  4   Lteam   145289 non-null  int64
#  5   Lscore  145289 non-null  int64
#  6   Wloc    145289 non-null  object
#  7   Numot   145289 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 8.9+ MB

# %% [markdown]
# # to get the satistical info about the data

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# 75%      1375.000000      72.000000       0.000000
# max      1464.000000     150.000000       6.000000

# %% [markdown]
# # aggregate functions

# %%
df[['Wteam']]
# Out:
#         Wteam
# 0        1228
# 1        1106
# 2        1112
# 3        1165
# 4        1192
# ...       ...
# 145284   1114
# 145285   1163
# 145286   1246
# 145287   1277
# 145288   1386
#
# [145289 rows x 1 columns]

# %%
df['Wteam'].mean()
# Out:
# np.float64(1286.7206464357246)

# %%
df['Wteam'].median()
# Out:
# np.float64(1284.0)

# %%
df['Wteam'].mode()
# Out:
# 0    1181
# Name: Wteam, dtype: int64

# %%
df['Wteam'].std()
# Out:
# np.float64(104.57027504914535)

# %%
df['Wteam'].var()
# Out:
# np.float64(10934.94242385391)

# %%
np.mean(df['Wteam'])
# Out:
# np.float64(1286.7206464357246)

# %%
np.std(df['Wteam'])
# Out:
# np.float64(104.5699151786287)

# %%
np.var(df['Wteam'])
# Out:
# np.float64(10934.867160465603)

# %%
df['Wteam'].min()
# Out:
# np.int64(1101)

# %%
df['Wteam'].max()
# Out:
# np.int64(1464)

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %% [markdown]
# # Indexing and slicing

# %%
df[-1:-21:-2]
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145288    2016     132   1386      87   1433      74    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145284    2016     132   1114      70   1419      50    N      0
# 145282    2016     131   1433      76   1172      54    N      0
# 145280    2016     131   1401      71   1261      38    N      0
# 145278    2016     131   1386      82   1173      79    N      0
# 145276    2016     131   1372      82   1394      60    N      0
# 145274    2016     131   1345      76   1276      59    N      0
# 145272    2016     131   1314      61   1438      57    N      0
# 145270    2016     131   1277      64   1268      61    N      0

# %%
df[0:6]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0
# 5    1985      25   1218      79   1337      78    H      0

# %% [markdown]
# # iloc:used to fetch the data by only int indexing

# %%
df.iloc[0:6]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0
# 5    1985      25   1218      79   1337      78    H      0

# %%
df.iloc[0:6,0:3]
# Out:
#    Season  Daynum  Wteam
# 0    1985      20   1228
# 1    1985      25   1106
# 2    1985      25   1112
# 3    1985      25   1165
# 4    1985      25   1192
# 5    1985      25   1218

# %%
df.iloc[-1:-6:-1,-1:-3:-1]
# Out:
#         Numot Wloc
# 145288      0    N
# 145287      0    N
# 145286      1    N
# 145285      0    N
# 145284      0    N

# %%
df.iloc[0:3,2:5]
# Out:
#    Wteam  Wscore  Lteam
# 0   1228      81   1328
# 1   1106      77   1354
# 2   1112      63   1223

# %% [markdown]
# # loc : used to fetch the data by the labels

# %%
df.loc[2:6]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0
# 5    1985      25   1218      79   1337      78    H      0
# 6    1985      25   1228      64   1226      44    N      0

# %%
df.loc[2:6,['Daynum','Wteam']]
# Out:
#    Daynum  Wteam
# 2      25   1112
# 3      25   1165
# 4      25   1192
# 5      25   1218
# 6      25   1228

# %%
df['Wscore']
# Out:
# 0         81
# 1         77
# 2         63
# 3         70
# 4         86
#           ..
# 145284    70
# 145285    72
# 145286    82
# 145287    66
# 145288    87
# Name: Wscore, Length: 145289, dtype: int64

# %%
df['Wscore'].max()
# Out:
# np.int64(186)

# %%
df['Wscore'].idxmax()
# Out:
# 24970

# %%
df.iloc[24970]
# Out:
# Season    1991
# Daynum      68
# Wteam     1258
# Wscore     186
# Lteam     1109
# Lscore     140
# Wloc         H
# Numot        0
# Name: 24970, dtype: object

# %%
df['Wscore'].idxmin()
# Out:
# 128582

# %%
df.iloc[128582]
# Out:
# Season    2013
# Daynum     116
# Wteam     1264
# Wscore      34
# Lteam     1193
# Lscore      31
# Wloc         H
# Numot        0
# Name: 128582, dtype: object

# %% [markdown]
# # to check the uniqevalue in th data

# %%
df['Season'].unique()
# Out:
# array([1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
df['Season'].nunique()
# Out:
# 32

# %% [markdown]
# # to check the count of the value in the data

# %%
df['Season'].value_counts()
# Out:
# Season
# 2016    5369
# 2014    5362
# 2015    5354
# 2013    5320
# 2010    5263
# 2012    5253
# 2009    5249
# 2011    5246
# 2008    5163
# 2007    5043
# 2006    4757
# 2005    4675
# 2003    4616
# 2004    4571
# 2002    4555
# 2000    4519
# 2001    4467
# 1999    4222
# 1998    4167
# 1997    4155
# 1992    4127
# 1991    4123
# 1996    4122
# 1995    4077
# 1994    4060
# 1990    4045
# 1989    4037
# 1993    3982
# 1988    3955
# 1987    3915
# 1986    3783
# 1985    3737
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %% [markdown]
# # to sort the data according to particular columns

# %%
df.sort_values(by =['Wscore'])
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 128582    2013     116   1264      34   1193      31    H      0
# 5364      1986      77   1229      35   1166      34    A      0
# 69336     2001     126   1206      35   1423      33    N      0
# 118590    2011     130   1336      36   1458      33    N      0
# 20246     1990      47   1374      36   1426      31    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 20022     1990      40   1116     166   1109     101    H      0
# 24341     1991      47   1328     172   1258     112    H      0
# 19653     1990      30   1328     173   1109     101    H      0
# 17867     1989      92   1258     181   1109     150    H      0
# 24970     1991      68   1258     186   1109     140    H      0
#
# [145289 rows x 8 columns]

# %%
df.sort_values(by =['Wscore'])
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 128582    2013     116   1264      34   1193      31    H      0
# 5364      1986      77   1229      35   1166      34    A      0
# 69336     2001     126   1206      35   1423      33    N      0
# 118590    2011     130   1336      36   1458      33    N      0
# 20246     1990      47   1374      36   1426      31    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 20022     1990      40   1116     166   1109     101    H      0
# 24341     1991      47   1328     172   1258     112    H      0
# 19653     1990      30   1328     173   1109     101    H      0
# 17867     1989      92   1258     181   1109     150    H      0
# 24970     1991      68   1258     186   1109     140    H      0
#
# [145289 rows x 8 columns]

# %%
df.sort_values(by =['Wscore'],ascending=False)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970     1991      68   1258     186   1109     140    H      0
# 17867     1989      92   1258     181   1109     150    H      0
# 19653     1990      30   1328     173   1109     101    H      0
# 24341     1991      47   1328     172   1258     112    H      0
# 20022     1990      40   1116     166   1109     101    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 20246     1990      47   1374      36   1426      31    H      0
# 118590    2011     130   1336      36   1458      33    N      0
# 69336     2001     126   1206      35   1423      33    N      0
# 5364      1986      77   1229      35   1166      34    A      0
# 128582    2013     116   1264      34   1193      31    H      0
#
# [145289 rows x 8 columns]

# %%
df.sort_values(by =['Wscore'],ascending=True)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 128582    2013     116   1264      34   1193      31    H      0
# 5364      1986      77   1229      35   1166      34    A      0
# 69336     2001     126   1206      35   1423      33    N      0
# 118590    2011     130   1336      36   1458      33    N      0
# 20246     1990      47   1374      36   1426      31    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 20022     1990      40   1116     166   1109     101    H      0
# 24341     1991      47   1328     172   1258     112    H      0
# 19653     1990      30   1328     173   1109     101    H      0
# 17867     1989      92   1258     181   1109     150    H      0
# 24970     1991      68   1258     186   1109     140    H      0
#
# [145289 rows x 8 columns]

# %%
df.sort_values(by =['Wteam'],ascending=True)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 139440    2015     120   1101      83   1223      71    H      0
# 143283    2016      89   1101      80   1249      71    H      0
# 142816    2016      78   1101      75   1270      67    H      0
# 137131    2015      71   1101      95   1322      81    A      0
# 135619    2015      31   1101      72   1170      61    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 65724     2001      33   1464      63   1331      62    A      0
# 33576     1993      79   1464     104   1138      89    H      0
# 173       1985      32   1464      81   1106      55    N      0
# 82        1985      28   1464      71   1134      58    H      0
# 689       1985      47   1464      74   1375      73    H      0
#
# [145289 rows x 8 columns]

# %%
df.sort_values(by =['Wteam'],ascending=False)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 114074    2011      23   1464      73   1405      67    H      0
# 4467      1986      47   1464      64   1320      62    H      0
# 144171    2016     106   1464      92   1227      91    H      2
# 5396      1986      77   1464      75   1184      69    H      0
# 5341      1986      75   1464      75   1287      48    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 139440    2015     120   1101      83   1223      71    H      0
# 143283    2016      89   1101      80   1249      71    H      0
# 135619    2015      31   1101      72   1170      61    H      0
# 137131    2015      71   1101      95   1322      81    A      0
# 136740    2015      62   1101      87   1146      70    H      0
#
# [145289 rows x 8 columns]

# %%
df.sort_values(by =['Wteam','Wscore'],ascending=[False,True])
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 62239     2000      65   1464      43   1237      41    A      0
# 12511     1988      57   1464      48   1186      47    H      0
# 40469     1995      46   1464      53   1293      48    N      0
# 119031    2012      18   1464      53   1415      49    H      1
# 11835     1988      33   1464      54   1368      51    N      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 136740    2015      62   1101      87   1146      70    H      0
# 142481    2016      71   1101      87   1322      72    H      0
# 144622    2016     117   1101      87   1309      84    H      0
# 144430    2016     111   1101      91   1368      80    H      0
# 137131    2015      71   1101      95   1322      81    A      0
#
# [145289 rows x 8 columns]

# %%
df["Wloc"].value_counts()
# Out:
# Wloc
# H    86471
# A    44229
# N    14589
# Name: count, dtype: int64

# %%
df.sample(20)
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 75079     2003      44   1387      83   1212      54    H      0
# 133729    2014     111   1304      76   1345      57    H      0
# 109214    2010      33   1237      86   1295      74    H      0
# 16803     1989      68   1110      70   1206      68    H      0
# 135142    2015      21   1360      77   1444      70    H      0
# 40607     1995      50   1241      70   1117      52    A      0
# 14617     1988     110   1292      92   1398      87    H      0
# 62703     2000      75   1424      98   1102      73    A      0
# 92688     2007      11   1160      78   1176      64    H      0
# 56998     1999      39   1216      89   1148      82    N      0
# 112623    2010     113   1243      83   1403      64    A      0
# 77904     2003     111   1103      84   1325      82    H      1
# 49888     1997      79   1231      66   1321      63    A      0
# 97841     2008       5   1463      82   1357      71    H      0
# 66939     2001      70   1428      83   1461      71    H      0
# 77597     2003     103   1444      67   1132      65    A      0
# 1636      1985      79   1153      73   1376      51    H      0
# 21055     1990      72   1400      83   1395      80    A      0
# 103340    2009      19   1415      59   1319      52    H      0
# 109682    2010      47   1320      64   1315      41    A      0

# %% [markdown]
# # to get the values only from the data

# %%
df.values
# Out:
# array([[1985, 20, 1228, ..., 64, 'N', 0],
#        [1985, 25, 1106, ..., 70, 'H', 0],
#        [1985, 25, 1112, ..., 56, 'H', 0],
#        ...,
#        [2016, 132, 1246, ..., 77, 'N', 1],
#        [2016, 132, 1277, ..., 62, 'N', 0],
#        [2016, 132, 1386, ..., 74, 'N', 0]], dtype=object)

# %% [markdown]
# # to get the dtype of all the columns

# %%
df.dtypes
# Out:
# Season     int64
# Daynum     int64
# Wteam      int64
# Wscore     int64
# Lteam      int64
# Lscore     int64
# Wloc      object
# Numot      int64
# dtype: object

# %% [markdown]
# # to get the null values

# %%
df.isnull()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore   Wloc  Numot
# 0        False   False  False   False  False   False  False  False
# 1        False   False  False   False  False   False  False  False
# 2        False   False  False   False  False   False  False  False
# 3        False   False  False   False  False   False  False  False
# 4        False   False  False   False  False   False  False  False
# ...        ...     ...    ...     ...    ...     ...    ...    ...
# 145284   False   False  False   False  False   False  False  False
# 145285   False   False  False   False  False   False  False  False
# 145286   False   False  False   False  False   False  False  False
# 145287   False   False  False   False  False   False  False  False
# 145288   False   False  False   False  False   False  False  False
#
# [145289 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Season    0
# Daynum    0
# Wteam     0
# Wscore    0
# Lteam     0
# Lscore    0
# Wloc      0
# Numot     0
# dtype: int64

# %% [markdown]
# # to check the duplicate rows in the data

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145284    False
# 145285    False
# 145286    False
# 145287    False
# 145288    False
# Length: 145289, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %% [markdown]
# # to rename the columns

# %%
df.rename(columns={'Season':'Year'})
# Out:
#         Year  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0       1985      20   1228      81   1328      64    N      0
# 1       1985      25   1106      77   1354      70    H      0
# 2       1985      25   1112      63   1223      56    H      0
# 3       1985      25   1165      70   1432      54    H      0
# 4       1985      25   1192      86   1447      74    H      0
# ...      ...     ...    ...     ...    ...     ...  ...    ...
# 145284  2016     132   1114      70   1419      50    N      0
# 145285  2016     132   1163      72   1272      58    N      0
# 145286  2016     132   1246      82   1401      77    N      1
# 145287  2016     132   1277      66   1345      62    N      0
# 145288  2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.rename(columns={'Season':'Year'},inplace=True)

# %%
df
# Out:
#         Year  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0       1985      20   1228      81   1328      64    N      0
# 1       1985      25   1106      77   1354      70    H      0
# 2       1985      25   1112      63   1223      56    H      0
# 3       1985      25   1165      70   1432      54    H      0
# 4       1985      25   1192      86   1447      74    H      0
# ...      ...     ...    ...     ...    ...     ...  ...    ...
# 145284  2016     132   1114      70   1419      50    N      0
# 145285  2016     132   1163      72   1272      58    N      0
# 145286  2016     132   1246      82   1401      77    N      1
# 145287  2016     132   1277      66   1345      62    N      0
# 145288  2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %%
df.head()
# Out:
#    Year  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0  1985      20   1228      81   1328      64    N      0
# 1  1985      25   1106      77   1354      70    H      0
# 2  1985      25   1112      63   1223      56    H      0
# 3  1985      25   1165      70   1432      54    H      0
# 4  1985      25   1192      86   1447      74    H      0

# %%
df.rename(columns={'Wteam':'Team','Wscore':'Score','Lteam':'Team'},inplace=True)

# %%
df
# Out:
#         Year  Daynum  Team  Score  Team  Lscore Wloc  Numot
# 0       1985      20  1228     81  1328      64    N      0
# 1       1985      25  1106     77  1354      70    H      0
# 2       1985      25  1112     63  1223      56    H      0
# 3       1985      25  1165     70  1432      54    H      0
# 4       1985      25  1192     86  1447      74    H      0
# ...      ...     ...   ...    ...   ...     ...  ...    ...
# 145284  2016     132  1114     70  1419      50    N      0
# 145285  2016     132  1163     72  1272      58    N      0
# 145286  2016     132  1246     82  1401      77    N      1
# 145287  2016     132  1277     66  1345      62    N      0
# 145288  2016     132  1386     87  1433      74    N      0
#
# [145289 rows x 8 columns]

# %% [markdown]
# # to drop the columns

# %%
df.drop(columns=['Wloc','Numot'],inplace=True)

# %%
df
# Out:
#         Year  Daynum  Team  Score  Team  Lscore
# 0       1985      20  1228     81  1328      64
# 1       1985      25  1106     77  1354      70
# 2       1985      25  1112     63  1223      56
# 3       1985      25  1165     70  1432      54
# 4       1985      25  1192     86  1447      74
# ...      ...     ...   ...    ...   ...     ...
# 145284  2016     132  1114     70  1419      50
# 145285  2016     132  1163     72  1272      58
# 145286  2016     132  1246     82  1401      77
# 145287  2016     132  1277     66  1345      62
# 145288  2016     132  1386     87  1433      74
#
# [145289 rows x 6 columns]

# %%
df
# Out:
#         Year  Daynum  Team  Score  Team  Lscore
# 0       1985      20  1228     81  1328      64
# 1       1985      25  1106     77  1354      70
# 2       1985      25  1112     63  1223      56
# 3       1985      25  1165     70  1432      54
# 4       1985      25  1192     86  1447      74
# ...      ...     ...   ...    ...   ...     ...
# 145284  2016     132  1114     70  1419      50
# 145285  2016     132  1163     72  1272      58
# 145286  2016     132  1246     82  1401      77
# 145287  2016     132  1277     66  1345      62
# 145288  2016     132  1386     87  1433      74
#
# [145289 rows x 6 columns]

# %%
df.head()
# Out:
#    Year  Daynum  Team  Score  Team  Lscore
# 0  1985      20  1228     81  1328      64
# 1  1985      25  1106     77  1354      70
# 2  1985      25  1112     63  1223      56
# 3  1985      25  1165     70  1432      54
# 4  1985      25  1192     86  1447      74

# %%
df['New_Year']=df['Year']+10

# %%
df
# Out:
#         Year  Daynum  Team  Score  Team  Lscore  New_Year
# 0       1985      20  1228     81  1328      64      1995
# 1       1985      25  1106     77  1354      70      1995
# 2       1985      25  1112     63  1223      56      1995
# 3       1985      25  1165     70  1432      54      1995
# 4       1985      25  1192     86  1447      74      1995
# ...      ...     ...   ...    ...   ...     ...       ...
# 145284  2016     132  1114     70  1419      50      2026
# 145285  2016     132  1163     72  1272      58      2026
# 145286  2016     132  1246     82  1401      77      2026
# 145287  2016     132  1277     66  1345      62      2026
# 145288  2016     132  1386     87  1433      74      2026
#
# [145289 rows x 7 columns]

# %% [markdown]
# # to set any columns as an index

# %%
df.set_index('Year',inplace=True)

# %%
df
# Out:
#       Daynum  Team  Score  Team  Lscore  New_Year
# Year
# 1985      20  1228     81  1328      64      1995
# 1985      25  1106     77  1354      70      1995
# 1985      25  1112     63  1223      56      1995
# 1985      25  1165     70  1432      54      1995
# 1985      25  1192     86  1447      74      1995
# ...      ...   ...    ...   ...     ...       ...
# 2016     132  1114     70  1419      50      2026
# 2016     132  1163     72  1272      58      2026
# 2016     132  1246     82  1401      77      2026
# 2016     132  1277     66  1345      62      2026
# 2016     132  1386     87  1433      74      2026
#
# [145289 rows x 6 columns]

# %%
df
# Out:
#       Daynum  Team  Score  Team  Lscore  New_Year
# Year
# 1985      20  1228     81  1328      64      1995
# 1985      25  1106     77  1354      70      1995
# 1985      25  1112     63  1223      56      1995
# 1985      25  1165     70  1432      54      1995
# 1985      25  1192     86  1447      74      1995
# ...      ...   ...    ...   ...     ...       ...
# 2016     132  1114     70  1419      50      2026
# 2016     132  1163     72  1272      58      2026
# 2016     132  1246     82  1401      77      2026
# 2016     132  1277     66  1345      62      2026
# 2016     132  1386     87  1433      74      2026
#
# [145289 rows x 6 columns]

# %% [markdown]
# # to reset_index()

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         Year  Daynum  Team  Score  Team  Lscore  New_Year
# 0       1985      20  1228     81  1328      64      1995
# 1       1985      25  1106     77  1354      70      1995
# 2       1985      25  1112     63  1223      56      1995
# 3       1985      25  1165     70  1432      54      1995
# 4       1985      25  1192     86  1447      74      1995
# ...      ...     ...   ...    ...   ...     ...       ...
# 145284  2016     132  1114     70  1419      50      2026
# 145285  2016     132  1163     72  1272      58      2026
# 145286  2016     132  1246     82  1401      77      2026
# 145287  2016     132  1277     66  1345      62      2026
# 145288  2016     132  1386     87  1433      74      2026
#
# [145289 rows x 7 columns]

# %% [markdown]
# # to rename the index

# %%
df.rename(index={0:'Bhopal'},inplace=True)

# %%
df
# Out:
#         Year  Daynum  Team  Score  Team  Lscore  New_Year
# Bhopal  1985      20  1228     81  1328      64      1995
# 1       1985      25  1106     77  1354      70      1995
# 2       1985      25  1112     63  1223      56      1995
# 3       1985      25  1165     70  1432      54      1995
# 4       1985      25  1192     86  1447      74      1995
# ...      ...     ...   ...    ...   ...     ...       ...
# 145284  2016     132  1114     70  1419      50      2026
# 145285  2016     132  1163     72  1272      58      2026
# 145286  2016     132  1246     82  1401      77      2026
# 145287  2016     132  1277     66  1345      62      2026
# 145288  2016     132  1386     87  1433      74      2026
#
# [145289 rows x 7 columns]

# %%
df.insert(2,"New_Year2",df['Year']+10)

# %%
df
# Out:
#         Year  Daynum  New_Year2  Team  Score  Team  Lscore  New_Year
# Bhopal  1985      20       1995  1228     81  1328      64      1995
# 1       1985      25       1995  1106     77  1354      70      1995
# 2       1985      25       1995  1112     63  1223      56      1995
# 3       1985      25       1995  1165     70  1432      54      1995
# 4       1985      25       1995  1192     86  1447      74      1995
# ...      ...     ...        ...   ...    ...   ...     ...       ...
# 145284  2016     132       2026  1114     70  1419      50      2026
# 145285  2016     132       2026  1163     72  1272      58      2026
# 145286  2016     132       2026  1246     82  1401      77      2026
# 145287  2016     132       2026  1277     66  1345      62      2026
# 145288  2016     132       2026  1386     87  1433      74      2026
#
# [145289 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

# %%
x={'Id':[1,2,3,4],"Name":['ram','shyam','sanyam','priyam'],'Age':[20,21,22,23]}

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#    Id    Name  Age
# 0   1     ram   20
# 1   2   shyam   21
# 2   3  sanyam   22
# 3   4  priyam   23

# %%
y={'Id':[3,4,5,6],"City":['Bhopal','Indore','Bhopal','Goa'],'Salary':[10,20,30,40]}

# %%
y=pd.DataFrame(y)

# %%
y
# Out:
#    Id    City  Salary
# 0   3  Bhopal      10
# 1   4  Indore      20
# 2   5  Bhopal      30
# 3   6     Goa      40

# %%
a=pd.concat([x,y],axis=0)

# %%
a
# Out:
#    Id    Name   Age    City  Salary
# 0   1     ram  20.0     NaN     NaN
# 1   2   shyam  21.0     NaN     NaN
# 2   3  sanyam  22.0     NaN     NaN
# 3   4  priyam  23.0     NaN     NaN
# 0   3     NaN   NaN  Bhopal    10.0
# 1   4     NaN   NaN  Indore    20.0
# 2   5     NaN   NaN  Bhopal    30.0
# 3   6     NaN   NaN     Goa    40.0

# %%
b=pd.concat([x,y],axis=0,ignore_index=True)

# %%
b
# Out:
#    Id    Name   Age    City  Salary
# 0   1     ram  20.0     NaN     NaN
# 1   2   shyam  21.0     NaN     NaN
# 2   3  sanyam  22.0     NaN     NaN
# 3   4  priyam  23.0     NaN     NaN
# 4   3     NaN   NaN  Bhopal    10.0
# 5   4     NaN   NaN  Indore    20.0
# 6   5     NaN   NaN  Bhopal    30.0
# 7   6     NaN   NaN     Goa    40.0

# %%
a=pd.concat([x,y],axis=1)

# %%
a
# Out:
#    Id    Name  Age  Id    City  Salary
# 0   1     ram   20   3  Bhopal      10
# 1   2   shyam   21   4  Indore      20
# 2   3  sanyam   22   5  Bhopal      30
# 3   4  priyam   23   6     Goa      40

# %%
a
# Out:
#    Id    Name  Age  Id    City  Salary
# 0   1     ram   20   3  Bhopal      10
# 1   2   shyam   21   4  Indore      20
# 2   3  sanyam   22   5  Bhopal      30
# 3   4  priyam   23   6     Goa      40

# %%
b=pd.concat([x,y],axis=0,keys=["x","y"])

# %%
b
# Out:
#      Id    Name   Age    City  Salary
# x 0   1     ram  20.0     NaN     NaN
#   1   2   shyam  21.0     NaN     NaN
#   2   3  sanyam  22.0     NaN     NaN
#   3   4  priyam  23.0     NaN     NaN
# y 0   3     NaN   NaN  Bhopal    10.0
#   1   4     NaN   NaN  Indore    20.0
#   2   5     NaN   NaN  Bhopal    30.0
#   3   6     NaN   NaN     Goa    40.0

# %%
x._append(y)
# Out:
#    Id    Name   Age    City  Salary
# 0   1     ram  20.0     NaN     NaN
# 1   2   shyam  21.0     NaN     NaN
# 2   3  sanyam  22.0     NaN     NaN
# 3   4  priyam  23.0     NaN     NaN
# 0   3     NaN   NaN  Bhopal    10.0
# 1   4     NaN   NaN  Indore    20.0
# 2   5     NaN   NaN  Bhopal    30.0
# 3   6     NaN   NaN     Goa    40.0

# %%
x
# Out:
#    Id    Name  Age
# 0   1     ram   20
# 1   2   shyam   21
# 2   3  sanyam   22
# 3   4  priyam   23

# %%
y
# Out:
#    Id    City  Salary
# 0   3  Bhopal      10
# 1   4  Indore      20
# 2   5  Bhopal      30
# 3   6     Goa      40

# %%
inner=pd.merge(x,y,on='Id',how='inner')

# %%
inner
# Out:
#    Id    Name  Age    City  Salary
# 0   3  sanyam   22  Bhopal      10
# 1   4  priyam   23  Indore      20

# %%
Left=pd.merge(x,y,on='Id',how='left')

# %%
Left
# Out:
#    Id    Name  Age    City  Salary
# 0   1     ram   20     NaN     NaN
# 1   2   shyam   21     NaN     NaN
# 2   3  sanyam   22  Bhopal    10.0
# 3   4  priyam   23  Indore    20.0

# %%
right=pd.merge(x,y,on='Id',how='right')

# %%
right
# Out:
#    Id    Name   Age    City  Salary
# 0   3  sanyam  22.0  Bhopal      10
# 1   4  priyam  23.0  Indore      20
# 2   5     NaN   NaN  Bhopal      30
# 3   6     NaN   NaN     Goa      40

# %%
outer=pd.merge(x,y,on='Id',how='outer')

# %%
outer
# Out:
#    Id    Name   Age    City  Salary
# 0   1     ram  20.0     NaN     NaN
# 1   2   shyam  21.0     NaN     NaN
# 2   3  sanyam  22.0  Bhopal    10.0
# 3   4  priyam  23.0  Indore    20.0
# 4   5     NaN   NaN  Bhopal    30.0
# 5   6     NaN   NaN     Goa    40.0

# %%
x
# Out:
#    Id    Name  Age
# 0   1     ram   20
# 1   2   shyam   21
# 2   3  sanyam   22
# 3   4  priyam   23

# %%
inner
# Out:
#    Id    Name  Age    City  Salary
# 0   3  sanyam   22  Bhopal      10
# 1   4  priyam   23  Indore      20

# %%
outer

# %%
outer['Last_name']='Sharma'

# %%
outer
# Out:
#    Id    Name   Age    City  Salary Last_name
# 0   1     ram  20.0     NaN     NaN    Sharma
# 1   2   shyam  21.0     NaN     NaN    Sharma
# 2   3  sanyam  22.0  Bhopal    10.0    Sharma
# 3   4  priyam  23.0  Indore    20.0    Sharma
# 4   5     NaN   NaN  Bhopal    30.0    Sharma
# 5   6     NaN   NaN     Goa    40.0    Sharma

# %%
outer['full_name']=outer['Name']+outer['Last_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[356], line 1
# ----> 1 outer['full_name']=outer['Name']+outer['Last_name']
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Name'

# %%
outer
# Out:
#    Id   Age    City Salary     full_namr
# 0   1  20.0       x      x     ramSharma
# 1   2  21.0       x      x   shyamSharma
# 2   3  22.0  Bhopal   10.0  sanyamSharma
# 3   4  23.0  Indore   20.0  priyamSharma
# 4   5     x  Bhopal   30.0             x
# 5   6     x     Goa   40.0             x

# %%
outer
# Out:
#    Id    Name   Age    City  Salary Last_name     full_namr
# 0   1     ram  20.0     NaN     NaN    Sharma     ramSharma
# 1   2   shyam  21.0     NaN     NaN    Sharma   shyamSharma
# 2   3  sanyam  22.0  Bhopal    10.0    Sharma  sanyamSharma
# 3   4  priyam  23.0  Indore    20.0    Sharma  priyamSharma
# 4   5     NaN   NaN  Bhopal    30.0    Sharma           NaN
# 5   6     NaN   NaN     Goa    40.0    Sharma           NaN

# %%
outer.fillna('x',inplace=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11044\895014583.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'x' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   outer.fillna('x',inplace=True)

# %%
outer
# Out:
#    Id    Name   Age    City Salary Last_name     full_namr
# 0   1     ram  20.0       x      x    Sharma     ramSharma
# 1   2   shyam  21.0       x      x    Sharma   shyamSharma
# 2   3  sanyam  22.0  Bhopal   10.0    Sharma  sanyamSharma
# 3   4  priyam  23.0  Indore   20.0    Sharma  priyamSharma
# 4   5       x     x  Bhopal   30.0    Sharma             x
# 5   6       x     x     Goa   40.0    Sharma             x

# %%
outer['Name']=outer['Name'].replace("x","SHAYAM")

# %%
outer
# Out:
#    Id    Name   Age    City Salary Last_name     full_namr
# 0   1     ram  20.0       x      x    Sharma     ramSharma
# 1   2   shyam  21.0       x      x    Sharma   shyamSharma
# 2   3  sanyam  22.0  Bhopal   10.0    Sharma  sanyamSharma
# 3   4  priyam  23.0  Indore   20.0    Sharma  priyamSharma
# 4   5  SHAYAM     x  Bhopal   30.0    Sharma             x
# 5   6  SHAYAM     x     Goa   40.0    Sharma             x

# %%
outer.drop(columns=['Name','Last_name'],inplace=True)

# %%
outer
# Out:
#    Id   Age    City Salary     full_namr
# 0   1  20.0       x      x     ramSharma
# 1   2  21.0       x      x   shyamSharma
# 2   3  22.0  Bhopal   10.0  sanyamSharma
# 3   4  23.0  Indore   20.0  priyamSharma
# 4   5     x  Bhopal   30.0             x
# 5   6     x     Goa   40.0             x

# %%
outer[['Fist_name','L_Name']]=outer['full_namr'].str.split(" ",expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[355], line 1
# ----> 1 outer[['Fist_name','L_Name']]=outer['full_namr'].str.split(" ",expand=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexers\utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key
