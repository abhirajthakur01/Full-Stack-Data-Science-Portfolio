# %%
#dictionary creation
my_dict = {
    'name': 'Alice',
    'age': 30,
    'city': 'New York'
}

# %%
print("My Dictionary:", my_dict)
# Out:
# My Dictionary: {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
print("Name:", my_dict['name'])
print("City:", my_dict['city'])
# Out:
# Name: Alice
# City: New York

# %%
my_dict['age'] = 32
my_dict['occupation'] = 'Engineer'

# %%
dict = {"name":['rama','shayama'],"age":30,"city":"bhopal"}

# %%
dict
# Out:
# {'name': ['rama', 'shayama'], 'age': 30, 'city': 'bhopal'}

# %%
dict["name"] = "shayama"

# %%
my_dict = {"ID": [1,2,3,4,5], "Name":["arush","abhi", "raj", "shiv", "dev"],"age":[20,30,45,22,34], "city": ["bpl","mumbai","delhi", "pip","leh"]}
my_dict
# Out:
# {'ID': [1, 2, 3, 4, 5],
#  'Name': ['arush', 'abhi', 'raj', 'shiv', 'dev'],
#  'age': [20, 30, 45, 22, 34],
#  'city': ['bpl', 'mumbai', 'delhi', 'pip', 'leh']}

# %%
my_dict['Name'][4]
# Out:
# 'dev'

# %%
my_dict.get("age")
# Out:
# [20, 30, 45, 22, 34]

# %%
my_dict.get('age','not found')
# Out:
# [20, 30, 45, 22, 34]

# %%
my_dict.keys()
# Out:
# dict_keys(['ID', 'Name', 'age', 'city'])

# %%
my_dict.values()
# Out:
# dict_values([[1, 2, 3, 4, 5], ['arush', 'abhi', 'raj', 'shiv', 'dev'], [20, 30, 45, 22, 34], ['bpl', 'mumbai', 'delhi', 'pip', 'leh']])

# %%
my_dict.items()
# Out:
# dict_items([('ID', [1, 2, 3, 4, 5]), ('Name', ['arush', 'abhi', 'raj', 'shiv', 'dev']), ('age', [20, 30, 45, 22, 34]), ('city', ['bpl', 'mumbai', 'delhi', 'pip', 'leh'])])

# %%
my_dict.update({'gender':['M','M','F','F','M']})

# %%
my_dict
# Out:
# {'ID': [1, 2, 3, 4, 5],
#  'Name': ['arush', 'abhi', 'raj', 'shiv', 'dev'],
#  'age': [20, 30, 45, 22, 34],
#  'city': ['bpl', 'mumbai', 'delhi', 'pip', 'leh'],
#  'gender': ['M', 'M', 'F', 'F', 'M']}
