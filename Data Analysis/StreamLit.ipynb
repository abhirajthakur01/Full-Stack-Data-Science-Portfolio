# %%
import streamlit as st

# %%
st.title("Machine Learning Project")#Title
# Out:
# 2025-04-18 22:48:22.553 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 22:48:23.154
# ...
#   command:
#
#     streamlit run C:\Users\HP\myenv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-18 22:48:23.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("this is a header")
# Out:
# 2025-04-18 22:49:14.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 22:49:14.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
