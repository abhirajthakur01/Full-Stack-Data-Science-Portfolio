# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("employee_data_200.csv")

# %%
df.shape
# Out:
# (250, 10)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['EmpId', 'FirstNme', 'LstName', 'Dept', 'Positon', 'Slary', 'HireDat',
#        'BrthDate', 'Phne', 'Emil'],
#       dtype='object')

# %%
#Load the CSV file employee_data_200.csv into a DataFrame
df.head(10)
# Out:
#    EmpId FirstNme   LstName       Dept      Positon  Slary     HireDat  \
# 0     45     John     Smith         IT   Consultant  72572  2016-10-11
# 1     48     John     Smith      Sales   Consultant  57951  2018-03-27
# 2     65     Jane     Smith    Finance      Manager  93005  2016-11-24
# 3     68      Bob       Doe         HR    Developer  68007  2016-07-08
# 4     68     John  Williams         IT    Developer  56091  2020-09-14
# 5     10    Alice       Doe         HR    Developer  84381  2015-12-22
# 6     84     Jane     Brown    Finance  Coordinator  91470  2019-09-17
# 7     22     Jane     Smith         HR   Consultant  57581  2019-09-27
# 8     37    David     Brown         HR   Consultant  72111  2015-03-23
# 9     88     John       Doe  Marketing      Analyst  78782  2020-09-17
#
#      BrthDate      Phne                     Emil
# 0  1990-03-24  555-4321  bob.johnson@example.com
# 1  1977-01-26  555-8765     john.doe@example.com
# ...

# %%
df.tail(10)
# Out:
#      EmpId FirstNme   LstName       Dept      Positon  Slary     HireDat  \
# 240     33     Jane  Williams         IT    Developer  60525  2016-01-13
# 241     22     Jane     Brown    Finance  Coordinator  91847  2016-05-13
# 242    100    Alice     Smith         IT      Manager  75983  2015-01-17
# 243     38    David  Williams  Marketing  Coordinator  89855  2020-07-16
# 244      4     John   Johnson    Finance    Developer  80642  2015-07-01
# 245     95      Bob     Brown  Marketing      Analyst  55912  2020-03-08
# 246     37     John       Doe      Sales  Coordinator  94503  2018-01-28
# 247     48    Alice     Smith         IT    Developer  74354  2015-04-27
# 248     99     Jane     Brown         IT    Developer  70594  2018-05-19
# 249     30    David   Johnson    Finance  Coordinator  66138  2017-10-25
#
#        BrthDate      Phne                        Emil
# 240  1993-10-03  555-5678  alice.williams@example.com
# 241  1996-08-30  555-5678     bob.johnson@example.com
# ...

# %%
df.columns.values.tolist()
# Out:
# ['EmpId',
#  'FirstNme',
#  'LstName',
#  'Dept',
#  'Positon',
#  'Slary',
#  'HireDat',
#  'BrthDate',
#  'Phne',
#  'Emil']

# %%
df.Dept.unique()
# Out:
# array(['IT', 'Sales', 'Finance', 'HR', 'Marketing'], dtype=object)

# %%
df.Positon.unique()
# Out:
# array(['Consultant', 'Manager', 'Developer', 'Coordinator', 'Analyst'],
#       dtype=object)

# %%
df.Dept.
