# %%
import numpy as np
import pandas as pd

# %%
#pandas data frame 
df = pd.read_csv("nba.csv")

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
sample_df = df.sample(15)

# %%
sample_df
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 391   Joffrey Lauvergne          Denver Nuggets    77.0        C  24.0   6-11
# 112     Marcelo Huertas      Los Angeles Lakers     9.0       PG  33.0    6-3
# 430        Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0    6-6
# 162         Joakim Noah           Chicago Bulls    13.0        C  31.0   6-11
# 435      Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0    7-1
# 327    Tyler Hansbrough       Charlotte Hornets    50.0       PF  30.0    6-9
# 94       Branden Dawson    Los Angeles Clippers    22.0       SF  23.0    6-6
# 307    Jonathon Simmons       San Antonio Spurs    17.0       SG  26.0    6-6
# 314         Kyle Korver           Atlanta Hawks    26.0       SG  35.0    6-7
# 157          Taj Gibson           Chicago Bulls    22.0       PF  30.0    6-9
# 376     Markieff Morris      Washington Wizards     5.0       PF  26.0   6-10
# ...

# %%
sample_df.sort_index()
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 94       Branden Dawson    Los Angeles Clippers    22.0       SF  23.0    6-6
# 112     Marcelo Huertas      Los Angeles Lakers     9.0       PG  33.0    6-3
# 157          Taj Gibson           Chicago Bulls    22.0       PF  30.0    6-9
# 162         Joakim Noah           Chicago Bulls    13.0        C  31.0   6-11
# 203           Ty Lawson          Indiana Pacers    10.0       PG  28.0   5-11
# 206  Glenn Robinson III          Indiana Pacers    40.0       SG  22.0    6-7
# 307    Jonathon Simmons       San Antonio Spurs    17.0       SG  26.0    6-6
# 314         Kyle Korver           Atlanta Hawks    26.0       SG  35.0    6-7
# 327    Tyler Hansbrough       Charlotte Hornets    50.0       PF  30.0    6-9
# 376     Markieff Morris      Washington Wizards     5.0       PF  26.0   6-10
# 391   Joffrey Lauvergne          Denver Nuggets    77.0        C  24.0   6-11
# ...

# %%
sample_df.sort_index(axis=0)
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 94       Branden Dawson    Los Angeles Clippers    22.0       SF  23.0    6-6
# 112     Marcelo Huertas      Los Angeles Lakers     9.0       PG  33.0    6-3
# 157          Taj Gibson           Chicago Bulls    22.0       PF  30.0    6-9
# 162         Joakim Noah           Chicago Bulls    13.0        C  31.0   6-11
# 203           Ty Lawson          Indiana Pacers    10.0       PG  28.0   5-11
# 206  Glenn Robinson III          Indiana Pacers    40.0       SG  22.0    6-7
# 307    Jonathon Simmons       San Antonio Spurs    17.0       SG  26.0    6-6
# 314         Kyle Korver           Atlanta Hawks    26.0       SG  35.0    6-7
# 327    Tyler Hansbrough       Charlotte Hornets    50.0       PF  30.0    6-9
# 376     Markieff Morris      Washington Wizards     5.0       PF  26.0   6-10
# 391   Joffrey Lauvergne          Denver Nuggets    77.0        C  24.0   6-11
# ...

# %%
df.sort_index(axis=1)
# Out:
#       Age            College Height           Name  Number Position  \
# 0    25.0              Texas    6-2  Avery Bradley     0.0       PG
# 1    25.0          Marquette    6-6    Jae Crowder    99.0       SF
# 2    27.0  Boston University    6-5   John Holland    30.0       SG
# 3    22.0      Georgia State    6-5    R.J. Hunter    28.0       SG
# 4    29.0                NaN   6-10  Jonas Jerebko     8.0       PF
# ..    ...                ...    ...            ...     ...      ...
# 453  26.0             Butler    6-3   Shelvin Mack     8.0       PG
# 454  24.0                NaN    6-1      Raul Neto    25.0       PG
# 455  26.0                NaN    7-3   Tibor Pleiss    21.0        C
# 456  26.0             Kansas    7-0    Jeff Withey    24.0        C
# 457   NaN                NaN    NaN            NaN     NaN      NaN
#
#         Salary            Team  Weight
# 0    7730337.0  Boston Celtics   180.0
# 1    6796117.0  Boston Celtics   235.0
# ...

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#      Weight            Team     Salary Position  Number           Name Height  \
# 0     180.0  Boston Celtics  7730337.0       PG     0.0  Avery Bradley    6-2
# 1     235.0  Boston Celtics  6796117.0       SF    99.0    Jae Crowder    6-6
# 2     205.0  Boston Celtics        NaN       SG    30.0   John Holland    6-5
# 3     185.0  Boston Celtics  1148640.0       SG    28.0    R.J. Hunter    6-5
# 4     231.0  Boston Celtics  5000000.0       PF     8.0  Jonas Jerebko   6-10
# ..      ...             ...        ...      ...     ...            ...    ...
# 453   203.0       Utah Jazz  2433333.0       PG     8.0   Shelvin Mack    6-3
# 454   179.0       Utah Jazz   900000.0       PG    25.0      Raul Neto    6-1
# 455   256.0       Utah Jazz  2900000.0        C    21.0   Tibor Pleiss    7-3
# 456   231.0       Utah Jazz   947276.0        C    24.0    Jeff Withey    7-0
# 457     NaN             NaN        NaN      NaN     NaN            NaN    NaN
#
#                College   Age
# ...

# %%
data = pd.read_csv("nba.csv")

# %%
#before sorting
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.sort_values("Name",axis=0, ascending=True,inplace=True, na_position='last')

# %%
data
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# ..              ...                     ...     ...      ...   ...    ...
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402     Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271   Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237   Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
data.sort_values("Name",axis=0, ascending=True,inplace=True, na_position='first')

# %%
data
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# ..               ...                     ...     ...      ...   ...    ...
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
#
#      Weight         College      Salary
# ...

# %%
data[['Team','Name']].sort_values(['Team','Name']).head(20)
# Out:
#                Team              Name
# 312   Atlanta Hawks        Al Horford
# 318   Atlanta Hawks   Dennis Schroder
# 323   Atlanta Hawks       Jeff Teague
# 309   Atlanta Hawks     Kent Bazemore
# 311   Atlanta Hawks      Kirk Hinrich
# 313   Atlanta Hawks    Kris Humphries
# 314   Atlanta Hawks       Kyle Korver
# 317   Atlanta Hawks   Lamar Patterson
# 316   Atlanta Hawks      Mike Muscala
# 319   Atlanta Hawks        Mike Scott
# 315   Atlanta Hawks      Paul Millsap
# 320   Atlanta Hawks   Thabo Sefolosha
# 321   Atlanta Hawks    Tiago Splitter
# 310   Atlanta Hawks  Tim Hardaway Jr.
# 322   Atlanta Hawks    Walter Tavares
# 5    Boston Celtics      Amir Johnson
# 0    Boston Celtics     Avery Bradley
# 12   Boston Celtics       Evan Turner
# 11   Boston Celtics     Isaiah Thomas
# 1    Boston Celtics       Jae Crowder

# %%
data[['Team','Name']].sort_values(['Team','Name'],ascending = True).head(20)
# Out:
#                Team              Name
# 312   Atlanta Hawks        Al Horford
# 318   Atlanta Hawks   Dennis Schroder
# 323   Atlanta Hawks       Jeff Teague
# 309   Atlanta Hawks     Kent Bazemore
# 311   Atlanta Hawks      Kirk Hinrich
# 313   Atlanta Hawks    Kris Humphries
# 314   Atlanta Hawks       Kyle Korver
# 317   Atlanta Hawks   Lamar Patterson
# 316   Atlanta Hawks      Mike Muscala
# 319   Atlanta Hawks        Mike Scott
# 315   Atlanta Hawks      Paul Millsap
# 320   Atlanta Hawks   Thabo Sefolosha
# 321   Atlanta Hawks    Tiago Splitter
# 310   Atlanta Hawks  Tim Hardaway Jr.
# 322   Atlanta Hawks    Walter Tavares
# 5    Boston Celtics      Amir Johnson
# 0    Boston Celtics     Avery Bradley
# 12   Boston Celtics       Evan Turner
# 11   Boston Celtics     Isaiah Thomas
# 1    Boston Celtics       Jae Crowder

# %%
data[['Team','Name']].sort_values(['Team','Name'],ascending= [True,False]).head(20)
# Out:
#                Team              Name
# 322   Atlanta Hawks    Walter Tavares
# 310   Atlanta Hawks  Tim Hardaway Jr.
# 321   Atlanta Hawks    Tiago Splitter
# 320   Atlanta Hawks   Thabo Sefolosha
# 315   Atlanta Hawks      Paul Millsap
# 319   Atlanta Hawks        Mike Scott
# 316   Atlanta Hawks      Mike Muscala
# 317   Atlanta Hawks   Lamar Patterson
# 314   Atlanta Hawks       Kyle Korver
# 313   Atlanta Hawks    Kris Humphries
# 311   Atlanta Hawks      Kirk Hinrich
# 309   Atlanta Hawks     Kent Bazemore
# 323   Atlanta Hawks       Jeff Teague
# 318   Atlanta Hawks   Dennis Schroder
# 312   Atlanta Hawks        Al Horford
# 14   Boston Celtics      Tyler Zeller
# 8    Boston Celtics      Terry Rozier
# 3    Boston Celtics       R.J. Hunter
# 9    Boston Celtics      Marcus Smart
# 7    Boston Celtics      Kelly Olynyk

# %%
data.sort_values(['Team','Name'],ascending=[True,False])
# Out:
#                  Name                Team  Number Position   Age Height  \
# 322    Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# ..                ...                 ...     ...      ...   ...    ...
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 322   260.0             NaN   1000000.0
# ...

# %%
data.sort_values(['Team','Name'],ascending=[True,False],ignore_index=True)
# Out:
#                  Name                Team  Number Position   Age Height  \
# 0      Walter Tavares       Atlanta Hawks    22.0        C  24.0    7-3
# 1    Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 2      Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 3     Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 4        Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# ..                ...                 ...     ...      ...   ...    ...
# 453    Garrett Temple  Washington Wizards    17.0       SG  30.0    6-6
# 454       Drew Gooden  Washington Wizards    90.0       PF  34.0   6-10
# 455      Bradley Beal  Washington Wizards     3.0       SG  22.0    6-5
# 456     Alan Anderson  Washington Wizards     6.0       SG  33.0    6-6
# 457               NaN                 NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# 0     260.0             NaN   1000000.0
# ...
