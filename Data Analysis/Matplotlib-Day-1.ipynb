# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig, ax=plt.subplots()
print(fig,ax)
# Out:
# Figure(640x480) Axes(0.125,0.11;0.775x0.77)

# %%
# y lable not shared
plt.figure(figsize=(6,4))
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.text(0.5,0.5,'left')
ax1.set_title('Left Subplot')
ax1.set_xlabel('Left_Subplot_xaxis')
ax1.set_ylabel('Left_Subplot_yaxis')
ax2.text(0.5,0.5,'right')
ax2.set_title('Right Subplot')
ax2.set_xlabel('Right_Subplot_xaxis')
ax2.set_ylabel('Left_Subplot_yaxis')
plt.tight_layout()

# %%
plt.figure(figsize=(6,4))
fig, (ax1,ax2) = plt.subplots(2,2)
print(fig,ax1)
# Out:
# Figure(640x480) [<Axes: > <Axes: >]

# %%
# y lable not shared
plt.figure(figsize=(6,4))
fig, (ax1,ax2) = plt.subplots(1,2,sharey=True)
ax1.text(0.5,0.5,'left')
ax1.set_title('Left Subplot')
ax1.set_xlabel('Left_Subplot_xaxis')
ax1.set_ylabel('Left_Subplot_yaxis')
ax2.text(0.5,0.5,'right')
ax2.set_title('Right Subplot')
ax2.set_xlabel('Right_Subplot_xaxis')
ax2.set_ylabel('Left_Subplot_yaxis')
plt.tight_layout()

# %%
# x lable not shared
plt.figure(figsize=(4,6))
fig,(ax1,ax2) = plt.subplots(2,1)
ax1.text(0.5,0.5,'Top',color = 'r', fontsize=14)
ax1.set_title('Top Subplot')
ax1.set_xlabel('Top_Subplot_xaxis')
ax1.set_ylabel('Top_Subplot_yaxis')
ax2.text(0.5,0.5,'Bottom', color='b')
ax2.set_title('Bottom Subplot')
ax2.set_xlabel('Bottom_Subplot_xaxis')
ax2.set_ylabel('Bottom_Subplot_yaxis')
plt.tight_layout()

# %%
# x lable not shared
plt.figure(figsize=(4,6))
fig,(ax1,ax2) = plt.subplots(2,1,sharex=True)
ax1.text(0.5,0.5,'Top',color = 'r', fontsize=14)
ax1.set_title('Top Subplot')
ax1.set_xlabel('Top_Subplot_xaxis')
ax1.set_ylabel('Top_Subplot_yaxis')
ax2.text(0.5,0.5,'Bottom', color='b')
ax2.set_title('Bottom Subplot')
ax2.set_xlabel('Bottom_Subplot_xaxis')
ax2.set_ylabel('Bottom_Subplot_yaxis')
plt.tight_layout()

# %%
# 2X3 grid subplots

rows, cols = 2, 3
fig, ax = plt.subplots(rows, cols,
                       sharex='col', 
                       sharey='row')

for row in range(rows):
    for col in range(cols):
        ax[row, col].text(0.5, 0.5, 
                          str((row, col)),
                          color="green",
                          fontsize=18, 
                          ha='center')

plt.show()

# %%
# x lable not shared
plt.figure(figsize=(4,6))
fig,(ax1,ax2,ax3,ax4,ax5,ax6) = plt.subplots(2,3)
ax1.text(0.5,0.5,'Top',color = 'r', fontsize=14)
ax1.set_title('Top Subplot')
ax1.set_xlabel('Top_Subplot_xaxis')
ax1.set_ylabel('Top_Subplot_yaxis')
ax2.text(0.5,0.5,'Bottom', color='b')
ax2.set_title('Bottom Subplot')
ax2.set_xlabel('Bottom_Subplot_xaxis')
ax2.set_ylabel('Bottom_Subplot_yaxis')
ax3.text(0.5,0.5,'Top',color = 'r', fontsize=14)
ax3.set_title('Top Subplot')
ax3.set_xlabel('Top_Subplot_xaxis')
ax3.set_ylabel('Top_Subplot_yaxis')
ax4.text(0.5,0.5,'Bottom', color='b')
ax4.set_title('Bottom Subplot')
ax4.set_xlabel('Bottom_Subplot_xaxis')
ax4.set_ylabel('Bottom_Subplot_yaxis')
ax5.text(0.5,0.5,'Top',color = 'r', fontsize=14)
ax5.set_title('Top Subplot')
ax5.set_xlabel('Top_Subplot_xaxis')
ax5.set_ylabel('Top_Subplot_yaxis')
ax6.text(0.5,0.5,'Bottom', color='b')
ax6.set_title('Bottom Subplot')
ax6.set_xlabel('Bottom_Subplot_xaxis')
ax6.set_ylabel('Bottom_Subplot_yaxis')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # x lable not shared
#       2 plt.figure(figsize=(4,6))
# ----> 3 fig,(ax1,ax2,ax3,ax4,ax5,ax6) = plt.subplots(2,3)
#       4 ax1.text(0.5,0.5,'Top',color = 'r', fontsize=14)
#       5 ax1.set_title('Top Subplot')
#
# ValueError: not enough values to unpack (expected 6, got 2)

# %%
# x lable not shared
plt.figure(figsize=(4,6))
fig,(ax) = plt.subplots(2,3)
[0,0].text(0.5,0.5,'Top',color = 'r', fontsize=14)
[0,0].set_title('Top Subplot')
[0,0].set_xlabel('Top_Subplot_xaxis')
[0,0].set_ylabel('Top_Subplot_yaxis')
[0,1].text(0.5,0.5,'Bottom', color='b')
[0,1].set_title('Bottom Subplot')
[0,1].set_xlabel('Bottom_Subplot_xaxis')
[0,1].set_ylabel('Bottom_Subplot_yaxis')
[0,2].text(0.5,0.5,'Top',color = 'r', fontsize=14)
[0,2].set_title('Top Subplot')
[0,2].set_xlabel('Top_Subplot_xaxis')
[0,2].set_ylabel('Top_Subplot_yaxis')
[1,0].text(0.5,0.5,'Bottom', color='b')
[1,0].set_title('Bottom Subplot')
[1,0].set_xlabel('Bottom_Subplot_xaxis')
[1,0].set_ylabel('Bottom_Subplot_yaxis')
[1,1].text(0.5,0.5,'Top',color = 'r', fontsize=14)
[1,1].set_title('Top Subplot')
[1,1].set_xlabel('Top_Subplot_xaxis')
[1,1].set_ylabel('Top_Subplot_yaxis')
[1,2].text(0.5,0.5,'Bottom', color='b')
[1,2].set_title('Bottom Subplot')
[1,2].set_xlabel('Bottom_Subplot_xaxis')
[1,2].set_ylabel('Bottom_Subplot_yaxis')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       2 plt.figure(figsize=(4,6))
#       3 fig,(ax) = plt.subplots(2,3)
# ----> 4 [0,0].text(0.5,0.5,'Top',color = 'r', fontsize=14)
#       5 [0,0].set_title('Top Subplot')
#       6 [0,0].set_xlabel('Top_Subplot_xaxis')
#
# AttributeError: 'list' object has no attribute 'text'

# %%
fig = plt.figure(figsize=(8,4))
# first plot
sub1 = plt.subplot(2,2,1)
sub1.set_xticks(()) # remove xticks
sub1.text(0.5,0.5,'Sub1',ha='center',va='center',size=20)

# Second plot
sub2 = plt.subplot(2,2,2)
sub2.text(0.5,0.5,'Sub2',ha='center',va='center', size=20)

# Third plot
sub3 = plt.subplot(2,2,3)
sub3.text(0.5,0.5,'Sub3', ha='center', va='center', size=20)

# Fourth plot
sub4 = plt.subplot(2,2,4, facecolor='yellow')
sub4.text(0.5,0.5,'Sub4', ha='center', va='center', size=20, color='b')
# Out:
# Text(0.5, 0.5, 'Sub4')

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).text(0.5,0.5,'Sub1',color='red',ha='center')
plt.subplot(2,2,1).set_facecolor('pink')
plt.subplot(2,2,2).text(0.5,0.5,'Sub2',ha='center')
plt.subplot(2,2,2).set_facecolor('Yellow')
plt.subplot(2,2,3).text(0.5,0.5,'Sub3',color='white',ha='center')
plt.subplot(2,2,3).set_facecolor('blue')
plt.subplot(2,2,4).text(0.5,0.5,'Sub4',ha='center')
plt.subplot(2,2,4).set_facecolor('green')

# %%
x = [(2,1,1),(2,3,4),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')

plt.tight_layout()

# %%
# remove xticks and yticks
x = [(2,1,1),(2,3,4),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks([])

plt.tight_layout()

# %%
x = [(2,3,(1,3)),(2,3,4),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,(1,2)),(2,3,4),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,(1,3)),(2,3,3),(2,3,4),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,1),(2,3,2),(2,3,4),(2,3,5),(2,3,(3,6))]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,1),(2,3,2),(2,3,4),(2,3,5),(2,3,(1,6))]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,1),(2,3,2),(2,3,4),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,1),(2,3,3),(2,3,4),(2,3,(2,5)),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,(1,4)),(2,3,2),(2,3,3),(2,3,5),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,1),(2,3,2),(2,3,3),(2,3,(4,5)),(2,3,6)]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())

plt.tight_layout()

# %%
x = [(2,3,1),(2,3,4),(2,3,(2,6))]
for nrows,ncols,plot_number in x:
    plt.subplot(nrows,ncols,plot_number)
    plt.text(0.5,0.5,(nrows,ncols,plot_number), ha='center',va='center')
    plt.xticks(())
    plt.yticks(())
    
plt.tight_layout()

# %%
date=["25/12","26/12","27/12"]
temp = [8.5,10.5,6.8]
#x = [(2,3,1),(2,3,4),(2,3,(2,6))]
plt.subplot(2,3,1)
plt.plot(date,temp)

plt.subplot(2,3,4)
plt.plot(date,temp, 'r--P')

plt.subplot(2,3,(2,6))
plt.plot(date,temp, 'b^')

plt.tight_layout()

# %%
x = [ (1,2,1), (3,2,2), (3,2,4), (3,2,6) ]
for nrows, ncols, plot_number in x:
    plt.subplot(nrows, ncols, plot_number)
    plt.xticks([])
    plt.yticks([])

# %%
df = pd.read_csv("HistoricalPrices.csv")

# %%
df.head()
# Out:
#        Date      Open      High       Low     Close
# 0  03/07/24  38784.30  38910.35  38730.13  38791.35
# 1  03/06/24  38721.15  38858.13  38570.80  38661.05
# 2  03/05/24  38906.98  38906.98  38457.83  38585.19
# 3  03/04/24  38968.77  39087.86  38913.30  38989.83
# 4  03/01/24  38989.51  39120.36  38850.50  39087.38

# %%
df.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close'], dtype='object')

# %%
plt.subplot(2,4,(1,4))
plt.plot(df['Date'],df[' Open'])

# %%
plt.figure(figsize=(10,8))#ex1
X = [1, 2, 3, 4, 5, 6, 7]
Y = [1, 3, 4, 2, 5, 8, 6]
axes1 = plt.axes([0.1,0.1,0.9,0.9])
axes2 = plt.axes([0.2,0.6,0.4,0.3])

axes1.plot(X,Y,marker='o',color='r',markerfacecolor='b')
axes2.plot(Y,X)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
# Generate data to plot
linear = [x for x in range(5)]
square = [x**2 for x in range(5)]
cube = [x**3 for x in range(5)]

# %%
print(linear)
print(square)
print(cube)
# Out:
# [0, 1, 2, 3, 4]
# [0, 1, 4, 9, 16]
# [0, 1, 8, 27, 64]

# %%
# Generate Figure object and Axes object with shape 3X1
fig, axes = plt.subplots(nrows=3, ncols=1)

# Access first subplot and plot linear numbers
axes[0].plot(linear)

# Access second subplot and plot square numbers
axes[1].plot(square)

# Access third subplot and plot cube numbers
axes[2].plot(cube)


plt.tight_layout()
plt.show()

# %%
fig , axes = plt.subplots(nrows=2, ncols=2)

# Generate data to plot
data = np.array([1,2,3,4,5])

# Access Axes object with numpy slicing then plot different distributions 

axes[0,0].plot(data)
axes[0,1].plot(data**2)
axes[1,0].plot(data**3)
axes[1,1].plot(np.log(data))
plt.tight_layout()
plt.show()
