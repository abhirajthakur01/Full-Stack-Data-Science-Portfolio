# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
world = pd.read_csv("world_population.csv")

# %%
world.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
world.shape
# Out:
# (234, 17)

# %%
world.info
# Out:
# <bound method DataFrame.info of      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# ...

# %%
temp=pd.DataFrame()

# %%
temp=world.groupby('Continent')['2022 Population'].sum()

# %%
temp
# Out:
# Continent
# Africa           1426730932
# Asia             4721383274
# Europe            743147538
# North America     600296136
# Oceania            45038554
# South America     436816608
# Name: 2022 Population, dtype: int64

# %%
type(temp)
# Out:
# pandas.core.series.Series

# %%
temp=pd.DataFrame(temp)

# %%
temp
# Out:
#                2022 Population
# Continent
# Africa              1426730932
# Asia                4721383274
# Europe               743147538
# North America        600296136
# Oceania               45038554
# South America        436816608

# %%
temp = temp.reset_index()

# %%
temp.columns
# Out:
# Index(['Continent', '2022 Population'], dtype='object')

# %%
world.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
#1-plot bar chat for asian country which show 2022,2020 and 2015 population
world[world['Continent']=='Asia'].plot('Country/Territory',['2022 Population', '2020 Population', '2015 Population'],kind='bar')
# Out:
# <Axes: xlabel='Country/Territory'>

# %%
world[world['Continent'].isin(['Asia','Europe'])].plot('Country/Territory',['2022 Population', '2020 Population', '2015 Population'],kind='bar')
# Out:
# <Axes: xlabel='Country/Territory'>

# %%
plt.figure(figsize=(20,4))

# %%
#2-. Plot bar chart for to 10 Asian country as per World Population Percentage .
W1 = world.sort_values('World Population Percentage',ascending=False).head(10)

# %%
W1
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
# 27      7  BRA            Brazil          Brasilia  South America
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 171     9  RUS            Russia            Moscow         Europe
# 131    10  MEX            Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
W1 = world[world['Continent']=='Asia'].sort_values('World Population Percentage',ascending=False).head(10)

# %%
W1
# Out:
#      Rank CCA3 Country/Territory    Capital Continent  2022 Population  \
# 41      1  CHN             China    Beijing      Asia       1425887337
# 92      2  IND             India  New Delhi      Asia       1417173173
# 93      4  IDN         Indonesia    Jakarta      Asia        275501339
# 156     5  PAK          Pakistan  Islamabad      Asia        235824862
# 16      8  BGD        Bangladesh      Dhaka      Asia        171186372
# 102    11  JPN             Japan      Tokyo      Asia        123951692
# 163    13  PHL       Philippines     Manila      Asia        115559009
# 228    16  VNM           Vietnam      Hanoi      Asia         98186856
# 94     17  IRN              Iran     Tehran      Asia         88550570
# 213    18  TUR            Turkey     Ankara      Asia         85341241
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 41        1424929781       1393715448       1348191368       1264099069
# ...

# %%
W1[['Country/Territory', 'World Population Percentage']].plot(kind='bar', x='Country/Territory', figsize=(10,3))
plt.xlabel('Country', fontsize=16)
plt.ylabel('popuplation', fontsize=16)
plt.title('Asia country population', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Asia country population')

# %%
#Q3. Plot pie chart which shows Continent wise share of World Population Percentage .
world.Continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
C1 = world.groupby('Continent')['World Population Percentage'].sum()

# %%
C1
# Out:
# Continent
# Africa           17.87
# Asia             59.19
# Europe            9.33
# North America     7.51
# Oceania           0.55
# South America     5.48
# Name: World Population Percentage, dtype: float64

# %%
C1.plot.pie(autopct='%2f')
# Out:
# <Axes: ylabel='World Population Percentage'>

# %%
#Q4. Plot pie chart which shows Continent wise share of Area.
C2 = world.groupby('Continent')['Area (km²)'].sum()

# %%
C2
# Out:
# Continent
# Africa           30317963
# Asia             32138141
# Europe           23010411
# North America    24244178
# Oceania           8515081
# South America    17833382
# Name: Area (km²), dtype: int64

# %%
C2.plot.pie(autopct='%2f')
# Out:
# <Axes: ylabel='Area (km²)'>

# %%
#Q5. Plot pie chart which shows Continent wise share of Density .

C3 = world.groupby('Continent')['Density (per km²)'].sum()

# %%
C3
# Out:
# Continent
# Africa            7127.7158
# Asia             51251.2068
# Europe           33166.2371
# North America    10910.4703
# Oceania           3048.4905
# South America      293.6077
# Name: Density (per km²), dtype: float64

# %%
C3.plot.pie(autopct='%2f')
# Out:
# <Axes: ylabel='Density (per km²)'>

# %%
#Q6. Plot bar chart which shows year wise trend of Indian population .
In = world[world['Country/Territory']=='India']

# %%
In.T
# Out:
#                                      92
# Rank                                  2
# CCA3                                IND
# Country/Territory                 India
# Capital                       New Delhi
# Continent                          Asia
# 2022 Population              1417173173
# 2020 Population              1396387127
# 2015 Population              1322866505
# 2010 Population              1240613620
# 2000 Population              1059633675
# 1990 Population               870452165
# 1980 Population               696828385
# 1970 Population               557501301
# Area (km²)                      3287590
# Density (per km²)              431.0675
# Growth Rate                      1.0068
# World Population Percentage       17.77

# %%
In.T[5:13].plot(kind='bar')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, '2022 Population'),
#   Text(1, 0, '2020 Population'),
#   Text(2, 0, '2015 Population'),
#   Text(3, 0, '2010 Population'),
#   Text(4, 0, '2000 Population'),
#   Text(5, 0, '1990 Population'),
#   Text(6, 0, '1980 Population'),
#   Text(7, 0, '1970 Population')])

# %%
#Q7. Plot line chart which shows year wise trend of Top 3 Asian county as per population percentage.
InCh = world[world['Country/Territory'].isin(['India','China','Indonesia'])]

# %%
InCh
# Out:
#     Rank CCA3 Country/Territory    Capital Continent  2022 Population  \
# 41     1  CHN             China    Beijing      Asia       1425887337
# 92     2  IND             India  New Delhi      Asia       1417173173
# 93     4  IDN         Indonesia    Jakarta      Asia        275501339
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 41       1424929781       1393715448       1348191368       1264099069
# 92       1396387127       1322866505       1240613620       1059633675
# 93        271857970        259091970        244016173        214072421
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 41       1153704252        982372466        822534450     9706961
# 92        870452165        696828385        557501301     3287590
# 93        182159874        148177096        115228394     1904569
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 41           146.8933       1.0000                        17.88
# ...

# %%
InCh.T
# Out:
#                                      41          92         93
# Rank                                  1           2          4
# CCA3                                CHN         IND        IDN
# Country/Territory                 China       India  Indonesia
# Capital                         Beijing   New Delhi    Jakarta
# Continent                          Asia        Asia       Asia
# 2022 Population              1425887337  1417173173  275501339
# 2020 Population              1424929781  1396387127  271857970
# 2015 Population              1393715448  1322866505  259091970
# 2010 Population              1348191368  1240613620  244016173
# 2000 Population              1264099069  1059633675  214072421
# 1990 Population              1153704252   870452165  182159874
# 1980 Population               982372466   696828385  148177096
# 1970 Population               822534450   557501301  115228394
# Area (km²)                      9706961     3287590    1904569
# ...

# %%
InCh.T[5:13].plot()
plt.xticks(rotation=90)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.]),
#  [Text(-1.0, 0, '1970 Population'),
#   Text(0.0, 0, '2022 Population'),
#   Text(1.0, 0, '2020 Population'),
#   Text(2.0, 0, '2015 Population'),
#   Text(3.0, 0, '2010 Population'),
#   Text(4.0, 0, '2000 Population'),
#   Text(5.0, 0, '1990 Population'),
#   Text(6.0, 0, '1980 Population'),
#   Text(7.0, 0, '1970 Population'),
#   Text(8.0, 0, '')])

# %%
#Q8. Top 5 County of Asian continent where density is high
#Q9. Top 5 County worldwise where density is low.
world.sort_values('Growth Rate',ascending=False).head(10)
# Out:
#      Rank CCA3 Country/Territory     Capital Continent  2022 Population  \
# 133   135  MDA           Moldova    Chisinau    Europe          3272996
# 164    37  POL            Poland      Warsaw    Europe         39857145
# 148    54  NER             Niger      Niamey    Africa         26207977
# 202    60  SYR             Syria    Damascus      Asia         22125249
# 189   116  SVK          Slovakia  Bratislava    Europe          5643453
# 55     15  COD          DR Congo    Kinshasa    Africa         99010212
# 130   182  MYT           Mayotte   Mamoudzou    Africa           326101
# 39     69  TCD              Chad   N'Djamena    Africa         17723315
# 5      42  AGO            Angola      Luanda    Africa         35588987
# 124    59  MLI              Mali      Bamako    Africa         22593590
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 133          3084847          3277388          3678186          4251573
# ...

# %%
world[world['Continent']=='Asia'].sort_values('Density (per km²)',ascending=False).head(20)
# Out:
#      Rank CCA3 Country/Territory            Capital Continent  \
# 119   167  MAC             Macau  Concelho de Macau      Asia
# 187   113  SGP         Singapore          Singapore      Asia
# 89    104  HKG         Hong Kong          Hong Kong      Asia
# 15    154  BHR           Bahrain             Manama      Asia
# 123   174  MDV          Maldives               Malé      Asia
# 16      8  BGD        Bangladesh              Dhaka      Asia
# 158   122  PSE         Palestine           Ramallah      Asia
# 203    57  TWN            Taiwan             Taipei      Asia
# 112   119  LBN           Lebanon             Beirut      Asia
# 194    29  KOR       South Korea              Seoul      Asia
# 98     98  ISR            Israel          Jerusalem      Asia
# 92      2  IND             India          New Delhi      Asia
# 163    13  PHL       Philippines             Manila      Asia
# 197    61  LKA         Sri Lanka            Colombo      Asia
# ...

# %%
world.sort_values('Density (per km²)').head(10)
# Out:
#      Rank CCA3 Country/Territory      Capital      Continent  2022 Population  \
# 78    208  GRL         Greenland         Nuuk  North America            56466
# 64    231  FLK  Falkland Islands      Stanley  South America             3780
# 230   172  ESH    Western Sahara     El Aaiún         Africa           575986
# 135   134  MNG          Mongolia  Ulaanbaatar           Asia          3398366
# 141   145  NAM           Namibia     Windhoek         Africa          2567012
# 11     55  AUS         Australia     Canberra        Oceania         26177413
# 91    179  ISL           Iceland    Reykjavík         Europe           372899
# 69    184  GUF     French Guiana      Cayenne  South America           304557
# 86    164  GUY            Guyana   Georgetown  South America           808726
# 199   170  SUR          Suriname   Paramaribo  South America           618040
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
world.pivot_table(index='Continent', columns=['Country/Territory'], aggfunc={'Density (per km²)':np.min,
                                                                            'Area (km²)':np.min})
# Out:
#                    Area (km²)                                             \
# Country/Territory Afghanistan  Albania    Algeria American Samoa Andorra
# Continent
# Africa                    NaN      NaN  2381741.0            NaN     NaN
# Asia                 652230.0      NaN        NaN            NaN     NaN
# Europe                    NaN  28748.0        NaN            NaN   468.0
# North America             NaN      NaN        NaN            NaN     NaN
# Oceania                   NaN      NaN        NaN          199.0     NaN
# South America             NaN      NaN        NaN            NaN     NaN
#
#                                                                                \
# Country/Territory     Angola Anguilla Antigua and Barbuda  Argentina  Armenia
# Continent
# Africa             1246700.0      NaN                 NaN        NaN      NaN
# Asia                     NaN      NaN                 NaN        NaN  29743.0
# ...

# %%
plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.bar(temp['Continent'],temp['2022 Population'])
plt.xticks(rotation=45)

plt.subplot(2,2,3)
plt.bar(temp['Continent'],temp['2022 Population'])
plt.xticks(rotation=45)

plt.subplot(2,2,(2,4))
plt.pie(temp['2022 Population'], labels=temp['Continent'], autopct='%0.2f%%')
plt.xticks(rotation=45)


plt.tight_layout()
