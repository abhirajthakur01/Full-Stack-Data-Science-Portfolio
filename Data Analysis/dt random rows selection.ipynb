# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('nba.csv')

# %%
df.shape
# Out:
# (458, 9)

# %%
df.sample()
# Out:
#               Name             Team  Number Position   Age Height  Weight  \
# 224  Miles Plumlee  Milwaukee Bucks    18.0        C  27.0   6-11   249.0
#
#     College     Salary
# 224    Duke  2109294.0

# %%
df.sample(25)
# Out:
#                        Name                    Team  Number Position   Age  \
# 326         Jorge Gutierrez       Charlotte Hornets    12.0       PG  27.0
# 442           Trevor Booker               Utah Jazz    33.0       PF  28.0
# 239           Dwight Powell        Dallas Mavericks     7.0       PF  24.0
# 198             Monta Ellis          Indiana Pacers    11.0       SG  30.0
# 16             Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 441             Noah Vonleh  Portland Trail Blazers    21.0       PF  20.0
# 168            Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0
# 354          Dewayne Dedmon           Orlando Magic     3.0        C  26.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 40       Kristaps Porzingis         New York Knicks     6.0       PF  20.0
# 151        Cameron Bairstow           Chicago Bulls    41.0       PF  25.0
# ...

# %%
df.sample(n=25)
# Out:
#                  Name                   Team  Number Position   Age Height  \
# 137    James Anderson       Sacramento Kings     5.0       SG  27.0    6-6
# 302  Boban Marjanovic      San Antonio Spurs    40.0        C  27.0    7-3
# 361    Shabazz Napier          Orlando Magic    13.0       PG  24.0    6-1
# 356      Aaron Gordon          Orlando Magic     0.0       PF  20.0    6-9
# 210         Joe Young         Indiana Pacers     1.0       PG  23.0    6-2
# 19       Jarrett Jack          Brooklyn Nets     2.0       PG  32.0    6-3
# 368     Alan Anderson     Washington Wizards     6.0       SG  33.0    6-6
# 154     Mike Dunleavy          Chicago Bulls    34.0       SG  35.0    6-9
# 393   Emmanuel Mudiay         Denver Nuggets     0.0       PG  20.0    6-5
# 145        Duje Dukan       Sacramento Kings    26.0       PF  24.0    6-9
# 322    Walter Tavares          Atlanta Hawks    22.0        C  24.0    7-3
# ...

# %%
df.sample(frac=0.5)
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 201      Jordan Hill       Indiana Pacers    27.0        C  28.0   6-10
# 2       John Holland       Boston Celtics    30.0       SG  27.0    6-5
# 385      Will Barton       Denver Nuggets     5.0       SF  25.0    6-6
# 176   Timofey Mozgov  Cleveland Cavaliers    20.0        C  29.0    7-1
# 383   Darrell Arthur       Denver Nuggets     0.0       PF  28.0    6-9
# ..               ...                  ...     ...      ...   ...    ...
# 198      Monta Ellis       Indiana Pacers    11.0       SG  30.0    6-3
# 12       Evan Turner       Boston Celtics    11.0       SG  27.0    6-7
# 227  Justin Anderson     Dallas Mavericks     1.0       SG  22.0    6-6
# 446   Derrick Favors            Utah Jazz    15.0       PF  24.0   6-10
# 390     Nikola Jokic       Denver Nuggets    15.0        C  21.0   6-10
#
#      Weight            College      Salary
# 201   235.0            Arizona   4000000.0
# ...

# %%
df1 = df.sample(frac=.7)

df1.sample(frac=.50)
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 75        Delon Wright         Toronto Raptors    55.0       PG  24.0    6-5
# 409         Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 335         Jeremy Lin       Charlotte Hornets     7.0       PG  27.0    6-3
# 251      Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 143   DeMarcus Cousins        Sacramento Kings    15.0        C  25.0   6-11
# ..                 ...                     ...     ...      ...   ...    ...
# 295      Kyle Anderson       San Antonio Spurs     1.0       SF  22.0    6-9
# 412       Steven Adams   Oklahoma City Thunder    12.0        C  22.0    7-0
# 88   Marreese Speights   Golden State Warriors     5.0        C  28.0   6-10
# 214   Jared Cunningham         Milwaukee Bucks     9.0       SG  25.0    6-4
# 169       LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
#
#      Weight       College      Salary
# ...

# %%
df.sample(n=458, replace=False)
# Out:
#                   Name                    Team  Number Position   Age Height  \
# 226      Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 327   Tyler Hansbrough       Charlotte Hornets    50.0       PF  30.0    6-9
# 443         Trey Burke               Utah Jazz     3.0       PG  23.0    6-1
# 14        Tyler Zeller          Boston Celtics    44.0        C  26.0    7-0
# 258         Tony Allen       Memphis Grizzlies     9.0       SG  34.0    6-4
# ..                 ...                     ...     ...      ...   ...    ...
# 321     Tiago Splitter           Atlanta Hawks    11.0        C  31.0   6-11
# 429    Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0    6-5
# 294  LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0   6-11
# 402        Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 328     Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
#
#      Weight         College      Salary
# ...

# %%
df.sample(n=500, replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.sample(n=500, replace=False)
#
# File ~\myenv\Lib\site-packages\pandas\core\generic.py:6118, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6115 if weights is not None:
#    6116     weights = sample.preprocess_weights(self, weights, axis)
# -> 6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#
# File ~\myenv\Lib\site-packages\pandas\core\sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# ...

# %%
df.sample(n=500, replace=True)
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 285        Tyreke Evans    New Orleans Pelicans     1.0       SG  26.0    6-6
# 296         Matt Bonner       San Antonio Spurs    15.0        C  36.0   6-10
# 305         Patty Mills       San Antonio Spurs     8.0       PG  27.0    6-0
# 273      Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 136          Quincy Acy        Sacramento Kings    13.0       SF  25.0    6-7
# ..                  ...                     ...     ...      ...   ...    ...
# 320     Thabo Sefolosha           Atlanta Hawks    25.0       SF  32.0    6-7
# 30        Arron Afflalo         New York Knicks     4.0       SG  30.0    6-5
# 206  Glenn Robinson III          Indiana Pacers    40.0       SG  22.0    6-7
# 320     Thabo Sefolosha           Atlanta Hawks    25.0       SF  32.0    6-7
# 410  Karl-Anthony Towns  Minnesota Timberwolves    32.0        C  20.0    7-0
#
# ...

# %%
df.sample(n=4,axis=0)
# Out:
#                    Name                Team  Number Position   Age Height  \
# 388    Danilo Gallinari      Denver Nuggets     8.0       SF  27.0   6-10
# 206  Glenn Robinson III      Indiana Pacers    40.0       SG  22.0    6-7
# 375        Nene Hilario  Washington Wizards    42.0        C  33.0   6-11
# 272    Lance Stephenson   Memphis Grizzlies     1.0       SF  25.0    6-5
#
#      Weight     College      Salary
# 388   225.0         NaN  14000000.0
# 206   222.0    Michigan   1100000.0
# 375   250.0         NaN  13000000.0
# 272   230.0  Cincinnati   9000000.0

# %%
df.sample(n=4,axis=1)
# Out:
#                Team     Salary Height  Weight
# 0    Boston Celtics  7730337.0    6-2   180.0
# 1    Boston Celtics  6796117.0    6-6   235.0
# 2    Boston Celtics        NaN    6-5   205.0
# 3    Boston Celtics  1148640.0    6-5   185.0
# 4    Boston Celtics  5000000.0   6-10   231.0
# ..              ...        ...    ...     ...
# 453       Utah Jazz  2433333.0    6-3   203.0
# 454       Utah Jazz   900000.0    6-1   179.0
# 455       Utah Jazz  2900000.0    7-3   256.0
# 456       Utah Jazz   947276.0    7-0   231.0
# 457             NaN        NaN    NaN     NaN
#
# [458 rows x 4 columns]

# %%
df.sample(n=10, random_state=2)
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 117     Robert Sacre    Los Angeles Lakers    50.0        C  27.0    7-0
# 281    Anthony Davis  New Orleans Pelicans    23.0       PF  23.0   6-10
# 372      Drew Gooden    Washington Wizards    90.0       PF  34.0   6-10
# 20    Sergey Karasev         Brooklyn Nets    10.0       SG  22.0    6-7
# 221      Steve Novak       Milwaukee Bucks     6.0       SF  32.0   6-10
# 266   JaMychal Green     Memphis Grizzlies     0.0       PF  25.0    6-9
# 227  Justin Anderson      Dallas Mavericks     1.0       SG  22.0    6-6
# 231     Devin Harris      Dallas Mavericks    34.0       PG  33.0    6-3
# 142  Darren Collison      Sacramento Kings     7.0       PG  28.0    6-0
# 230   Raymond Felton      Dallas Mavericks     2.0       PG  31.0    6-1
#
#      Weight         College     Salary
# 117   270.0         Gonzaga   981348.0
# 281   253.0        Kentucky  7070730.0
# 372   250.0          Kansas  3300000.0
# ...

# %%
data = {'Name': ['Jai','Princi','Gaurav','Anuj','Geeku'],
        'Age': [27,24,22,32,15],
        'Address':['Delhi','Kanpur','Allahabad','Kannauj','Noida'],
        'Qualification':['Msc','MA','MCA','Phd','10th']}

df = pd.DataFrame(data)
print(df)

chosen_idx = np.random.choice(4, replace=True,size=6)
print(chosen_idx)
df2 = df.iloc[chosen_idx]
df
