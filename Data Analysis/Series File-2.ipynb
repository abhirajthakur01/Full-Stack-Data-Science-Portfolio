# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("nba.csv")

# %%
data.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.Age.value_counts()
# Out:
# Age
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 30.0    31
# 28.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 21.0    19
# 20.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 19.0     2
# 39.0     2
# Name: count, dtype: int64

# %%
data.Age.hist()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data.Age.hist()
#
# File ~\myenv\Lib\site-packages\pandas\plotting\_core.py:128, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      47 def hist_series(
#      48     self: Series,
#      49     by=None,
#    (...)
#      60     **kwargs,
#      61 ):
#      62     """
#      63     Draw histogram of the input series using matplotlib.
#      64
#    (...)
#     126         >>> hist = ser.groupby(level=0).hist()
#     127     """
# --> 128     plot_backend = _get_plot_backend(backend)
#     129     return plot_backend.hist_series(
#     130         self,
#     131         by=by,
#    (...)
#     141         **kwargs,
#     142     )
#
# File ~\myenv\Lib\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~\myenv\Lib\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
data[:2]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
data[2:]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# 2    Boston University         NaN
# 3        Georgia State   1148640.0
# 4                  NaN   5000000.0
# 5                  NaN  12000000.0
# 6                  LSU   1170960.0
# ..                 ...         ...
# 453             Butler   2433333.0
# 454                NaN    900000.0
# 455                NaN   2900000.0
# 456             Kansas    947276.0
# 457                NaN         NaN
#
# [456 rows x 9 columns]

# %%
data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
data.tail(2)
# Out:
#             Name       Team  Number Position   Age Height  Weight College  \
# 456  Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457          NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#        Salary
# 456  947276.0
# 457       NaN

# %%
data[-3:]
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
ser = pd.Series(data.Name)

# %%
data.Name.head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
ser.head()
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
ser[:2]
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# Name: Name, dtype: object

# %%
ser[0]
# Out:
# 'Avery Bradley'

# %%
ser[[0,3,30]]
# Out:
# 0     Avery Bradley
# 3       R.J. Hunter
# 30    Arron Afflalo
# Name: Name, dtype: object

# %%
ser[::-1]
# Out:
# 457              NaN
# 456      Jeff Withey
# 455     Tibor Pleiss
# 454        Raul Neto
# 453     Shelvin Mack
#            ...
# 4      Jonas Jerebko
# 3        R.J. Hunter
# 2       John Holland
# 1        Jae Crowder
# 0      Avery Bradley
# Name: Name, Length: 458, dtype: object

# %%
ser[[1,0,4]]
# Out:
# 1      Jae Crowder
# 0    Avery Bradley
# 4    Jonas Jerebko
# Name: Name, dtype: object

# %%
ser
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
ser.at[456]
# Out:
# 'Jeff Withey'

# %%
ser[456]
# Out:
# 'Jeff Withey'

# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the Series 
sr = pd.Series(['New York', 'Chicago', 'Toronto', 'Lisbon']) 
  
# Creating the row axis labels 
sr.index = ['City 1', 'City 2', 'City 3', 'City 4']  
  
# Print the series 
print(sr)
# Out:
# City 1    New York
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# dtype: object

# %%
sr['City 1':'City 4']
# Out:
# City 1    New York
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# dtype: object

# %%
sr.iloc[[1,3]]
# Out:
# City 2    Chicago
# City 4     Lisbon
# dtype: object

# %%
sr.at['City 1']
# Out:
# 'New York'

# %%
sr.iat[0]
# Out:
# 'New York'

# %%
sr.iat['City 2']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sr.iat['City 2']
#
# File ~\myenv\Lib\site-packages\pandas\core\indexing.py:2526, in _ScalarAccessIndexer.__getitem__(self, key)
#    2523     else:
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2526 key = self._convert_key(key)
#    2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\myenv\Lib\site-packages\pandas\core\indexing.py:2599, in _iAtIndexer._convert_key(self, key)
#    2597 for i in key:
#    2598     if not is_integer(i):
# -> 2599         raise ValueError("iAt based indexing can only have integer indexers")
#    2600 return key
#
# ValueError: iAt based indexing can only have integer indexers

# %%
sr.iat[3]
# Out:
# 'Lisbon'

# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the Series 
sr = pd.Series(['New York', 'Chicago', 'Toronto', 'Lisbon']) 
  
# Creating the row axis labels 
sr.index = ['City 1', 'City 2', 'City 3', 'City 4']  
  
# Print the series 
print(sr)
# Out:
# City 1    New York
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# dtype: object

# %%
# slice the object element in the  
# passed range 
sr.iloc[0:2]
# Out:
# City 1    New York
# City 2     Chicago
# dtype: object

# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the Series 
sr = pd.Series(['1/1/2018', '2/1/2018', '3/1/2018', '4/1/2018']) 
  
# Creating the row axis labels 
sr.index = ['Day 1', 'Day 2', 'Day 3', 'Day 4'] 
  
# Print the series 
print(sr)
# Out:
# Day 1    1/1/2018
# Day 2    2/1/2018
# Day 3    3/1/2018
# Day 4    4/1/2018
# dtype: object

# %%
# slice the object element in the  
# passed range 
sr.iloc[1:3]
# Out:
# Day 2    2/1/2018
# Day 3    3/1/2018
# dtype: object

# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the Series 
sr = pd.Series(['New York', 'Chicago', 'Toronto', 'Lisbon']) 
  
# Creating the row axis labels 
sr.index = ['City 1', 'City 2', 'City 3', 'City 4']  
  
# Print the series 
print(sr)
# Out:
# City 1    New York
# City 2     Chicago
# City 3     Toronto
# City 4      Lisbon
# dtype: object

# %%
# return the selected values. 
sr.loc[['City 4', 'City 3', 'City 1']]
# Out:
# City 4      Lisbon
# City 3     Toronto
# City 1    New York
# dtype: object

# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the Series 
sr = pd.Series(['1/1/2018', '2/1/2018', '3/1/2018', '4/1/2018']) 
  
# Creating the row axis labels 
sr.index = ['Day 1', 'Day 2', 'Day 3', 'Day 4'] 
  
# Print the series 
print(sr)
# Out:
# Day 1    1/1/2018
# Day 2    2/1/2018
# Day 3    3/1/2018
# Day 4    4/1/2018
# dtype: object

# %%
# return the selected values. 
sr.loc[['Day 4', 'Day 3', 'Day 1']]
# Out:
# Day 4    4/1/2018
# Day 3    3/1/2018
# Day 1    1/1/2018
# dtype: object

# %%
# importing pandas as pd 
import pandas as pd 
  
# Creating the first Series 
sr1 = pd.Series([80, 25, 3, 25, 24, 6]) 
  
# Creating the second Series 
sr2 = pd.Series([80, 25, 3, 25, 24, 6]) 
  
# Create the Index 
index_ = ['Coca Cola', 'Sprite', 'Coke', 'Fanta', 'Dew', 'ThumbsUp'] 
  
# set the first index 
sr1.index = index_ 
  
# set the second index 
sr2.index = index_ 
  
# Print the first series 
print(sr1) 
  
# Print the second series 
print(sr2)
# Out:
# Coca Cola    80
# Sprite       25
# Coke          3
# Fanta        25
# Dew          24
# ThumbsUp      6
# dtype: int64
# Coca Cola    80
# Sprite       25
# Coke          3
# Fanta        25
# Dew          24
# ThumbsUp      6
# dtype: int64

# %%
# find the correlation 
result = sr1.corr(sr2) 
  
# Print the result 
print(result)
# Out:
# 1.0

# %%
# making data frame  
data = pd.read_csv("nba.csv")  
    
# removing null values to avoid errors  
data.dropna(inplace = True)

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %%
data.Age.value_counts()
# Out:
# Age
# 25.0    41
# 24.0    41
# 27.0    35
# 23.0    33
# 26.0    32
# 28.0    27
# 22.0    23
# 30.0    20
# 31.0    17
# 29.0    17
# 20.0    15
# 21.0    14
# 32.0     9
# 36.0     9
# 33.0     8
# 35.0     7
# 34.0     7
# 38.0     3
# 19.0     2
# 40.0     2
# 37.0     1
# 39.0     1
# Name: count, dtype: int64

# %%
# lower value of range 
lower = 22
  
# upper value of range 
upper = 25
  
# passing values to new column 
data["New Age"]= data["Age"].clip(lower = lower, upper = upper) 
  
# display 
data[['Age','New Age']].head(50)
# Out:
#      Age  New Age
# 0   25.0     25.0
# 1   25.0     25.0
# 3   22.0     22.0
# 6   21.0     22.0
# 7   25.0     25.0
# 8   22.0     22.0
# 9   22.0     22.0
# 10  24.0     24.0
# 11  27.0     25.0
# 12  27.0     25.0
# 13  20.0     22.0
# 14  26.0     25.0
# 16  24.0     24.0
# 17  28.0     25.0
# 18  21.0     22.0
# 19  32.0     25.0
# 21  26.0     25.0
# 22  23.0     23.0
# 23  28.0     25.0
# 24  21.0     22.0
# 25  26.0     25.0
# 26  25.0     25.0
# 27  26.0     25.0
# 28  28.0     25.0
# 29  27.0     25.0
# 30  30.0     25.0
# 31  33.0     25.0
# 33  32.0     25.0
# 35  25.0     25.0
# 36  24.0     24.0
# 37  23.0     23.0
# 38  28.0     25.0
# 39  26.0     25.0
# 42  28.0     25.0
# 44  25.0     25.0
# 45  23.0     23.0
# 47  25.0     25.0
# 48  25.0     25.0
# 49  22.0     22.0
# 50  22.0     22.0
# 51  22.0     22.0
# 52  32.0     25.0
# 53  24.0     24.0
# 54  24.0     24.0
# 55  22.0     22.0
# 56  20.0     22.0
# 57  27.0     25.0
# 58  22.0     22.0
# 59  25.0     25.0
# 60  20.0     22.0

# %%
data['New Age'].value_counts()
# Out:
# New Age
# 25.0    236
# 22.0     54
# 24.0     41
# 23.0     33
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

# %%
# making data frame  
data = pd.read_csv("nba.csv")  
    
# removing null values to avoid errors  
data.dropna(inplace = True)  
  
# lower value of range 
lower = 22
  
# upper value of range 
upper = 25
  
# passing values to new column 
data["New Age"]= data["Age"].clip(lower = lower) 
  
# display 
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  New Age
# 0            Texas  7730337.0     25.0
# 1        Marquette  6796117.0     25.0
# 3    Georgia State  1148640.0     22.0
# 6              LSU  1170960.0     22.0
# 7          Gonzaga  2165160.0     25.0
# ..             ...        ...      ...
# 449           Duke  1348440.0     23.0
# 451         Dayton   981348.0     26.0
# 452       Kentucky  2239800.0     22.0
# 453         Butler  2433333.0     26.0
# 456         Kansas   947276.0     26.0
#
# [364 rows x 10 columns]

# %%
# making data frame  
data = pd.read_csv("nba.csv")  
    
# removing null values to avoid errors  
data.dropna(inplace = True)  
  
# lower value of range 
lower = 22
  
# upper value of range 
upper = 25
  
# passing values to new column 
data["New Age"]= data["Age"].clip(upper = upper) 
  
# display 
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  New Age
# 0            Texas  7730337.0     25.0
# 1        Marquette  6796117.0     25.0
# 3    Georgia State  1148640.0     22.0
# 6              LSU  1170960.0     21.0
# 7          Gonzaga  2165160.0     25.0
# ..             ...        ...      ...
# 449           Duke  1348440.0     23.0
# 451         Dayton   981348.0     25.0
# 452       Kentucky  2239800.0     20.0
# 453         Butler  2433333.0     25.0
# 456         Kansas   947276.0     25.0
#
# [364 rows x 10 columns]

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  New Age
# 0            Texas  7730337.0     25.0
# 1        Marquette  6796117.0     25.0
# 3    Georgia State  1148640.0     22.0
# 6              LSU  1170960.0     21.0
# 7          Gonzaga  2165160.0     25.0
# ..             ...        ...      ...
# 449           Duke  1348440.0     23.0
# 451         Dayton   981348.0     25.0
# 452       Kentucky  2239800.0     20.0
# 453         Butler  2433333.0     25.0
# 456         Kansas   947276.0     25.0
#
# [364 rows x 10 columns]

# %%
d1 = pd.Series(data['Team'])

# %%
d1.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
d1.value_counts()
# Out:
# Team
# New Orleans Pelicans      16
# Detroit Pistons           15
# Portland Trail Blazers    15
# Oklahoma City Thunder     14
# Los Angeles Clippers      14
# Philadelphia 76ers        14
# Milwaukee Bucks           14
# Memphis Grizzlies         13
# Washington Wizards        13
# Charlotte Hornets         13
# Phoenix Suns              13
# Sacramento Kings          13
# Brooklyn Nets             13
# Los Angeles Lakers        12
# Boston Celtics            12
# Golden State Warriors     12
# Chicago Bulls             12
# Indiana Pacers            12
# Dallas Mavericks          12
# Atlanta Hawks             11
# New York Knicks           11
# Cleveland Cavaliers       11
# Houston Rockets           11
# San Antonio Spurs         11
# Toronto Raptors           10
# Miami Heat                10
# Utah Jazz                 10
# Orlando Magic             10
# Denver Nuggets             9
# Minnesota Timberwolves     8
# Name: count, dtype: int64

# %%
d1.nunique()
# Out:
# 30

# %%
d1.value_counts()
# Out:
# Team
# New Orleans Pelicans      16
# Detroit Pistons           15
# Portland Trail Blazers    15
# Oklahoma City Thunder     14
# Los Angeles Clippers      14
# Philadelphia 76ers        14
# Milwaukee Bucks           14
# Memphis Grizzlies         13
# Washington Wizards        13
# Charlotte Hornets         13
# Phoenix Suns              13
# Sacramento Kings          13
# Brooklyn Nets             13
# Los Angeles Lakers        12
# Boston Celtics            12
# Golden State Warriors     12
# Chicago Bulls             12
# Indiana Pacers            12
# Dallas Mavericks          12
# Atlanta Hawks             11
# New York Knicks           11
# Cleveland Cavaliers       11
# Houston Rockets           11
# San Antonio Spurs         11
# Toronto Raptors           10
# Miami Heat                10
# Utah Jazz                 10
# Orlando Magic             10
# Denver Nuggets             9
# Minnesota Timberwolves     8
# Name: count, dtype: int64

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary  New Age
# 0            Texas  7730337.0     25.0
# 1        Marquette  6796117.0     25.0
# 3    Georgia State  1148640.0     22.0
# 6              LSU  1170960.0     21.0
# 7          Gonzaga  2165160.0     25.0
# ..             ...        ...      ...
# 449           Duke  1348440.0     23.0
# 451         Dayton   981348.0     25.0
# 452       Kentucky  2239800.0     20.0
# 453         Butler  2433333.0     25.0
# 456         Kansas   947276.0     25.0
#
# [364 rows x 10 columns]

# %%
d2 = pd.Series(data['Age'])

# %%
d2
# Out:
# 0      25.0
# 1      25.0
# 3      22.0
# 6      21.0
# 7      25.0
#        ...
# 449    23.0
# 451    26.0
# 452    20.0
# 453    26.0
# 456    26.0
# Name: Age, Length: 364, dtype: float64

# %%
d2.between(20,25).sum()
# Out:
# np.int64(167)

# %%
data2 = data['Age']

# %%
data2
# Out:
# 0      25.0
# 1      25.0
# 3      22.0
# 6      21.0
# 7      25.0
#        ...
# 449    23.0
# 451    26.0
# 452    20.0
# 453    26.0
# 456    26.0
# Name: Age, Length: 364, dtype: float64

# %%
data2[data2>25]
# Out:
# 11     27.0
# 12     27.0
# 14     26.0
# 17     28.0
# 19     32.0
#        ...
# 442    28.0
# 448    26.0
# 451    26.0
# 453    26.0
# 456    26.0
# Name: Age, Length: 195, dtype: float64

# %%
data2[data2>25].value_counts().sum()
# Out:
# np.int64(195)

# %%
data2[data2>25].sum()
# Out:
# np.float64(5782.0)
