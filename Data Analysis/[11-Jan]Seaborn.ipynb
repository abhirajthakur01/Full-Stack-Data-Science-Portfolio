# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips= sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.groupby('smoker')['smoker'].count()
# Out:
# smoker
# Yes     93
# No     151
# Name: smoker, dtype: int64

# %%
sns.scatterplot(x='total_bill', y='tip', data= tips)
plt.title('Total_bill vs Tips')
# Out:
# Text(0.5, 1.0, 'Total_bill vs Tips')

# %%
sns.relplot(x='total_bill', y='tip', data= tips)

# %%
sns.set_theme(style='darkgrid')

# %%
sns.relplot(x='total_bill', y='tip', data= tips, kind='scatter')

# %%
sns.relplot(tips['total_bill'], tips['tip'], kind = 'scatter')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 sns.relplot(tips['total_bill'], tips['tip'], kind = 'scatter')
#
# TypeError: relplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
sns.relplot(x=tips['total_bill'],y=tips['tip'])

# %%
sns.relplot(x='total_bill',y='tip', data=tips, hue='sex')

# %%
sns.relplot(x='total_bill',y='tip', data=tips, hue='smoker', style='smoker')

# %%
sns.relplot(x='total_bill',y='tip', data=tips, hue='sex', style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',row='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size = 'size',sizes=(15,200),col='time',hue='sex')

# %%
sns.relplot(x='total_bill',y='tip', hue='smoker',col='time',row='day', data=tips)

# %%
dowjones = sns.load_dataset('dowjones')

# %%
sns.lineplot(x='Date',y='Price', data=dowjones)
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.relplot(x='Date',y='Price', data=dowjones)

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm',hue='sex',col='time')

# %%
sns.catplot(x='day',y='total_bill',data=tips)

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='strip',hue='sex',col='time')

# %%
sns.stripplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='strip',hue='sex',col='time')

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm',hue='sex',col='time')

# %%
sns.swarmplot(x='day', y='total_bill',data=tips,dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill',data=tips,dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill',data=tips,dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill',data=tips,dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x='smoker',y='tip')

# %%
sns.catplot(data=tips, x='smoker',y='tip',order=['No','Yes'])

# %%
diamonds = sns.load_dataset('diamonds')

# %%
sns.histplot(tips['tip'],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['total_bill'],kde=True,bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x='sex',y='tip',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,kind='hex', cmap="YlGnBu")

# %%
sns.pairplot(data=tips)

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(data=tips, x='day', y='total_bill', hue='sex')
plt.legend(loc='upper left')

# %% [markdown]
#  # Boxplot

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='box')

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', kind='box')

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', kind='box', col='time')

# %%
diamonds = sns.load_dataset('diamonds')

# %%
sns.catplot(data=diamonds, x='color', y='price')

# %%
sns.catplot(data=diamonds, x='color', y='price', kind='box')

# %%
sns.catplot(data=diamonds, x='color', y='price', kind='boxen')

# %%
sns.catplot( data=tips, x="day", y="total_bill", hue="sex", kind="violin")
