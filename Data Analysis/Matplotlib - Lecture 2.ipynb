# 11 2024-02-21  38483.66  38618.03  38338.58  38612.24
# 10 2024-02-22  38845.19  39149.61  38802.07  39069.11
# 9  2024-02-23  39127.97  39282.28  39094.36  39131.53
# 8  2024-02-26  39144.79  39245.89  39025.80  39069.23
# 7  2024-02-27  39087.90  39087.90  38881.90  38972.41
# 6  2024-02-28  38938.08  38956.46  38741.68  38949.02
# 5  2024-02-29  39013.75  39074.13  38809.28  38996.39
# 4  2024-03-01  38989.51  39120.36  38850.50  39087.38
# 3  2024-03-04  38968.77  39087.86  38913.30  38989.83
# 2  2024-03-05  38906.98  38906.98  38457.83  38585.19
# 1  2024-03-06  38721.15  38858.13  38570.80  38661.05
# 0  2024-03-07  38784.30  38910.35  38730.13  38791.35

# %%
df.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close'], dtype='object')

# %%
date1 = df.Date
high1 = df[' High']

# %%
date1
# Out:
# 59   2023-12-11
# 58   2023-12-12
# 57   2023-12-13
# 56   2023-12-14
# 55   2023-12-15
# 54   2023-12-18
# 53   2023-12-19
# 52   2023-12-20
# 51   2023-12-21
# 50   2023-12-22
# 49   2023-12-26
# 48   2023-12-27
# 47   2023-12-28
# 46   2023-12-29
# 45   2024-01-02
# 44   2024-01-03
# 43   2024-01-04
# 42   2024-01-05
# 41   2024-01-08
# 40   2024-01-09
# 39   2024-01-10
# 38   2024-01-11
# 37   2024-01-12
# 36   2024-01-16
# 35   2024-01-17
# 34   2024-01-18
# 33   2024-01-19
# 32   2024-01-22
# 31   2024-01-23
# 30   2024-01-24
# 29   2024-01-25
# 28   2024-01-26
# 27   2024-01-29
# 26   2024-01-30
# 25   2024-01-31
# 24   2024-02-01
# 23   2024-02-02
# 22   2024-02-05
# 21   2024-02-06
# 20   2024-02-07
# 19   2024-02-08
# 18   2024-02-09
# 17   2024-02-12
# 16   2024-02-13
# 15   2024-02-14
# 14   2024-02-15
# 13   2024-02-16
# 12   2024-02-20
# 11   2024-02-21
# 10   2024-02-22
# 9    2024-02-23
# 8    2024-02-26
# 7    2024-02-27
# 6    2024-02-28
# 5    2024-02-29
# 4    2024-03-01
# 3    2024-03-04
# 2    2024-03-05
# 1    2024-03-06
# 0    2024-03-07
# Name: Date, dtype: datetime64[ns]

# %%
plt.plot(date1,high1)

# %%
plt.plot(df['Date'], df[' High'])
plt.xticks(rotation=45)
# Out:
# (array([19706., 19723., 19737., 19754., 19768., 19783.]),
#  [Text(19706.0, 0, '2023-12-15'),
#   Text(19723.0, 0, '2024-01-01'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19783.0, 0, '2024-03-01')])

# %%
# Method1
plt.plot(df['Date'].values, df[' High'].values)

# %%
# Method2
plt.figure(figsize=(15,6))
plt.plot(df['Date'].to_numpy(), df[' High'].to_numpy())
plt.xticks(rotation=45)
# Out:
# (array([19706., 19723., 19737., 19754., 19768., 19783.]),
#  [Text(19706.0, 0, '2023-12-15'),
#   Text(19723.0, 0, '2024-01-01'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19783.0, 0, '2024-03-01')])

# %%
df.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close'], dtype='object')

# %%
plt.figure(figsize=(15,6))
plt.plot(df['Date'].to_numpy(), df[' High'].to_numpy(),label='High')
plt.plot(df['Date'].to_numpy(), df[' Low'].to_numpy(), label='Low')
plt.plot(df['Date'].to_numpy(), df[' Open'].to_numpy(),label='Open')
plt.plot(df['Date'].to_numpy(), df[' Close'].to_numpy(), label='Close')
plt.legend(['high','low','open','close'])
#plt.plot(df['Date'].to_numpy(), df[' High'].to_numpy())
plt.xticks(rotation=45)
# Out:
# (array([19706., 19723., 19737., 19754., 19768., 19783.]),
#  [Text(19706.0, 0, '2023-12-15'),
#   Text(19723.0, 0, '2024-01-01'),
#   Text(19737.0, 0, '2024-01-15'),
#   Text(19754.0, 0, '2024-02-01'),
#   Text(19768.0, 0, '2024-02-15'),
#   Text(19783.0, 0, '2024-03-01')])

# %%
df.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close'], dtype='object')
