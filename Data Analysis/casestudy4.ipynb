# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('RS_Session_246_AU_76_1.1.csv')

# %%
df
# Out:
#              Category                 States/UTs  Total No. of Jails  \
# 0               State             Andhra Pradesh                 112
# 1               State          Arunachal Pradesh                   2
# 2               State                      Assam                  31
# 3               State                      Bihar                  58
# 4               State               Chhattisgarh                  28
# 5               State                        Goa                   2
# 6               State                    Gujarat                  27
# 7               State                    Haryana                  19
# 8               State           Himachal Pradesh                  14
# 9               State            Jammu & Kashmir                  14
# 10              State                  Jharkhand                  29
# 11              State                  Karnataka                 102
# 12              State                     Kerala                  54
# ...

# %%
df.shape
# Out:
# (39, 12)

# %%
df.columns
# Out:
# Index(['Category', 'States/UTs', 'Total No. of Jails',
#        'Available Capacity - Male', 'Available Capacity - Female',
#        'Available Capacity - Total', 'Inmate Population - Male',
#        'Inmate Population - Female', 'Inmate Population - Total',
#        'Occupancy Rate (in %) - Male', 'Occupancy Rate (in %) - Female',
#        'Occupancy Rate (in %) - Total'],
#       dtype='object')

# %%
df1 =df.sort_values('Total No. of Jails', ascending=False).head(10)

# %%
def addvalue(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])


plt.bar(df1['States/UTs'],df1['Total No. of Jails'])
plt.xticks(rotation=45)


l1 = df1['States/UTs']
l2 = df1['Total No. of Jails']

addvalue(df1['States/UTs'],df1['Total No. of Jails'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
