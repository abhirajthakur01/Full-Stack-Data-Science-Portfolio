# %%
import numpy as np 
import pandas as pd

# %%
df1 = pd.read_csv('Example1.csv')

# %%
df1.head()
# Out:
#   IMPDS Deduplication     Unnamed: 1               Unnamed: 2  \
# 0               S.No.  District Name  Total Duplicate Records
# 1                   1     AGAR MALWA                      997
# 2                   2      ALIRAJPUR                      492
# 3                   3        ANUPPUR                     2077
# 4                   4     ASHOKNAGAR                      336
#
#            Unnamed: 3                            Unnamed: 4
# 0  Total Field Survey  Recommended for Cancellation/Blocked
# 1                 961                                    35
# 2                 480                                    17
# 3                1981                                   165
# 4                 335                                    89

# %%
df2 = pd.read_csv('Example2.csv')

# %%
df2.head()
# Out:
#                              IMPDS Deduplication::::
# 0  S.No.:District Name:Total Duplicate Records:To...
# 1                            1:AGAR MALWA:997:961:35
# 2                             2:ALIRAJPUR:492:480:17
# 3                            3:ANUPPUR:2077:1981:165
# 4                            4:ASHOKNAGAR:336:335:89

# %%
df3 = pd.read_csv('Example2.csv', sep=':')

# %%
df3.head()
# Out:
#   IMPDS Deduplication     Unnamed: 1               Unnamed: 2  \
# 0               S.No.  District Name  Total Duplicate Records
# 1                   1     AGAR MALWA                      997
# 2                   2      ALIRAJPUR                      492
# 3                   3        ANUPPUR                     2077
# 4                   4     ASHOKNAGAR                      336
#
#            Unnamed: 3                            Unnamed: 4
# 0  Total Field Survey  Recommended for Cancellation/Blocked
# 1                 961                                    35
# 2                 480                                    17
# 3                1981                                   165
# 4                 335                                    89

# %%
df4 = pd.read_csv('Example2.csv', sep=':', header=1)

# %%
df4.head()
# Out:
#    S.No. District Name  Total Duplicate Records  Total Field Survey  \
# 0      1    AGAR MALWA                      997                 961
# 1      2     ALIRAJPUR                      492                 480
# 2      3       ANUPPUR                     2077                1981
# 3      4    ASHOKNAGAR                      336                 335
# 4      5      BALAGHAT                     5285                5246
#
#    Recommended for Cancellation/Blocked
# 0                                    35
# 1                                    17
# 2                                   165
# 3                                    89
# 4                                   284

# %%
df5 = pd.read_csv('Example2.csv', sep=':', header=1,nrows=7)

# %%
df5
# Out:
#    S.No. District Name  Total Duplicate Records  Total Field Survey  \
# 0      1    AGAR MALWA                      997                 961
# 1      2     ALIRAJPUR                      492                 480
# 2      3       ANUPPUR                     2077                1981
# 3      4    ASHOKNAGAR                      336                 335
# 4      5      BALAGHAT                     5285                5246
# 5      6       BARWANI                     2360                2353
# 6      7         BETUL                     1809                1770
#
#    Recommended for Cancellation/Blocked
# 0                                    35
# 1                                    17
# 2                                   165
# 3                                    89
# 4                                   284
# 5                                   201
# 6                                    32

# %%
df6 = pd.read_csv('Example2.csv', sep=':', header=1,nrows=7, usecols=[0,2,4])

# %%
df6
# Out:
#    S.No.  Total Duplicate Records  Recommended for Cancellation/Blocked
# 0      1                      997                                    35
# 1      2                      492                                    17
# 2      3                     2077                                   165
# 3      4                      336                                    89
# 4      5                     5285                                   284
# 5      6                     2360                                   201
# 6      7                     1809                                    32

# %%
df6 = pd.read_csv('Example2.csv', sep=':', header=1,nrows=7, usecols=[1,3])

# %%
df6
# Out:
#   District Name  Total Field Survey
# 0    AGAR MALWA                 961
# 1     ALIRAJPUR                 480
# 2       ANUPPUR                1981
# 3    ASHOKNAGAR                 335
# 4      BALAGHAT                5246
# 5       BARWANI                2353
# 6         BETUL                1770

# %%
df5.columns
# Out:
# Index(['S.No.', 'District Name', 'Total Duplicate Records',
#        'Total Field Survey', 'Recommended for Cancellation/Blocked'],
#       dtype='object')

# %%
df7 = pd.read_csv('Example2.csv', sep=':', header=1,nrows=7, usecols=['District Name', 'Total Duplicate Records'])

# %%
df7
# Out:
#   District Name  Total Duplicate Records
# 0    AGAR MALWA                      997
# 1     ALIRAJPUR                      492
# 2       ANUPPUR                     2077
# 3    ASHOKNAGAR                      336
# 4      BALAGHAT                     5285
# 5       BARWANI                     2360
# 6         BETUL                     1809

# %%
df8 = pd.read_csv('Example2.csv', sep=':', header=1,nrows=7, index_col=[0])

# %%
df8.head()
# Out:
#       District Name  Total Duplicate Records  Total Field Survey  \
# S.No.
# 1        AGAR MALWA                      997                 961
# 2         ALIRAJPUR                      492                 480
# 3           ANUPPUR                     2077                1981
# 4        ASHOKNAGAR                      336                 335
# 5          BALAGHAT                     5285                5246
#
#        Recommended for Cancellation/Blocked
# S.No.
# 1                                        35
# 2                                        17
# 3                                       165
# 4                                        89
# 5                                       284

# %%
df9 = pd.read_csv('Example2.csv', sep=':', skiprows=5)

# %%
df9.head()
# Out:
#    4 ASHOKNAGAR   336   335   89
# 0  5   BALAGHAT  5285  5246  284
# 1  6    BARWANI  2360  2353  201
# 2  7      BETUL  1809  1770   32
# 3  8      BHIND   688   670  190
# 4  9     BHOPAL  3923  3867  721

# %%
df10 = pd.read_csv('Example2.csv', sep=':', header=1,nrows=7, index_col=[0], chunksize=10)

# %%
df10

# %%
df11 = pd.read_excel('ex2.xlsx')

# %%
df11.tail()
# Out:
#        Sno                Team Position            Name  Number   Age Height  \
# 145    145  Washington Wizards       PF     Drew Gooden      90    34   6-10
# 146    146  Washington Wizards       PG  Ramon Sessions       7    30    6-3
# 147    147  Washington Wizards       SF    Jared Dudley       1    30    6-7
# 148    148  Washington Wizards       SG   Alan Anderson       6    33    6-6
# 149  Total                 NaN      NaN             NaN    2601  4066      0
#
#      Weight         College     Salary
# 145   250.0          Kansas  3300000.0
# 146   190.0          Nevada  2170465.0
# 147   225.0  Boston College  4375000.0
# 148   220.0  Michigan State  4000000.0
# 149     NaN             NaN        NaN

# %%
df12 = pd.read_excel('ex2.xlsx', skipfooter=1)

# %%
df12.tail()
# Out:
#      Sno                Team Position            Name  Number  Age Height  \
# 144  144  Washington Wizards        C   Marcin Gortat      13   32   6-11
# 145  145  Washington Wizards       PF     Drew Gooden      90   34   6-10
# 146  146  Washington Wizards       PG  Ramon Sessions       7   30    6-3
# 147  147  Washington Wizards       SF    Jared Dudley       1   30    6-7
# 148  148  Washington Wizards       SG   Alan Anderson       6   33    6-6
#
#      Weight               College    Salary
# 144     240  North Carolina State  11217391
# 145     250                Kansas   3300000
# 146     190                Nevada   2170465
# 147     225        Boston College   4375000
# 148     220        Michigan State   4000000
