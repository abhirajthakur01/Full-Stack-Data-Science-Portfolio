# %%
#list is a collection of data type which can  mutable and ordered it is collection of homogeneous and heterogeneous data types
list = [1,2,3,4.5,'bhopal',4+4j]
print(list)
# Out:
# [1, 2, 3, 4.5, 'bhopal', (4+4j)]

# %%
list[3]
# Out:
# 'bhopal'

# %%
list[3:]
# Out:
# ['bhopal', (4+4j)]

# %%
list = [1,2,3,4.5,'bhopal',3+4j]
for i in list:
    print(i)
# Out:
# 1
# 2
# 3
# 4.5
# bhopal
# (3+4j)

# %%
list = [1,2,3,4.5,'bhopal',3+4j]
for i in list:
    if i ==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4.5
# bhopal
# (3+4j)

# %%
list = [1,2,3,4.5,'bhopal',3+4j]
for i in list:
    if i ==3+4j:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4.5
# bhopal

# %%
list = [1,2,3,4.5,'bhopal',3+4j]

# %%
list[4]
# Out:
# 'bhopal'

# %%
list[4][3]
# Out:
# 'p'

# %%
list.reverse()

# %%
list
# Out:
# [(3+4j), 'bhopal', 4.5, 3, 2, 1]

# %%
#Creating a list of numbers
numbers = [3, 7, 1, 5, 9]
numbers
# Out:
# [3, 7, 1, 5, 9]

# %%
#addind an elements to the list at end 
numbers.append(4)
print(numbers)
# Out:
# [3, 7, 1, 5, 9, 4, 4, 4, 4, 4]

# %%
numbers.insert(2,11)
print(numbers)
# Out:
# [3, 7, 11, 11, 1, 5, 9, 4, 4, 4, 4, 4]

# %%
numbers[2]=500
print(numbers)
# Out:
# [3, 7, 500, 11, 1, 5, 9, 4, 4, 4, 4, 4]
