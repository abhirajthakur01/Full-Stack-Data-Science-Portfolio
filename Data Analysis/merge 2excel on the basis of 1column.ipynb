# %%
import numpy as np
import pandas as pd

# %%
f1=pd.read_excel("Registration details.xlsx")
f2=pd.read_excel("exam results.xlsx")

# %%
f1.columns
# Out:
# Index(['ADMISSION DATE', 'NAME OF STUDENT ', 'GENDER', 'DOB',
#        'STUDENT EMAIL ID ', 'NO. OF ADMISIONS ', 'ENQUIRY NO.',
#        'REGISTRATION NO'],
#       dtype='object')

# %%
f2.columns
# Out:
# Index(['REGISTRATION NO', 'Name', 'No of questions Attempted ', 'Correct',
#        'Incorrect', 'Marks Obtained', 'Percentage'],
#       dtype='object')

# %%
f1.shape
# Out:
# (102, 8)

# %%
f2.shape
# Out:
# (32, 7)

# %%
f1.isna().sum()
# Out:
# ADMISSION DATE        88
# NAME OF STUDENT       83
# GENDER                83
# DOB                   88
# STUDENT EMAIL ID      88
# NO. OF ADMISIONS     102
# ENQUIRY NO.           88
# REGISTRATION NO       88
# dtype: int64

# %%
del f1['NO. OF ADMISIONS ']

# %%
f1.shape
# Out:
# (102, 7)

# %%
f1.dropna(inplace=True)

# %%
f1.isna().sum()
# Out:
# ADMISSION DATE       0
# NAME OF STUDENT      0
# GENDER               0
# DOB                  0
# STUDENT EMAIL ID     0
# ENQUIRY NO.          0
# REGISTRATION NO      0
# dtype: int64

# %%
f1.shape
# Out:
# (14, 7)

# %%
#merge two files - result consist all columns

# %%
result1 =pd.merge(f1,f2,on=['REGISTRATION NO'])

# %%
result1
# Out:
#    ADMISSION DATE   NAME OF STUDENT   GENDER        DOB   STUDENT EMAIL ID   \
# 0      2020-03-28      millind arora    MALE 1980-05-10  milind@example.com
# 1      2020-03-29           abhinav     MALE 1980-06-11  abhind@example.com
# 2      2020-03-29     rahul tripathi    MALE 1980-07-13  rahind@example.com
# 3      2020-03-29             sumit     MALE 1980-08-14  sumind@example.com
# 4      2020-03-29         amit saini    MALE 1980-09-15  amiind@example.com
# 5      2020-03-29    akanshsha sudan  FEMALE 1980-10-17  akaind@example.com
# 6      2020-03-29     abhishek kumar    MALE 1980-11-18  abhind@example.com
# 7      2020-03-30  yatharth aggarwal    MALE 1980-12-20  yatind@example.com
# 8      2020-03-30             yograj    MALE 1981-01-21  yogind@example.com
# 9      2020-03-30      parmeet kaur   FEMALE 1981-02-22  parind@example.com
# 10     2020-03-30             ankit     MALE 1981-03-26  ankind@example.com
# 11     2020-03-30       FAZAL ANSARI    MALE 1981-04-27  FAZind@example.com
# 12     2020-03-30             mayank    MALE 1981-05-29  mayind@example.com
# 13     2020-03-30             ronak     MALE 1981-06-30  ronind@example.com
#
#    ENQUIRY NO. REGISTRATION NO               Name  No of questions Attempted   \
# 0   EN10-05-80    RG10-05-1980      millind arora                          25
# 1   EN11-06-80    RG11-06-1980           abhinav                           25
# 2   EN13-07-80    RG13-07-1980     rahul tripathi                          25
# 3   EN14-08-80    RG14-08-1980             sumit                           25
# 4   EN15-09-80    RG15-09-1980         amit saini                          25
# 5   EN17-10-80    RG17-10-1980    akanshsha sudan                          25
# 6   EN18-11-80    RG18-11-1980     abhishek kumar                          25
# 7   EN20-12-80    RG20-12-1980  yatharth aggarwal                          25
# 8   EN21-01-81    RG21-01-1981             yograj                          25
# 9   EN22-02-81    RG22-02-1981      parmeet kaur                           25
# 10  EN26-03-81    RG26-03-1981             ankit                           25
# 11  EN27-04-81    RG27-04-1981       FAZAL ANSARI                          25
# 12  EN29-05-81    RG29-05-1981             mayank                          25
# 13  EN30-06-81    RG30-06-1981             ronak                           25
#
#     Correct  Incorrect  Marks Obtained  Percentage
# 0        25          0              50         100
# 1        25          0              50         100
# 2        25          0              50         100
# 3        24          1              48          96
# 4        24          1              48          96
# 5        24          1              48          96
# 6        23          2              46          92
# 7        23          2              46          92
# 8        23          2              46          92
# 9        22          3              44          88
# 10       22          3              44          88
# 11       22          3              44          88
# 12       22          3              44          88
# 13       22          3              44          88

# %%
result2 =pd.merge(f1,f2,on=['REGISTRATION NO'],how='left')
result2
# Out:
#    ADMISSION DATE   NAME OF STUDENT   GENDER        DOB   STUDENT EMAIL ID   \
# 0      2020-03-28      millind arora    MALE 1980-05-10  milind@example.com
# 1      2020-03-29           abhinav     MALE 1980-06-11  abhind@example.com
# 2      2020-03-29     rahul tripathi    MALE 1980-07-13  rahind@example.com
# 3      2020-03-29             sumit     MALE 1980-08-14  sumind@example.com
# 4      2020-03-29         amit saini    MALE 1980-09-15  amiind@example.com
# 5      2020-03-29    akanshsha sudan  FEMALE 1980-10-17  akaind@example.com
# 6      2020-03-29     abhishek kumar    MALE 1980-11-18  abhind@example.com
# 7      2020-03-30  yatharth aggarwal    MALE 1980-12-20  yatind@example.com
# 8      2020-03-30             yograj    MALE 1981-01-21  yogind@example.com
# 9      2020-03-30      parmeet kaur   FEMALE 1981-02-22  parind@example.com
# 10     2020-03-30             ankit     MALE 1981-03-26  ankind@example.com
# 11     2020-03-30       FAZAL ANSARI    MALE 1981-04-27  FAZind@example.com
# 12     2020-03-30             mayank    MALE 1981-05-29  mayind@example.com
# 13     2020-03-30             ronak     MALE 1981-06-30  ronind@example.com
#
#    ENQUIRY NO. REGISTRATION NO               Name  No of questions Attempted   \
# 0   EN10-05-80    RG10-05-1980      millind arora                          25
# 1   EN11-06-80    RG11-06-1980           abhinav                           25
# 2   EN13-07-80    RG13-07-1980     rahul tripathi                          25
# 3   EN14-08-80    RG14-08-1980             sumit                           25
# 4   EN15-09-80    RG15-09-1980         amit saini                          25
# 5   EN17-10-80    RG17-10-1980    akanshsha sudan                          25
# 6   EN18-11-80    RG18-11-1980     abhishek kumar                          25
# 7   EN20-12-80    RG20-12-1980  yatharth aggarwal                          25
# 8   EN21-01-81    RG21-01-1981             yograj                          25
# 9   EN22-02-81    RG22-02-1981      parmeet kaur                           25
# 10  EN26-03-81    RG26-03-1981             ankit                           25
# 11  EN27-04-81    RG27-04-1981       FAZAL ANSARI                          25
# 12  EN29-05-81    RG29-05-1981             mayank                          25
# 13  EN30-06-81    RG30-06-1981             ronak                           25
#
#     Correct  Incorrect  Marks Obtained  Percentage
# 0        25          0              50         100
# 1        25          0              50         100
# 2        25          0              50         100
# 3        24          1              48          96
# 4        24          1              48          96
# 5        24          1              48          96
# 6        23          2              46          92
# 7        23          2              46          92
# 8        23          2              46          92
# 9        22          3              44          88
# 10       22          3              44          88
# 11       22          3              44          88
# 12       22          3              44          88
# 13       22          3              44          88

# %%
result3 =pd.merge(f1,f2,on=['REGISTRATION NO'],how='right')
result3
# Out:
#    ADMISSION DATE   NAME OF STUDENT   GENDER        DOB   STUDENT EMAIL ID   \
# 0             NaT                NaN     NaN        NaT                 NaN
# 1      2020-03-29           abhinav     MALE 1980-06-11  abhind@example.com
# 2      2020-03-29     abhishek kumar    MALE 1980-11-18  abhind@example.com
# 3             NaT                NaN     NaN        NaT                 NaN
# 4      2020-03-29    akanshsha sudan  FEMALE 1980-10-17  akaind@example.com
# 5      2020-03-29         amit saini    MALE 1980-09-15  amiind@example.com
# 6      2020-03-30             ankit     MALE 1981-03-26  ankind@example.com
# 7             NaT                NaN     NaN        NaT                 NaN
# 8             NaT                NaN     NaN        NaT                 NaN
# 9      2020-03-30       FAZAL ANSARI    MALE 1981-04-27  FAZind@example.com
# 10            NaT                NaN     NaN        NaT                 NaN
# 11            NaT                NaN     NaN        NaT                 NaN
# 12            NaT                NaN     NaN        NaT                 NaN
# 13            NaT                NaN     NaN        NaT                 NaN
# 14     2020-03-30             mayank    MALE 1981-05-29  mayind@example.com
# 15            NaT                NaN     NaN        NaT                 NaN
# 16            NaT                NaN     NaN        NaT                 NaN
# 17     2020-03-28      millind arora    MALE 1980-05-10  milind@example.com
# 18            NaT                NaN     NaN        NaT                 NaN
# 19     2020-03-30      parmeet kaur   FEMALE 1981-02-22  parind@example.com
# 20            NaT                NaN     NaN        NaT                 NaN
# 21            NaT                NaN     NaN        NaT                 NaN
# 22     2020-03-29     rahul tripathi    MALE 1980-07-13  rahind@example.com
# 23     2020-03-30             ronak     MALE 1981-06-30  ronind@example.com
# 24            NaT                NaN     NaN        NaT                 NaN
# 25            NaT                NaN     NaN        NaT                 NaN
# 26            NaT                NaN     NaN        NaT                 NaN
# 27     2020-03-29             sumit     MALE 1980-08-14  sumind@example.com
# 28            NaT                NaN     NaN        NaT                 NaN
# 29     2020-03-30  yatharth aggarwal    MALE 1980-12-20  yatind@example.com
# 30            NaT                NaN     NaN        NaT                 NaN
# 31     2020-03-30             yograj    MALE 1981-01-21  yogind@example.com
#
#    ENQUIRY NO. REGISTRATION NO               Name  No of questions Attempted   \
# 0          NaN    RG30-06-1989            ABHINAV                          25
# 1   EN11-06-80    RG11-06-1980           abhinav                           25
# 2   EN18-11-80    RG18-11-1980     abhishek kumar                          25
# 3          NaN    RG30-06-1991  Agam Singh Talwar                          25
# 4   EN17-10-80    RG17-10-1980    akanshsha sudan                          25
# 5   EN15-09-80    RG15-09-1980         amit saini                          25
# 6   EN26-03-81    RG26-03-1981             ankit                           25
# 7          NaN    RG30-06-1987             Ankit                           25
# 8          NaN    RG30-06-1998          Divyanshi                          25
# 9   EN27-04-81    RG27-04-1981       FAZAL ANSARI                          25
# 10         NaN    RG30-06-1997       FAZAL ANSARI                          25
# 11         NaN    RG30-06-1986          Gursimran                          25
# 12         NaN    RG30-06-1988  Kanwal Jeet Singh                          25
# 13         NaN    RG30-06-1994       Manish Rawat                          25
# 14  EN29-05-81    RG29-05-1981             mayank                          25
# 15         NaN    RG30-06-1996             Mayank                          25
# 16         NaN    RG30-06-1999       Mehtab Kalra                          25
# 17  EN10-05-80    RG10-05-1980      millind arora                          25
# 18         NaN    RG30-06-1990      Nikita Grover                          24
# 19  EN22-02-81    RG22-02-1981      parmeet kaur                           25
# 20         NaN    RG30-06-1982   POOJA CHAURASIA                           25
# 21         NaN    RG30-06-1995       Rahul Sharma                          25
# 22  EN13-07-80    RG13-07-1980     rahul tripathi                          25
# 23  EN30-06-81    RG30-06-1981             ronak                           25
# 24         NaN    RG30-06-1985     Saurabh Sharma                          25
# 25         NaN    RG30-06-1983      Shubham Gupta                          25
# 26         NaN    RG30-06-1993              Sumit                          25
# 27  EN14-08-80    RG14-08-1980             sumit                           25
# 28         NaN    RG30-06-1992              Tanya                          25
# 29  EN20-12-80    RG20-12-1980  yatharth aggarwal                          25
# 30         NaN    RG30-06-1984  Yatharth Aggarwal                          25
# 31  EN21-01-81    RG21-01-1981             yograj                          25
#
#     Correct  Incorrect  Marks Obtained  Percentage
# 0        21          4              42          84
# 1        25          0              50         100
# 2        23          2              46          92
# 3        21          4              42          84
# 4        24          1              48          96
# 5        24          1              48          96
# 6        22          3              44          88
# 7        21          4              42          84
# 8        19          6              38          76
# 9        22          3              44          88
# 10       19          6              38          76
# 11       22          3              44          88
# 12       21          4              42          84
# 13       19          6              38          76
# 14       22          3              44          88
# 15       19          6              38          76
# 16       18          7              36          72
# 17       25          0              50         100
# 18       21          3              42          84
# 19       22          3              44          88
# 20       22          3              44          88
# 21       19          6              38          76
# 22       25          0              50         100
# 23       22          3              44          88
# 24       22          3              44          88
# 25       22          3              44          88
# 26       19          6              38          76
# 27       24          1              48          96
# 28       20          5              40          80
# 29       23          2              46          92
# 30       22          3              44          88
# 31       23          2              46          92

# %%
result4 =pd.merge(f1,f2,on=['REGISTRATION NO'],how='outer')
result4
# Out:
#    ADMISSION DATE   NAME OF STUDENT   GENDER        DOB   STUDENT EMAIL ID   \
# 0      2020-03-28      millind arora    MALE 1980-05-10  milind@example.com
# 1      2020-03-29           abhinav     MALE 1980-06-11  abhind@example.com
# 2      2020-03-29     rahul tripathi    MALE 1980-07-13  rahind@example.com
# 3      2020-03-29             sumit     MALE 1980-08-14  sumind@example.com
# 4      2020-03-29         amit saini    MALE 1980-09-15  amiind@example.com
# 5      2020-03-29    akanshsha sudan  FEMALE 1980-10-17  akaind@example.com
# 6      2020-03-29     abhishek kumar    MALE 1980-11-18  abhind@example.com
# 7      2020-03-30  yatharth aggarwal    MALE 1980-12-20  yatind@example.com
# 8      2020-03-30             yograj    MALE 1981-01-21  yogind@example.com
# 9      2020-03-30      parmeet kaur   FEMALE 1981-02-22  parind@example.com
# 10     2020-03-30             ankit     MALE 1981-03-26  ankind@example.com
# 11     2020-03-30       FAZAL ANSARI    MALE 1981-04-27  FAZind@example.com
# 12     2020-03-30             mayank    MALE 1981-05-29  mayind@example.com
# 13     2020-03-30             ronak     MALE 1981-06-30  ronind@example.com
# 14            NaT                NaN     NaN        NaT                 NaN
# 15            NaT                NaN     NaN        NaT                 NaN
# 16            NaT                NaN     NaN        NaT                 NaN
# 17            NaT                NaN     NaN        NaT                 NaN
# 18            NaT                NaN     NaN        NaT                 NaN
# 19            NaT                NaN     NaN        NaT                 NaN
# 20            NaT                NaN     NaN        NaT                 NaN
# 21            NaT                NaN     NaN        NaT                 NaN
# 22            NaT                NaN     NaN        NaT                 NaN
# 23            NaT                NaN     NaN        NaT                 NaN
# 24            NaT                NaN     NaN        NaT                 NaN
# 25            NaT                NaN     NaN        NaT                 NaN
# 26            NaT                NaN     NaN        NaT                 NaN
# 27            NaT                NaN     NaN        NaT                 NaN
# 28            NaT                NaN     NaN        NaT                 NaN
# 29            NaT                NaN     NaN        NaT                 NaN
# 30            NaT                NaN     NaN        NaT                 NaN
# 31            NaT                NaN     NaN        NaT                 NaN
#
#    ENQUIRY NO. REGISTRATION NO               Name  No of questions Attempted   \
# 0   EN10-05-80    RG10-05-1980      millind arora                          25
# 1   EN11-06-80    RG11-06-1980           abhinav                           25
# 2   EN13-07-80    RG13-07-1980     rahul tripathi                          25
# 3   EN14-08-80    RG14-08-1980             sumit                           25
# 4   EN15-09-80    RG15-09-1980         amit saini                          25
# 5   EN17-10-80    RG17-10-1980    akanshsha sudan                          25
# 6   EN18-11-80    RG18-11-1980     abhishek kumar                          25
# 7   EN20-12-80    RG20-12-1980  yatharth aggarwal                          25
# 8   EN21-01-81    RG21-01-1981             yograj                          25
# 9   EN22-02-81    RG22-02-1981      parmeet kaur                           25
# 10  EN26-03-81    RG26-03-1981             ankit                           25
# 11  EN27-04-81    RG27-04-1981       FAZAL ANSARI                          25
# 12  EN29-05-81    RG29-05-1981             mayank                          25
# 13  EN30-06-81    RG30-06-1981             ronak                           25
# 14         NaN    RG30-06-1982   POOJA CHAURASIA                           25
# 15         NaN    RG30-06-1983      Shubham Gupta                          25
# 16         NaN    RG30-06-1984  Yatharth Aggarwal                          25
# 17         NaN    RG30-06-1985     Saurabh Sharma                          25
# 18         NaN    RG30-06-1986          Gursimran                          25
# 19         NaN    RG30-06-1987             Ankit                           25
# 20         NaN    RG30-06-1988  Kanwal Jeet Singh                          25
# 21         NaN    RG30-06-1989            ABHINAV                          25
# 22         NaN    RG30-06-1990      Nikita Grover                          24
# 23         NaN    RG30-06-1991  Agam Singh Talwar                          25
# 24         NaN    RG30-06-1992              Tanya                          25
# 25         NaN    RG30-06-1993              Sumit                          25
# 26         NaN    RG30-06-1994       Manish Rawat                          25
# 27         NaN    RG30-06-1995       Rahul Sharma                          25
# 28         NaN    RG30-06-1996             Mayank                          25
# 29         NaN    RG30-06-1997       FAZAL ANSARI                          25
# 30         NaN    RG30-06-1998          Divyanshi                          25
# 31         NaN    RG30-06-1999       Mehtab Kalra                          25
#
#     Correct  Incorrect  Marks Obtained  Percentage
# 0        25          0              50         100
# 1        25          0              50         100
# 2        25          0              50         100
# 3        24          1              48          96
# 4        24          1              48          96
# 5        24          1              48          96
# 6        23          2              46          92
# 7        23          2              46          92
# 8        23          2              46          92
# 9        22          3              44          88
# 10       22          3              44          88
# 11       22          3              44          88
# 12       22          3              44          88
# 13       22          3              44          88
# 14       22          3              44          88
# 15       22          3              44          88
# 16       22          3              44          88
# 17       22          3              44          88
# 18       22          3              44          88
# 19       21          4              42          84
# 20       21          4              42          84
# 21       21          4              42          84
# 22       21          3              42          84
# 23       21          4              42          84
# 24       20          5              40          80
# 25       19          6              38          76
# 26       19          6              38          76
# 27       19          6              38          76
# 28       19          6              38          76
# 29       19          6              38          76
# 30       19          6              38          76
# 31       18          7              36          72

# %%
f1.columns
# Out:
# Index(['ADMISSION DATE', 'NAME OF STUDENT ', 'GENDER', 'DOB',
#        'STUDENT EMAIL ID ', 'ENQUIRY NO.', 'REGISTRATION NO'],
#       dtype='object')

# %%
f2.columns
# Out:
# Index(['REGISTRATION NO', 'Name', 'No of questions Attempted ', 'Correct',
#        'Incorrect', 'Marks Obtained', 'Percentage'],
#       dtype='object')

# %%
result5=pd.merge(f1[['REGISTRATION NO','STUDENT EMAIL ID ']],f2[['REGISTRATION NO','Name','Marks Obtained', 'Percentage']],on=['REGISTRATION NO'])

# %%
result5
# Out:
#    REGISTRATION NO   STUDENT EMAIL ID                Name  Marks Obtained  \
# 0     RG10-05-1980  milind@example.com      millind arora              50
# 1     RG11-06-1980  abhind@example.com           abhinav               50
# 2     RG13-07-1980  rahind@example.com     rahul tripathi              50
# 3     RG14-08-1980  sumind@example.com             sumit               48
# 4     RG15-09-1980  amiind@example.com         amit saini              48
# 5     RG17-10-1980  akaind@example.com    akanshsha sudan              48
# 6     RG18-11-1980  abhind@example.com     abhishek kumar              46
# 7     RG20-12-1980  yatind@example.com  yatharth aggarwal              46
# 8     RG21-01-1981  yogind@example.com             yograj              46
# 9     RG22-02-1981  parind@example.com      parmeet kaur               44
# 10    RG26-03-1981  ankind@example.com             ankit               44
# 11    RG27-04-1981  FAZind@example.com       FAZAL ANSARI              44
# 12    RG29-05-1981  mayind@example.com             mayank              44
# 13    RG30-06-1981  ronind@example.com             ronak               44
#
#     Percentage
# 0          100
# 1          100
# 2          100
# 3           96
# 4           96
# 5           96
# 6           92
# 7           92
# 8           92
# 9           88
# 10          88
# 11          88
# 12          88
# 13          88
