# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("complete.csv")

# %%
df
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 1         1975            Physics
# 2         2004          Chemistry
# 3         1982          Chemistry
# 4         1979            Physics
# ..         ...                ...
# 945       1972            Physics
# 946       1954          Chemistry
# 947       1911          Chemistry
# 948       1981              Peace
# 949       1963              Peace
#
#                                       categoryFullName  sortOrder portion  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                           The Nobel Prize in Physics          1     1/3
# 2                         The Nobel Prize in Chemistry          1     1/3
# 3                         The Nobel Prize in Chemistry          1       1
# 4                           The Nobel Prize in Physics          2     1/3
# ..                                                 ...        ...     ...
# 945                         The Nobel Prize in Physics          1     1/3
# 946                       The Nobel Prize in Chemistry          1       1
# 947                       The Nobel Prize in Chemistry          1       1
# 948                              The Nobel Peace Prize          1       1
# 949                              The Nobel Peace Prize          1     1/2
#
#      prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0       10000000             12295082  2001-10-10    received
# 1         630000              3404179  1975-10-17    received
# 2       10000000             11762861  2004-10-06    received
# 3        1150000              3102518  1982-10-18    received
# 4         800000              2988048  1979-10-15    received
# ..           ...                  ...         ...         ...
# 945       480000              3345725         NaN    received
# 946       181647              2640218         NaN    received
# 947       140695              7327865         NaN    received
# 948      1000000              2929688  1981-10-14    received
# 949       265000              2839286  1963-10-10    received
#
#                                             motivation  ...  \
# 0    for their analyses of markets with asymmetric ...  ...
# 1    for the discovery of the connection between co...  ...
# 2    for the discovery of ubiquitin-mediated protei...  ...
# 3    for his development of crystallographic electr...  ...
# 4    for their contributions to the theory of the u...  ...
# ..                                                 ...  ...
# 945  for their jointly developed theory of supercon...  ...
# 946  for his research into the nature of the chemic...  ...
# 947  in recognition of her services to the advancem...  ...
# 948   for promoting the fundamental rights of refugees  ...
# 949  for promoting the principles of the Geneva Con...  ...
#
#     org_founded_country org_founded_countryNow  org_founded_locationString  \
# 0                   NaN                    NaN                         NaN
# 1                   NaN                    NaN                         NaN
# 2                   NaN                    NaN                         NaN
# 3                   NaN                    NaN                         NaN
# 4                   NaN                    NaN                         NaN
# ..                  ...                    ...                         ...
# 945                 NaN                    NaN                         NaN
# 946                 NaN                    NaN                         NaN
# 947                 NaN                    NaN                         NaN
# 948         Switzerland            Switzerland         Geneva, Switzerland
# 949         Switzerland            Switzerland         Geneva, Switzerland
#
#        ind_or_org residence_1 residence_2  \
# 0      Individual         NaN         NaN
# 1      Individual         NaN         NaN
# 2      Individual         NaN         NaN
# 3      Individual         NaN         NaN
# 4      Individual         NaN         NaN
# ..            ...         ...         ...
# 945    Individual         NaN         NaN
# 946    Individual         NaN         NaN
# 947    Individual         NaN         NaN
# 948  Organization         NaN         NaN
# 949  Organization         NaN         NaN
#
#                                          affiliation_1  \
# 0               Stanford University, Stanford, CA, USA
# 1            Niels Bohr Institute, Copenhagen, Denmark
# 2    Technion - Israel Institute of Technology, Hai...
# 3    MRC Laboratory of Molecular Biology, Cambridge...
# 4    International Centre for Theoretical Physics, ...
# ..                                                 ...
# 945            University of Illinois, Urbana, IL, USA
# 946  California Institute of Technology (Caltech), ...
# 947                 Sorbonne University, Paris, France
# 948                                                NaN
# 949                                                NaN
#
#                                 affiliation_2 affiliation_3 affiliation_4
# 0                                         NaN           NaN           NaN
# 1                                         NaN           NaN           NaN
# 2                                         NaN           NaN           NaN
# 3                                         NaN           NaN           NaN
# 4    Imperial College, London, United Kingdom           NaN           NaN
# ..                                        ...           ...           ...
# 945                                       NaN           NaN           NaN
# 946                                       NaN           NaN           NaN
# 947                                       NaN           NaN           NaN
# 948                                       NaN           NaN           NaN
# 949                                       NaN           NaN           NaN
#
# [950 rows x 52 columns]

# %%
df.columns.tolist()
# Out:
# ['awardYear',
#  'category',
#  'categoryFullName',
#  'sortOrder',
#  'portion',
#  'prizeAmount',
#  'prizeAmountAdjusted',
#  'dateAwarded',
#  'prizeStatus',
#  'motivation',
#  'categoryTopMotivation',
#  'award_link',
#  'id',
#  'name',
#  'knownName',
#  'givenName',
#  'familyName',
#  'fullName',
#  'penName',
#  'gender',
#  'laureate_link',
#  'birth_date',
#  'birth_city',
#  'birth_cityNow',
#  'birth_continent',
#  'birth_country',
#  'birth_countryNow',
#  'birth_locationString',
#  'death_date',
#  'death_city',
#  'death_cityNow',
#  'death_continent',
#  'death_country',
#  'death_countryNow',
#  'death_locationString',
#  'orgName',
#  'nativeName',
#  'acronym',
#  'org_founded_date',
#  'org_founded_city',
#  'org_founded_cityNow',
#  'org_founded_continent',
#  'org_founded_country',
#  'org_founded_countryNow',
#  'org_founded_locationString',
#  'ind_or_org',
#  'residence_1',
#  'residence_2',
#  'affiliation_1',
#  'affiliation_2',
#  'affiliation_3',
#  'affiliation_4']

# %%
df.shape
# Out:
# (950, 52)

# %%
df.size
# Out:
# 49400

# %%
df.isnull()
# Out:
#      awardYear  category  categoryFullName  sortOrder  portion  prizeAmount  \
# 0        False     False             False      False    False        False
# 1        False     False             False      False    False        False
# 2        False     False             False      False    False        False
# 3        False     False             False      False    False        False
# 4        False     False             False      False    False        False
# ..         ...       ...               ...        ...      ...          ...
# 945      False     False             False      False    False        False
# 946      False     False             False      False    False        False
# 947      False     False             False      False    False        False
# 948      False     False             False      False    False        False
# 949      False     False             False      False    False        False
#
#      prizeAmountAdjusted  dateAwarded  prizeStatus  motivation  ...  \
# 0                  False        False        False       False  ...
# 1                  False        False        False       False  ...
# 2                  False        False        False       False  ...
# 3                  False        False        False       False  ...
# 4                  False        False        False       False  ...
# ..                   ...          ...          ...         ...  ...
# 945                False         True        False       False  ...
# 946                False         True        False       False  ...
# 947                False         True        False       False  ...
# 948                False        False        False       False  ...
# 949                False        False        False       False  ...
#
#      org_founded_country  org_founded_countryNow  org_founded_locationString  \
# 0                   True                    True                        True
# 1                   True                    True                        True
# 2                   True                    True                        True
# 3                   True                    True                        True
# 4                   True                    True                        True
# ..                   ...                     ...                         ...
# 945                 True                    True                        True
# 946                 True                    True                        True
# 947                 True                    True                        True
# 948                False                   False                       False
# 949                False                   False                       False
#
#      ind_or_org  residence_1  residence_2  affiliation_1  affiliation_2  \
# 0         False         True         True          False           True
# 1         False         True         True          False           True
# 2         False         True         True          False           True
# 3         False         True         True          False           True
# 4         False         True         True          False          False
# ..          ...          ...          ...            ...            ...
# 945       False         True         True          False           True
# 946       False         True         True          False           True
# 947       False         True         True          False           True
# 948       False         True         True           True           True
# 949       False         True         True           True           True
#
#      affiliation_3  affiliation_4
# 0             True           True
# 1             True           True
# 2             True           True
# 3             True           True
# 4             True           True
# ..             ...            ...
# 945           True           True
# 946           True           True
# 947           True           True
# 948           True           True
# 949           True           True
#
# [950 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['awardYear', 'category', 'categoryFullName', 'sortOrder', 'portion',
#        'prizeAmount', 'prizeAmountAdjusted', 'dateAwarded', 'prizeStatus',
#        'motivation', 'categoryTopMotivation', 'award_link', 'id', 'name',
#        'knownName', 'givenName', 'familyName', 'fullName', 'penName', 'gender',
#        'laureate_link', 'birth_date', 'birth_city', 'birth_cityNow',
#        'birth_continent', 'birth_country', 'birth_countryNow',
#        'birth_locationString', 'death_date', 'death_city', 'death_cityNow',
#        'death_continent', 'death_country', 'death_countryNow',
#        'death_locationString', 'orgName', 'nativeName', 'acronym',
#        'org_founded_date', 'org_founded_city', 'org_founded_cityNow',
#        'org_founded_continent', 'org_founded_country',
#        'org_founded_countryNow', 'org_founded_locationString', 'ind_or_org',
#        'residence_1', 'residence_2', 'affiliation_1', 'affiliation_2',
#        'affiliation_3', 'affiliation_4'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 52

# %%
df= df[['awardYear', 'category', 'prizeAmount', 'prizeAmountAdjusted', 'name', 'gender', 'birth_continent']]

# %%
df
# Out:
#      awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0         2001  Economic Sciences     10000000             12295082
# 1         1975            Physics       630000              3404179
# 2         2004          Chemistry     10000000             11762861
# 3         1982          Chemistry      1150000              3102518
# 4         1979            Physics       800000              2988048
# ..         ...                ...          ...                  ...
# 945       1972            Physics       480000              3345725
# 946       1954          Chemistry       181647              2640218
# 947       1911          Chemistry       140695              7327865
# 948       1981              Peace      1000000              2929688
# 949       1963              Peace       265000              2839286
#
#                                                   name  gender birth_continent
# 0                                    A. Michael Spence    male   North America
# 1                                         Aage N. Bohr    male          Europe
# 2                                    Aaron Ciechanover    male            Asia
# 3                                           Aaron Klug    male          Europe
# 4                                          Abdus Salam    male            Asia
# ..                                                 ...     ...             ...
# 945                                       John Bardeen    male   North America
# 946                                      Linus Pauling    male   North America
# 947                                        Marie Curie  female          Europe
# 948  Office of the United Nations High Commissioner...     NaN             NaN
# 949           International Committee of the Red Cross     NaN             NaN
#
# [950 rows x 7 columns]

# %%
df.awardYear.nunique()
# Out:
# 116

# %%
df.category.nunique()
# Out:
# 6

# %%
df.category.unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Peace',
#        'Physiology or Medicine', 'Literature'], dtype=object)

# %%
df.prizeAmount.max()
# Out:
# np.int64(10000000)

# %%
grouped = df.groupby('category')

# %%
grouped

# %%
grouped_category_year = df.groupby(['category','awardYear'])

# %%
grouped_category_year

# %%
df.head(20)
# Out:
#     awardYear                category  prizeAmount  prizeAmountAdjusted  \
# 0        2001       Economic Sciences     10000000             12295082
# 1        1975                 Physics       630000              3404179
# 2        2004               Chemistry     10000000             11762861
# 3        1982               Chemistry      1150000              3102518
# 4        1979                 Physics       800000              2988048
# 5        2019       Economic Sciences      9000000              9000000
# 6        2019                   Peace      9000000              9000000
# 7        2009               Chemistry     10000000             10958504
# 8        2011                 Physics     10000000             10545557
# 9        1939               Chemistry       148822              4227898
# 10       1905               Chemistry       138089              7615202
# 11       1928               Chemistry       156939              4458494
# 12       1980                   Peace       880000              2889667
# 13       1999               Chemistry      7900000             10049186
# 14       2010               Chemistry     10000000             10819388
# 15       2019               Chemistry      9000000              9000000
# 16       2007                   Peace     10000000             11301989
# 17       2000               Chemistry      9000000             11333109
# 18       1963  Physiology or Medicine       265000              2839286
# 19       2000               Chemistry      9000000             11333109
#
#                      name  gender birth_continent
# 0       A. Michael Spence    male   North America
# 1            Aage N. Bohr    male          Europe
# 2       Aaron Ciechanover    male            Asia
# 3              Aaron Klug    male          Europe
# 4             Abdus Salam    male            Asia
# 5        Abhijit Banerjee    male            Asia
# 6          Abiy Ahmed Ali    male          Africa
# 7           Ada E. Yonath  female            Asia
# 8           Adam G. Riess    male   North America
# 9         Adolf Butenandt    male          Europe
# 10       Adolf von Baeyer    male          Europe
# 11          Adolf Windaus    male          Europe
# 12  Adolfo Pérez Esquivel    male   South America
# 13           Ahmed Zewail    male          Africa
# 14           Akira Suzuki    male            Asia
# 15          Akira Yoshino    male            Asia
# 16                Al Gore    male   North America
# 17            Alan Heeger    male   North America
# 18           Alan Hodgkin    male          Europe
# 19        Alan MacDiarmid    male         Oceania

# %%
df[df.category=='Chemistry']
# Out:
#      awardYear   category  prizeAmount  prizeAmountAdjusted  \
# 2         2004  Chemistry     10000000             11762861
# 3         1982  Chemistry      1150000              3102518
# 7         2009  Chemistry     10000000             10958504
# 9         1939  Chemistry       148822              4227898
# 10        1905  Chemistry       138089              7615202
# ..         ...        ...          ...                  ...
# 940       1986  Chemistry      2000000              4098361
# 941       2005  Chemistry     10000000             11711430
# 943       1980  Chemistry       880000              2889667
# 946       1954  Chemistry       181647              2640218
# 947       1911  Chemistry       140695              7327865
#
#                   name  gender birth_continent
# 2    Aaron Ciechanover    male            Asia
# 3           Aaron Klug    male          Europe
# 7        Ada E. Yonath  female            Asia
# 9      Adolf Butenandt    male          Europe
# 10    Adolf von Baeyer    male          Europe
# ..                 ...     ...             ...
# 940        Yuan T. Lee    male            Asia
# 941       Yves Chauvin    male          Europe
#         192, 194, 196, 198, 208, 211, 217, 218, 226, 229, 242, 245, 248,
#         252, 254, 261, 262, 273, 281, 285, 288, 290, 293, 294, 299, 300,
#         302, 304, 309, 313, 314, 319, 322, 325, 331, 332, 334, 339, 340,
#         342, 344, 358, 368, 371, 379, 380, 383, 401, 407, 409, 414, 417,
#         423, 427, 431, 437, 443, 452, 464, 466, 473, 474, 478, 484, 486,
#         488, 490, 493, 494, 496, 497, 502, 503, 507, 519, 520, 531, 543,
#         551, 554, 568, 570, 575, 582, 584, 587, 589, 597, 598, 600, 624,
#         625, 626, 638, 645, 646, 649, 660, 662, 663, 672, 680, 685, 687,
#         689, 692, 701, 704, 706, 709, 712, 718, 728, 733, 740, 741, 748,
#         754, 757, 760, 762, 764, 768, 769, 778, 782, 783, 789, 791, 794,
#         804, 807, 809, 811, 812, 815, 816, 818, 819, 820, 821, 824, 825,
#         826, 830, 831, 837, 838, 841, 843, 845, 849, 857, 858, 859, 863,
#         869, 873, 874, 891, 898, 899, 906, 911, 918, 923, 939])}

# %%
len(grouped)
# Out:
# 6

# %%
grouped.ngroups
# Out:
# 6

# %%
grouped.get_group('Chemistry')
# Out:
#      awardYear   category  prizeAmount  prizeAmountAdjusted  \
# 2         2004  Chemistry     10000000             11762861
# 3         1982  Chemistry      1150000              3102518
# 7         2009  Chemistry     10000000             10958504
# 9         1939  Chemistry       148822              4227898
# 10        1905  Chemistry       138089              7615202
# ..         ...        ...          ...                  ...
# 940       1986  Chemistry      2000000              4098361
# 941       2005  Chemistry     10000000             11711430
# 943       1980  Chemistry       880000              2889667
# 946       1954  Chemistry       181647              2640218
# 947       1911  Chemistry       140695              7327865
#
#                   name  gender birth_continent
# 2    Aaron Ciechanover    male            Asia
# 3           Aaron Klug    male          Europe
# 7        Ada E. Yonath  female            Asia
# 9      Adolf Butenandt    male          Europe
# 10    Adolf von Baeyer    male          Europe
# ..                 ...     ...             ...
# 940        Yuan T. Lee    male            Asia
# 941       Yves Chauvin    male          Europe
# 943   Frederick Sanger    male          Europe
# 946      Linus Pauling    male   North America
# 947        Marie Curie  female          Europe
#
# [184 rows x 7 columns]

# %%
grouped.get_group(['Economic Science', 'Physics'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 grouped.get_group(['Economic Science', 'Physics'])
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:1112, in BaseGroupBy.get_group(self, name, obj)
#    1102     elif not isinstance(name, tuple):
#    1103         warnings.warn(
#    1104             "When grouping with a length-1 list-like, "
#    1105             "you will need to pass a length-1 tuple to get_group in a future "
#    (...)
#    1109             stacklevel=find_stack_level(),
#    1110         )
# -> 1112 inds = self._get_index(name)
#    1113 if not len(inds):
#    1114     raise KeyError(name)
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:964, in BaseGroupBy._get_index(self, name)
#     959 @final
#     960 def _get_index(self, name):
#     961     """
#     962     Safe get index, translate keys for datelike to underlying repr.
#     963     """
# --> 964     return self._get_indices([name])[0]
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:957, in BaseGroupBy._get_indices(self, names)
#     954     converter = get_converter(index_sample)
#     955     names = (converter(name) for name in names)
# --> 957 return [self.indices.get(name, []) for name in names]
#
# TypeError: unhashable type: 'list'

# %%
grouped.agg(np.mean)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_
to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 grouped.agg(np.mean)
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File ~\myenv\Lib\site-packages\pandas\core\apply.py:199, in Apply.agg(self)
#     197     if f and not args and not kwargs:
#     198         warn_alias_replacement(obj, func, f)
# --> 199         return getattr(obj, f)()
#     201 # caller can react
#     202 return None
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~\myenv\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~\myenv\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~\myenv\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.mean)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\377985497.py:1: FutureWarning: The provided callable <function mean at 0x0000022A7A247600> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.mean)
#                          prizeAmount  prizeAmountAdjusted
# category
# Chemistry               3.629279e+06         6.257868e+06
# Economic Sciences       6.105845e+06         7.837779e+06
# Literature              2.493811e+06         5.598256e+06
# Peace                   3.124879e+06         6.163907e+06
# Physics                 3.407939e+06         6.086978e+06
# Physiology or Medicine  3.072973e+06         5.738301e+06

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.median)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\3741155779.py:1: FutureWarning: The provided callable <function median at 0x0000022A7A390860> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.median)
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                  800000.0            5117217.0
# Economic Sciences         7550000.0            9000000.0
# Literature                 269000.0            4366629.0
# Peace                      480000.0            5238085.0
# Physics                    700000.0            4907955.0
# Physiology or Medicine     510000.0            4098361.0

# %%
df.info
# Out:
# <bound method DataFrame.info of      awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0         2001  Economic Sciences     10000000             12295082
# 1         1975            Physics       630000              3404179
# 2         2004          Chemistry     10000000             11762861
# 3         1982          Chemistry      1150000              3102518
# 4         1979            Physics       800000              2988048
# ..         ...                ...          ...                  ...
# 945       1972            Physics       480000              3345725
# 946       1954          Chemistry       181647              2640218
# 947       1911          Chemistry       140695              7327865
# 948       1981              Peace      1000000              2929688
# 949       1963              Peace       265000              2839286
#
#                                                   name  gender birth_continent
# 0                                    A. Michael Spence    male   North America
# 1                                         Aage N. Bohr    male          Europe
# 2                                    Aaron Ciechanover    male            Asia
# 3                                           Aaron Klug    male          Europe
# 4                                          Abdus Salam    male            Asia
# ..                                                 ...     ...             ...
# 945                                       John Bardeen    male   North America
# 946                                      Linus Pauling    male   North America
# 947                                        Marie Curie  female          Europe
# 948  Office of the United Nations High Commissioner...     NaN             NaN
# 949           International Committee of the Red Cross     NaN             NaN
#
# [950 rows x 7 columns]>

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].median
# Out:
# <bound method GroupBy.median of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000022A01F87AA0>>

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.max)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\3663710181.py:1: FutureWarning: The provided callable <function max at 0x0000022A7A246C00> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.max)
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                  10000000             12295082
# Economic Sciences          10000000             12295082
# Literature                 10000000             12295082
# Peace                      10000000             12295082
# Physics                    10000000             12295082
# Physiology or Medicine     10000000             12295082

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.min)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\3288830877.py:1: FutureWarning: The provided callable <function min at 0x0000022A7A246D40> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.min)
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                    114935              2394643
# Economic Sciences            375000              2889667
# Literature                   114935              2377268
# Peace                        116960              2377268
# Physics                      114935              2377268
# Physiology or Medicine       114935              2377268

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.sum)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\2116602024.py:1: FutureWarning: The provided callable <function sum at 0x0000022A7A246200> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.sum)
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                 667787418           1151447726
# Economic Sciences         512891000            658373449
# Literature                289282102            649397731
# Peace                     418733807            825963521
# Physics                   725890928           1296526352
# Physiology or Medicine    672981066           1256687857

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.size)
# Out:
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                       184                  184
# Economic Sciences                84                   84
# Literature                      116                  116
# Peace                           134                  134
# Physics                         213                  213
# Physiology or Medicine          219                  219

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.std)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\3340171541.py:1: FutureWarning: The provided callable <function std at 0x0000022A7A247740> is currently using DataFrameGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.std)
#                          prizeAmount  prizeAmountAdjusted
# category
# Chemistry               4.070588e+06         3.276027e+06
# Economic Sciences       3.787630e+06         3.313153e+06
# Literature              3.653734e+06         3.029512e+06
# Peace                   3.934391e+06         3.189886e+06
# Physics                 4.013073e+06         3.294268e+06
# Physiology or Medicine  3.898539e+06         3.241781e+06

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].count()
# Out:
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                       184                  184
# Economic Sciences                84                   84
# Literature                      116                  116
# Peace                           134                  134
# Physics                         213                  213
# Physiology or Medicine          219                  219

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.len)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 grouped[['prizeAmount','prizeAmountAdjusted']].agg(np.len)
#
# File ~\myenv\Lib\site-packages\numpy\__init__.py:428, in __getattr__(attr)
#     425     import numpy.char as char
#     426     return char.chararray
# --> 428 raise AttributeError("module {!r} has no attribute "
#     429                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'len'

# %%
grouped[['prizeAmount','prizeAmountAdjusted']].agg(len)
# Out:
#                         prizeAmount  prizeAmountAdjusted
# category
# Chemistry                       184                  184
# Economic Sciences                84                   84
# Literature                      116                  116
# Peace                           134                  134
# Physics                         213                  213
# Physiology or Medicine          219                  219

# %%
df.groupby('category').sum()
# Out:
#                         awardYear  prizeAmount  prizeAmountAdjusted  \
# category
# Chemistry                  362912    667787418           1151447726
# Economic Sciences          167674    512891000            658373449
# Literature                 227468    289282102            649397731
# Peace                      263248    418733807            825963521
# Physics                    419837    725890928           1296526352
# Physiology or Medicine     431508    672981066           1256687857
#
#                                                                      name  \
# category
# Chemistry               Aaron CiechanoverAaron KlugAda E. YonathAdolf ...
# Economic Sciences       A. Michael SpenceAbhijit BanerjeeAlvin E. Roth...
# Literature              Albert CamusAlexandr SolzhenitsynAlice MunroAn...
# Peace                   Abiy Ahmed AliAdolfo Pérez EsquivelAl GoreAlbe...
# Physics                 Aage N. BohrAbdus SalamAdam G. RiessAlbert A. ...
# Physiology or Medicine  Alan HodgkinAlbert ClaudeAlbert Szent-GyörgyiA...
#
#                                                                    gender  \
# category
# Chemistry               malemalefemalemalemalemalemalemalemalemalemale...
# Economic Sciences       malemalemalemalemalemalemalemalemalemalemalema...
# Literature              malemalefemalemalemalemalemalemalemalemalemale...
# Peace                   malemalemalemalemalemalemalemalefemalemalemale...
# Physics                 malemalemalemalemalemalemalemalemalemalemalema...
# Physiology or Medicine  malemalemalemalemalemalemalemalemalemalemalema...
#
#                                                           birth_continent
# category
# Chemistry               AsiaEuropeAsiaEuropeEuropeEuropeAfricaAsiaAsia...
# Economic Sciences       North AmericaAsiaNorth AmericaAsiaEuropeEurope...
# Literature              AfricaEuropeNorth AmericaEuropeEuropeEuropeEur...
# Peace                   AfricaSouth AmericaNorth AmericaEuropeAfricaEu...
# Physics                 EuropeAsiaNorth AmericaEuropeEuropeEuropeOcean...
# Physiology or Medicine  EuropeEuropeEuropeEuropeEuropeNorth AmericaNor...

# %%
df.groupby(['prizeAmount','prizeAmountAdjusted']).sum()
# Out:
#                                  awardYear  \
# prizeAmount prizeAmountAdjusted
# 114935      3169164                   9615
# 116719      3218355                   5772
# 116960      3273134                  11556
# 118165      3211005                  11550
# 121333      2499993                  13615
# ...                                    ...
# 10000000    11711430                 26065
#             11762861                 24048
#             11807305                 22033
#             12034660                 26026
#             12295082                 30015
#
#                                                                           category  \
# prizeAmount prizeAmountAdjusted
# 114935      3169164              Physiology or MedicineChemistryPhysiology or M...
# 116719      3218355                        PhysicsPhysiology or MedicineLiterature
# 116960      3273134              PeaceLiteraturePeacePhysicsPhysiology or Medic...
# 118165      3211005                    PeaceLiteraturePhysicsPhysicsChemistryPeace
# 121333      2499993              ChemistryPeacePhysiology or MedicineLiterature...
# ...                                                                            ...
# 10000000    11711430             Physiology or MedicineLiteraturePeacePhysiolog...
#             11762861             ChemistryChemistryPhysicsEconomic SciencesLite...
#             11807305             PhysicsPhysicsEconomic SciencesLiteraturePhysi...
#             12034660             Economic SciencesPhysiology or MedicineLiterat...
#             12295082             Economic SciencesChemistryPhysicsPhysicsEconom...
#
#                                                                               name  \
# prizeAmount prizeAmountAdjusted
# 114935      3169164              Frederick G. BantingFritz PreglJohn MacleodRob...
# 116719      3218355                Manne SiegbahnWillem EinthovenWladyslaw Reymont
# 116960      3273134              Aristide BriandGrazia DeleddaGustav Stresemann...
# 118165      3211005              Charles G. DawesGeorge Bernard ShawGustav Hert...
# 121333      2499993              Artturi VirtanenCordell HullErnst B. ChainGabr...
# ...                                                                            ...
# 10000000    11711430             Barry J. MarshallHarold PinterInternational At...
#             11762861             Aaron CiechanoverAvram HershkoDavid J. GrossEd...
#             11807305             Alexei AbrikosovAnthony J. LeggettClive W.J. G...
#             12034660             Daniel KahnemanH. Robert HorvitzImre KertészJi...
#             12295082             A. Michael SpenceBarry SharplessCarl WiemanEri...
#
#                                                                             gender  \
# prizeAmount prizeAmountAdjusted
# 114935      3169164                                           malemalemalemalemale
# 116719      3218355                                                   malemalemale
# 116960      3273134                                     malefemalemalemalemalemale
# 118165      3211005                                       malemalemalemalemalemale
# 121333      2499993                                 malemalemalefemalemalemalemale
# ...                                                                            ...
# 10000000    11711430              malemalemalemalemalemalemalemalemalemalemalemale
#             11762861             malemalemalemalefemalemalemalemalemalefemalema...
#             11807305                malemalemalemalemalemalemalemalefemalemalemale
#             12034660             malemalemalemalemalemalemalemalemalemalemalema...
#             12295082             malemalemalemalemalemalemalemalemalemalemalema...
#
#                                                                    birth_continent
# prizeAmount prizeAmountAdjusted
# 114935      3169164                   North AmericaEuropeEuropeNorth AmericaEurope
# 116719      3218355                                               EuropeAsiaEurope
# 116960      3273134                           EuropeEuropeEuropeEuropeEuropeEurope
# 118165      3211005                    North AmericaEuropeEuropeEuropeEuropeEurope
# 121333      2499993              EuropeNorth AmericaEuropeSouth AmericaEuropeOc...
# ...                                                                            ...
# 10000000    11711430             OceaniaEuropeOceaniaNorth AmericaAfricaNorth A...
#             11762861             AsiaEuropeNorth AmericaNorth AmericaEuropeEuro...
#             11807305             EuropeEuropeEuropeAfricaNorth AmericaNorth Ame...
#             12034660             AsiaNorth AmericaEuropeNorth AmericaNorth Amer...
#             12295082             North AmericaNorth AmericaNorth AmericaNorth A...
#
# [114 rows x 5 columns]

# %%
df.groupby(['prizeAmount','prizeAmountAdjusted'])['prizeAmount'].sum()
# Out:
# prizeAmount  prizeAmountAdjusted
# 114935       3169164                   574675
# 116719       3218355                   350157
# 116960       3273134                   701760
# 118165       3211005                   708990
# 121333       2499993                   849331
#                                       ...
# 10000000     11711430               130000000
#              11762861               120000000
#              11807305               110000000
#              12034660               130000000
#              12295082               150000000
# Name: prizeAmount, Length: 114, dtype: int64

# %%
df.groupby('category')[['prizeAmountAdjusted','prizeAmount']].sum()
# Out:
#                         prizeAmountAdjusted  prizeAmount
# category
# Chemistry                        1151447726    667787418
# Economic Sciences                 658373449    512891000
# Literature                        649397731    289282102
# Peace                             825963521    418733807
# Physics                          1296526352    725890928
# Physiology or Medicine           1256687857    672981066

# %%
df.groupby('category')[['prizeAmountAdjusted','prizeAmount']].agg([np.sum,np.mean,np.median])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\1078242908.py:1: FutureWarning: The provided callable <function sum at 0x0000022A7A246200> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby('category')[['prizeAmountAdjusted','prizeAmount']].agg([np.sum,np.mean,np.median])
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\1078242908.py:1: FutureWarning: The provided callable <function mean at 0x0000022A7A247600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('category')[['prizeAmountAdjusted','prizeAmount']].agg([np.sum,np.mean,np.median])
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\1078242908.py:1: FutureWarning: The provided callable <function median at 0x0000022A7A390860> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby('category')[['prizeAmountAdjusted','prizeAmount']].agg([np.sum,np.mean,np.median])
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\1078242908.py:1: FutureWarning: The provided callable <function sum at 0x0000022A7A246200> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby('category')[['prizeAmountAdjusted','prizeAmount']].agg([np.sum,np.mean,np.median])
#                        prizeAmountAdjusted                           \
#                                        sum          mean     median
# category
# Chemistry                       1151447726  6.257868e+06  5117217.0
# Economic Sciences                658373449  7.837779e+06  9000000.0
# Literature                       649397731  5.598256e+06  4366629.0
# Peace                            825963521  6.163907e+06  5238085.0
# Physics                         1296526352  6.086978e+06  4907955.0
# Physiology or Medicine          1256687857  5.738301e+06  4098361.0
#
#                        prizeAmount
#                                sum          mean     median
# category
# Chemistry                667787418  3.629279e+06   800000.0
# Economic Sciences        512891000  6.105845e+06  7550000.0
# Literature               289282102  2.493811e+06   269000.0
# Peace                    418733807  3.124879e+06   480000.0
# Physics                  725890928  3.407939e+06   700000.0
# Physiology or Medicine   672981066  3.072973e+06   510000.0

# %%
grouped.agg({'prizeAmount':[np.sum,np.size],'prizeAmountAdjusted':np.mean})
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\469950434.py:1: FutureWarning: The provided callable <function sum at 0x0000022A7A246200> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grouped.agg({'prizeAmount':[np.sum,np.size],'prizeAmountAdjusted':np.mean})
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\469950434.py:1: FutureWarning: The provided callable <function mean at 0x0000022A7A247600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grouped.agg({'prizeAmount':[np.sum,np.size],'prizeAmountAdjusted':np.mean})
#                        prizeAmount      prizeAmountAdjusted
#                                sum size                mean
# category
# Chemistry                667787418  184        6.257868e+06
# Economic Sciences        512891000   84        7.837779e+06
# Literature               289282102  116        5.598256e+06
# Peace                    418733807  134        6.163907e+06
# Physics                  725890928  213        6.086978e+06
# Physiology or Medicine   672981066  219        5.738301e+06

# %%
df.groupby('category').agg({'prizeAmount':[np.sum,np.size],'prizeAmountAdjusted':np.mean})
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\3934615713.py:1: FutureWarning: The provided callable <function sum at 0x0000022A7A246200> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby('category').agg({'prizeAmount':[np.sum,np.size],'prizeAmountAdjusted':np.mean})
# C:\Users\HP\AppData\Local\Temp\ipykernel_15444\3934615713.py:1: FutureWarning: The provided callable <function mean at 0x0000022A7A247600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('category').agg({'prizeAmount':[np.sum,np.size],'prizeAmountAdjusted':np.mean})
#                        prizeAmount      prizeAmountAdjusted
#                                sum size                mean
# category
# Chemistry                667787418  184        6.257868e+06
# Economic Sciences        512891000   84        7.837779e+06
# Literature               289282102  116        5.598256e+06
# Peace                    418733807  134        6.163907e+06
# Physics                  725890928  213        6.086978e+06
# Physiology or Medicine   672981066  219        5.738301e+06

# %%
df1 = pd.read_csv("nba.csv")

# %%
df1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df1.nunique()
# Out:
# Name        457
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %%
df1..groupby("College")["College"].count()
# Out:
#   Cell In[69], line 1
#     df1..groupby("College")["College"].count()
#         ^
# SyntaxError: invalid syntax

# %%
df1.groupby(['Team','Position']).count()
# Out:
#                              Name  Number  Age  Height  Weight  College  \
# Team               Position
# Atlanta Hawks      C            3       3    3       3       3        1
#                    PF           4       4    4       4       4        4
#                    PG           2       2    2       2       2        1
#                    SF           2       2    2       2       2        1
#                    SG           4       4    4       4       4        4
# ...                           ...     ...  ...     ...     ...      ...
# Washington Wizards C            3       3    3       3       3        1
#                    PF           2       2    2       2       2        2
#                    PG           2       2    2       2       2        2
#                    SF           4       4    4       4       4        4
#                    SG           4       4    4       4       4        4
#
#                              Salary
# Team               Position
# Atlanta Hawks      C              3
#                    PF             4
#                    PG             2
#                    SF             2
#                    SG             4
# ...                             ...
# Washington Wizards C              3
#                    PF             2
#                    PG             2
#                    SF             4
#                    SG             4
#
# [149 rows x 7 columns]

# %%
df1.groupby(['Team','Position']).first()
# Out:
#                                          Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C               Al Horford    15.0  30.0   6-10   245.0
#                    PF          Kris Humphries    43.0  31.0    6-9   235.0
#                    PG         Dennis Schroder    17.0  22.0    6-1   172.0
#                    SF           Kent Bazemore    24.0  26.0    6-5   201.0
#                    SG        Tim Hardaway Jr.    10.0  24.0    6-6   205.0
# ...                                       ...     ...   ...    ...     ...
# Washington Wizards C            Marcin Gortat    13.0  32.0   6-11   240.0
#                    PF             Drew Gooden    90.0  34.0   6-10   250.0
#                    PG          Ramon Sessions     7.0  30.0    6-3   190.0
#                    SF            Jared Dudley     1.0  30.0    6-7   225.0
#                    SG           Alan Anderson     6.0  33.0    6-6   220.0
#
#                                           College      Salary
# Team               Position
# Atlanta Hawks      C                      Florida  12000000.0
#                    PF                   Minnesota   1000000.0
#                    PG                 Wake Forest   1763400.0
#                    SF                Old Dominion   2000000.0
#                    SG                    Michigan   1304520.0
# ...                                           ...         ...
# Washington Wizards C         North Carolina State  11217391.0
#                    PF                      Kansas   3300000.0
#                    PG                      Nevada   2170465.0
#                    SF              Boston College   4375000.0
#                    SG              Michigan State   4000000.0
#
# [149 rows x 7 columns]

# %%
df1.groupby(['Team','Position']).last()
# Out:
#                                         Name  Number   Age Height  Weight  \
# Team               Position
# Atlanta Hawks      C          Walter Tavares    22.0  24.0    7-3   260.0
#                    PF             Mike Scott    32.0  27.0    6-8   237.0
#                    PG            Jeff Teague     0.0  27.0    6-2   186.0
#                    SF        Thabo Sefolosha    25.0  32.0    6-7   220.0
#                    SG        Lamar Patterson    13.0  24.0    6-5   225.0
# ...                                      ...     ...   ...    ...     ...
# Washington Wizards C            Nene Hilario    42.0  33.0   6-11   250.0
#                    PF        Markieff Morris     5.0  26.0   6-10   245.0
#                    PG              John Wall     2.0  25.0    6-4   195.0
#                    SF        Marcus Thornton    15.0  29.0    6-4   205.0
#                    SG         Garrett Temple    17.0  30.0    6-6   195.0
#
#                                           College      Salary
# Team               Position
# Atlanta Hawks      C                      Florida   1000000.0
#                    PF                    Virginia   3333333.0
#                    PG                 Wake Forest   8000000.0
#                    SF                Old Dominion   4000000.0
#                    SG                  Pittsburgh    525093.0
# ...                                           ...         ...
# Washington Wizards C         North Carolina State  13000000.0
#                    PF                      Kansas   8000000.0
#                    PG                    Kentucky  15851950.0
#                    SF                         LSU    200600.0
#                    SG                         LSU   1100602.0
#
# [149 rows x 7 columns]

# %%
df1.groupby(['Team','Position']), as_index=False).first()
# Out:
#   Cell In[73], line 1
#     df1.groupby(['Team','Position']), as_index=False).first()
#                                                     ^
# SyntaxError: unmatched ')'
