# %%
class car:
    name = 'tata'

s1 = car()
print(s1.name)
# Out:
# tata

# %%
class car:
    def __init__(self):
        self.make = "Toyota"
        self.model = "Corolla"
        self.year = 2020

car = car()
print(car.make)
print(car.model)
print(car.year)
# Out:
# Toyota
# Corolla
# 2020

# %%
class Student:
    name = "RAJ"
    CLASS = 12
    CITY = "BHOPAL"

# %%
s1 = Student()

# %%
print(s1)

# %%
s1.name
# Out:
# 'RAJ'

# %%
s1.CLASS
# Out:
# 12

# %%
s1.CITY
# Out:
# 'BHOPAL'

# %%
class Student:
    name = "RAJ"
    def student1():
        print("Student is studying")

# %%
Student.student1()
# Out:
# Student is studying
