# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp)
#show the figure
plt.show()

# %%
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp)
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.title("Date wise Temperature")
plt.grid(True)
plt.yticks(temp)
plt.savefig("temp.png")
#show the figure
plt.show()

# %%
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp)
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.title("Date wise Temperature")
plt.grid(True)
plt.ylim(0,15)
plt.savefig("temp.png")
#show the figure
plt.show()

# %%
#MARKER
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, marker="P")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,marker='p')
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, "P")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, "D")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,"rD")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, '-')
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,'--')
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,'-.')
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,":")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,"--+")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,"--P")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,"--r")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,"r--")
#show the figure
plt.show()

# %%
#plot temperature values for the given data
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp,"r--P")
#show the figure
plt.show()

# %%
t = np.arange(0., 5.,0.2)
plt.plot(t, t, "r--",t, t**2,'bs',t,t**3,"g^")
plt.show()

# %%
t = np.arange(0., 5.,0.2)
plt.plot(t, t, "r--",t, t**2,'bs',t,t**3,"g^")
plt.show()
plt.plot(t, t, "r--")
plt.plot(t**2,'bs')
plt.plot(t,t**3,"g^")

# %%
t = np.arange(0., 5.,0.3)
plt.plot(t, t, "r--",t, t**2,'bs',t,t**3,"g^")
plt.show()
plt.plot(t, t, "r--")
plt.plot(t**2,'bs')
plt.plot(t,t**3,"g^")

# %%
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, color='green',linestyle='--',marker='o', markerfacecolor='blue',markersize = 12, linewidth = 5)
#show the figure
plt.show()

# %%
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, color='green',linestyle='--',marker='o', markerfacecolor='blue',markersize = 120, linewidth = 5)
#show the figure
plt.show()

# %%
#storing date in string format
date=["25/12","26/12","27/12"]
#list storing temperature values
temp=[8.5,10.5,6.8]
#create a figure plotting temp versus date
plt.plot(date, temp, color='green',linestyle='--',marker='D', markerfacecolor='blue',markersize = 12, linewidth = 5, markeredgewidth=2,markevery=1)
#show the figure
plt.show()

# %%
t = np.arange(0., 5.,0.3)
plt.plot(t, t, "r--")
plt.plot(t**2,'bs')
plt.plot(t,t**3,"g^",markevery=1)
plt.show()

# %%
t = np.arange(0., 5.,0.3)
plt.plot(t, t, "r--")
plt.plot(t**2,'bs')
plt.plot(t,t**3,"g<",markevery=1)
plt.show()
