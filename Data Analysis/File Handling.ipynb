# %%
file_data = open('Thakur.txt','r')

# %%
print(file_data)
# Out:
# <_io.TextIOWrapper name='Thakur.txt' mode='r' encoding='cp1252'>

# %%
content = file_data.read()
print(content)
# Out:
# Data Science And Data Analytics

# %%
file_data = open('Thakur.txt','w')

# %%
print(file_data)
# Out:
# <_io.TextIOWrapper name='Thakur.txt' mode='w' encoding='cp1252'>

# %%
file_data = open('Thakur.txt','r')
for i in file_data:
    print(i)
# Out:
# 1 a
#
# 2 b
#
# c 3
#
# d 4
#
# e 5
#
# f 6

# %%
file_data = open('Thakur.txt','w')
file_data.write("THIS IS WRITE COMMAND TO OVER WRITE THE DATA")
file_data.write("\nThis is last line.")
file_data.close()

#\n is used for new line

# %%
file_data = open('Bhopal.txt','w')
file_data.write("THIS IS WRITE COMMAND TO OVER WRITE THE DATA")
file_data.write("\nThis is last line.")
file_data.close()

# %%
file_data = open('Bhopal.txt','a')
file_data.write("WRITING USING APPEND MODE\n")
file_data.write("\nThis is append mode.")
file_data.close()

# %%
with open("Thakur.txt","r") as file:
    content=file.read()
    print(content)

file.close()
# Out:
# THIS IS WRITE COMMAND TO OVER WRITE THE DATA
# This is last line.

# %%
file_data = open('Bhopal.txt','w')
file_data.write("\ndata science and data analytics syllabus\npython-numpy,pandas\nsql\npower bi""\nexcel""\nML")
file_data.close()

# %%
FILE = open("Thakur.txt",'r')
content = FILE.readlines()

# %%
content.insert(1,"DEWAS\n")

# %%
import csv
#writing to a csv file
