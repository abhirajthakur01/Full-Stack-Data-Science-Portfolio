# %%
from sklearn.neighbors import KDTree,KNeighborsClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x,y=make_classification(n_samples=500,n_features=5,n_informative=3,n_classes=2,random_state=42)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knn_model=KNeighborsClassifier(n_neighbors=5,algorithm="kd_tree")

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree')

# %%
y_pred=knn_model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.95

# %%
# explicit ball tree
kd_tree=KDTree(x_train)
distances,indices=ball_tree.query([x_test[0]],k=5)

# %%
distances
# Out:
# array([[0.51478791, 0.52457131, 0.70293506, 0.74407544, 0.99740778]])

# %%
indices
# Out:
# array([[333,  60,   9, 102, 351]], dtype=int64)
