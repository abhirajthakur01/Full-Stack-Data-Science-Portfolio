# %% [markdown]
# #### ASSIGNMENT:
# * ALL THE INFO ABOUT EACH ATTRIBUTE/COLUMN OF BOTH THE DATASET(cars and google eda dataset)

# %% [markdown]
# ## EDA PROJECT ON GOOGLE APP STORE DATASET

# %% [markdown]
# #### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\91854\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\91854\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %% [markdown]
# #### Data ingestion

# %%
df = pd.read_csv('Google_app_store_eda_sample.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           App Name  \
# 0      114793                      Universal Remote For Insignia
# 1     1298958                                  Revilla Domínguez
# 2     1205716                                            Polaris
# 3     1539667                                BioChem Euchre Deck
# 4     1002970  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     NaN
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  ...  \
# 0         646.0  100,000+          100000.0            102424  True  ...
# 1           0.0        0+               0.0                 0  True  ...
# 2           NaN       10+              10.0                12  True  ...
# 3          44.0   10,000+           10000.0             12198  True  ...
# 4          78.0   50,000+           50000.0             74811  True  ...
#
#          Developer Website                  Developer Email      Released  \
# 0                      NaN              Daud19887@gmail.com  Jan 21, 2019
# 1                      NaN                      app@bewe.io   Jan 2, 2020
# 2                      NaN          support@polaris-vpn.com           NaN
# 3  http://cmer.uoguelph.ca                 cmer@uoguelph.ca  Dec 16, 2011
# 4                      NaN  Yogendrakushwah151995@gmail.com   Jul 8, 2018
#
#    Last Updated Content Rating  \
# 0  Apr 08, 2021       Everyone
# 1  Feb 15, 2020       Everyone
# 2  Apr 21, 2021       Everyone
# 3  Feb 08, 2012       Everyone
# 4  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2                                                NaN        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 22:12:43
# 1            False          False  2021-06-15 22:09:38
# 2             True          False  2021-06-15 20:46:00
# 3            False          False  2021-06-16 01:57:28
# 4            False          False  2021-06-16 12:21:40
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Attribute information

# %% [markdown]
# * App Name:

# %% [markdown]
# #### last 5 rows of the dataset

# %%
df.tail()
# Out:
#        Unnamed: 0                                           App Name  \
# 99995     1421966                        USB UART Terminal (AD-free)
# 99996      751043  Photo par Gazal Shayari Likhe - फोटो पर ग़ज़ल शायरी
# 99997      886312                   Tangle Master - Solve the tangle
# 99998      865728              Wild Wolf Chasing Animal Simulator 3D
# 99999     1675582                       أغاني و قصائد  قحطان البديري
#
#                                            App Id       Category  Rating  \
# 99995                  com.simran.usbuartterminal          Tools     0.0
# 99996                  com.devadroid.gazalshayari         Comics     0.0
# 99997                        com.taikenoel.tangle         Puzzle     3.7
# 99998  com.gss.wild.wolf.chasing.animal.simulator         Comics     4.5
# 99999                     musicmp3.Qahtan_Budairi  Music & Audio     3.8
#
#        Rating Count  Installs  Minimum Installs  Maximum Installs  Free  ...  \
# 99995           0.0      500+             500.0               629  True  ...
# 99996           0.0    1,000+            1000.0              2134  True  ...
# 99997           6.0      500+             500.0               682  True  ...
# 99998        1304.0  100,000+          100000.0            370802  True  ...
# 99999          10.0    1,000+            1000.0              1758  True  ...
#
#                      Developer Website           Developer Email  \
# 99995                              NaN        smarok77@gmail.com
# 99996                              NaN  borondeveloper@gmail.com
# 99997                              NaN     device.en16@gmail.com
# 99998    https://www.weplaystudio.com/   studiogamehit@gmail.com
# 99999  https://musicagani.blogspot.com         rayan.razan@bk.ru
#
#            Released  Last Updated Content Rating  \
# 99995  Jan 12, 2019  Aug 06, 2019       Everyone
# 99996  Oct 30, 2017  Oct 08, 2018     Mature 17+
# 99997  Jan 25, 2021  Jan 25, 2021       Everyone
# 99998  May 18, 2019  Mar 30, 2021       Everyone
# 99999  Apr 30, 2020  Jun 14, 2020       Everyone
#
#                                           Privacy Policy Ad Supported  \
# 99995                                                NaN        False
# 99996  https://www.freeprivacypolicy.com/privacy/view...         True
# 99997                                                NaN         True
# 99998  https://docs.google.com/document/d/1Z79BT2rHTB...         True
# 99999  https://googleplayw.blogspot.com/2019/05/priva...         True
#
#       In App Purchases Editors Choice         Scraped Time
# 99995            False          False  2021-06-16 00:07:59
# 99996            False          False  2021-06-16 08:26:12
# 99997            False          False  2021-06-16 10:33:09
# 99998            False          False  2021-06-16 10:13:52
# 99999            False          False  2021-06-16 03:50:50
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (100000, 25)

# %% [markdown]
# #### Information of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         100000 non-null  int64
#  1   App Name           100000 non-null  object
#  2   App Id             100000 non-null  object
#  3   Category           100000 non-null  object
#  4   Rating             98997 non-null   float64
#  5   Rating Count       98997 non-null   float64
#  6   Installs           99996 non-null   object
#  7   Minimum Installs   99996 non-null   float64
#  8   Maximum Installs   100000 non-null  int64
#  9   Free               100000 non-null  bool
#  10  Price              100000 non-null  float64
#  11  Currency           99995 non-null   object
#  12  Size               99991 non-null   object
#  13  Minimum Android    99703 non-null   object
#  14  Developer Id       99997 non-null   object
#  15  Developer Website  67068 non-null   object
#  16  Developer Email    99998 non-null   object
#  17  Released           96868 non-null   object
#  18  Last Updated       100000 non-null  object
#  19  Content Rating     100000 non-null  object
#  20  Privacy Policy     81629 non-null   object
#  21  Ad Supported       100000 non-null  bool
#  22  In App Purchases   100000 non-null  bool
#  23  Editors Choice     100000 non-null  bool
#  24  Scraped Time       100000 non-null  object
# dtypes: bool(4), float64(4), int64(2), object(15)
# memory usage: 16.4+ MB

# %% [markdown]
# #### Statistical info about the data

# %%
df.describe()
# Out:
#          Unnamed: 0        Rating  Rating Count  Minimum Installs  \
# count  1.000000e+05  98997.000000  9.899700e+04      9.999600e+04
# mean   1.154456e+06      2.205181  3.785662e+03      2.221193e+05
# std    6.686028e+05      2.104959  3.940463e+05      1.748239e+07
# min    6.300000e+01      0.000000  0.000000e+00      0.000000e+00
# 25%    5.745438e+05      0.000000  0.000000e+00      5.000000e+01
# 50%    1.151178e+06      3.000000  6.000000e+00      5.000000e+02
# 75%    1.735626e+06      4.300000  4.300000e+01      5.000000e+03
# max    2.312879e+06      5.000000  1.178501e+08      5.000000e+09
#
#        Maximum Installs          Price
# count      1.000000e+05  100000.000000
# mean       3.613425e+05       0.097742
# std        2.440629e+07       2.369911
# min        0.000000e+00       0.000000
# 25%        8.400000e+01       0.000000
# 50%        7.000000e+02       0.000000
# 75%        7.495250e+03       0.000000
# max        6.782620e+09     399.990000

# %% [markdown]
# #### Correlation between all the numerical columns

# %%
df.corr(numeric_only=True)
# Out:
#                   Unnamed: 0    Rating  Rating Count  Minimum Installs  \
# Unnamed: 0          1.000000 -0.002837      0.005518          0.006513
# Rating             -0.002837  1.000000      0.006692          0.009530
# Rating Count        0.005518  0.006692      1.000000          0.889435
# Minimum Installs    0.006513  0.009530      0.889435          1.000000
# Maximum Installs    0.006122  0.011573      0.885496          0.989366
# Free                0.001282 -0.014525      0.001149          0.001706
# Price               0.001820 -0.004409     -0.000350         -0.000513
# Ad Supported       -0.002353  0.163963      0.004428          0.003502
# In App Purchases   -0.002154  0.154936      0.022431          0.018634
# Editors Choice      0.004019  0.017253      0.091721          0.014414
#
#                   Maximum Installs      Free     Price  Ad Supported  \
# Unnamed: 0                0.006122  0.001282  0.001820     -0.002353
# Rating                    0.011573 -0.014525 -0.004409      0.163963
# Rating Count              0.885496  0.001149 -0.000350      0.004428
# Minimum Installs          0.989366  0.001706 -0.000513      0.003502
# Maximum Installs          1.000000  0.001981 -0.000594      0.004307
# Free                      0.001981  1.000000 -0.297150      0.120369
# Price                    -0.000594 -0.297150  1.000000     -0.037314
# Ad Supported              0.004307  0.120369 -0.037314      1.000000
# In App Purchases          0.022058  0.008854 -0.004280      0.140454
# Editors Choice            0.032855 -0.002066  0.001451      0.004914
#
#                   In App Purchases  Editors Choice
# Unnamed: 0               -0.002154        0.004019
# Rating                    0.154936        0.017253
# Rating Count              0.022431        0.091721
# Minimum Installs          0.018634        0.014414
# Maximum Installs          0.022058        0.032855
# Free                      0.008854       -0.002066
# Price                    -0.004280        0.001451
# Ad Supported              0.140454        0.004914
# In App Purchases          1.000000        0.046162
# Editors Choice            0.046162        1.000000

# %% [markdown]
# #### Droppping the unnecessary column "Unnamed: 0"

# %%
df.drop(columns = 'Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#                                             App Name  \
# 0                      Universal Remote For Insignia
# 1                                  Revilla Domínguez
# 2                                            Polaris
# 3                                BioChem Euchre Deck
# 4  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     NaN
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0         646.0  100,000+          100000.0            102424  True    0.0
# 1           0.0        0+               0.0                 0  True    0.0
# 2           NaN       10+              10.0                12  True    0.0
# 3          44.0   10,000+           10000.0             12198  True    0.0
# 4          78.0   50,000+           50000.0             74811  True    0.0
#
#    ...        Developer Website                  Developer Email  \
# 0  ...                      NaN              Daud19887@gmail.com
# 1  ...                      NaN                      app@bewe.io
# 2  ...                      NaN          support@polaris-vpn.com
# 3  ...  http://cmer.uoguelph.ca                 cmer@uoguelph.ca
# 4  ...                      NaN  Yogendrakushwah151995@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Jan 21, 2019  Apr 08, 2021       Everyone
# 1   Jan 2, 2020  Feb 15, 2020       Everyone
# 2           NaN  Apr 21, 2021       Everyone
# 3  Dec 16, 2011  Feb 08, 2012       Everyone
# 4   Jul 8, 2018  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2                                                NaN        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 22:12:43
# 1            False          False  2021-06-15 22:09:38
# 2             True          False  2021-06-15 20:46:00
# 3            False          False  2021-06-16 01:57:28
# 4            False          False  2021-06-16 12:21:40
#
# [5 rows x 24 columns]

# %% [markdown]
# #### To get the list of all the columns

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
df.loc[:,'App Name':'Price']
# Out:
#                                                 App Name  \
# 0                          Universal Remote For Insignia
# 1                                      Revilla Domínguez
# 2                                                Polaris
# 3                                    BioChem Euchre Deck
# 4      TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
# ...                                                  ...
# 99995                        USB UART Terminal (AD-free)
# 99996  Photo par Gazal Shayari Likhe - फोटो पर ग़ज़ल शायरी
# 99997                   Tangle Master - Solve the tangle
# 99998              Wild Wolf Chasing Animal Simulator 3D
# 99999                       أغاني و قصائد  قحطان البديري
#
#                                              App Id       Category  Rating  \
# 0      com.illusions.insigniauniversalremotecontrol          Tools     3.2
# 1                                  com.bewe.app1135      Lifestyle     0.0
# 2                                com.polarisvpn.vpn          Tools     NaN
# 3                                  ca.uoguelph.cmer      Education     4.2
# 4               com.yogendrakushwah151995.TET_EXAMS      Education     4.2
# ...                                             ...            ...     ...
# 99995                    com.simran.usbuartterminal          Tools     0.0
# 99996                    com.devadroid.gazalshayari         Comics     0.0
# 99997                          com.taikenoel.tangle         Puzzle     3.7
# 99998    com.gss.wild.wolf.chasing.animal.simulator         Comics     4.5
# 99999                       musicmp3.Qahtan_Budairi  Music & Audio     3.8
#
#        Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price
# 0             646.0  100,000+          100000.0            102424  True    0.0
# 1               0.0        0+               0.0                 0  True    0.0
# 2               NaN       10+              10.0                12  True    0.0
# 3              44.0   10,000+           10000.0             12198  True    0.0
# 4              78.0   50,000+           50000.0             74811  True    0.0
# ...             ...       ...               ...               ...   ...    ...
# 99995           0.0      500+             500.0               629  True    0.0
# 99996           0.0    1,000+            1000.0              2134  True    0.0
# 99997           6.0      500+             500.0               682  True    0.0
# 99998        1304.0  100,000+          100000.0            370802  True    0.0
# 99999          10.0    1,000+            1000.0              1758  True    0.0
#
# [100000 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
df.loc[:,'Price':]
# Out:
#        Price Currency                Size     Minimum Android  \
# 0        0.0      USD                7.3M          4.4 and up
# 1        0.0      USD                 28M          4.1 and up
# 2        0.0      USD  Varies with device  Varies with device
# 3        0.0      USD                1.6M          1.1 and up
# 4        0.0      USD                8.4M          4.4 and up
# ...      ...      ...                 ...                 ...
# 99995    0.0      USD                1.2M          6.0 and up
# 99996    0.0      USD                6.9M        4.0.3 and up
# 99997    0.0      USD                 27M          4.4 and up
# 99998    0.0      USD                 40M          4.1 and up
# 99999    0.0      USD                8.1M          4.1 and up
#
#                                    Developer Id  \
# 0                                     illlusion
# 1                           Bewe Smart Software
# 2                                         Sibad
# 3      Centre for Mobile Education and Research
# 4                                    Exam Point
# ...                                         ...
# 99995                           Simranjit Marok
# 99996                           Boron Developer
# 99997           Wuanshinobi Gaming Studios, LLC
# 99998                         Game Stone Studio
# 99999                                    ahlazi
#
#                      Developer Website                  Developer Email  \
# 0                                  NaN              Daud19887@gmail.com
# 1                                  NaN                      app@bewe.io
# 2                                  NaN          support@polaris-vpn.com
# 3              http://cmer.uoguelph.ca                 cmer@uoguelph.ca
# 4                                  NaN  Yogendrakushwah151995@gmail.com
# ...                                ...                              ...
# 99995                              NaN               smarok77@gmail.com
# 99996                              NaN         borondeveloper@gmail.com
# 99997                              NaN            device.en16@gmail.com
# 99998    https://www.weplaystudio.com/          studiogamehit@gmail.com
# 99999  https://musicagani.blogspot.com                rayan.razan@bk.ru
#
#            Released  Last Updated Content Rating  \
# 0      Jan 21, 2019  Apr 08, 2021       Everyone
# 1       Jan 2, 2020  Feb 15, 2020       Everyone
# 2               NaN  Apr 21, 2021       Everyone
# 3      Dec 16, 2011  Feb 08, 2012       Everyone
# 4       Jul 8, 2018  Oct 03, 2019       Everyone
# ...             ...           ...            ...
# 99995  Jan 12, 2019  Aug 06, 2019       Everyone
# 99996  Oct 30, 2017  Oct 08, 2018     Mature 17+
# 99997  Jan 25, 2021  Jan 25, 2021       Everyone
# 99998  May 18, 2019  Mar 30, 2021       Everyone
# 99999  Apr 30, 2020  Jun 14, 2020       Everyone
#
#                                           Privacy Policy  Ad Supported  \
# 0      https://privacy-policy-illution.blogspot.com/p...          True
# 1                https://bewe.io/mx/politica-privacidad/         False
# 2                                                    NaN         False
# 3      https://www.uoguelph.ca/ccs/google-apps/privac...         False
# 4      http://apkprivacypolicy1.blogspot.com/p/privac...          True
# ...                                                  ...           ...
# 99995                                                NaN         False
# 99996  https://www.freeprivacypolicy.com/privacy/view...          True
# 99997                                                NaN          True
# 99998  https://docs.google.com/document/d/1Z79BT2rHTB...          True
# 99999  https://googleplayw.blogspot.com/2019/05/priva...          True
#
#        In App Purchases  Editors Choice         Scraped Time
# 0                 False           False  2021-06-15 22:12:43
# 1                 False           False  2021-06-15 22:09:38
# 2                  True           False  2021-06-15 20:46:00
# 3                 False           False  2021-06-16 01:57:28
# 4                 False           False  2021-06-16 12:21:40
# ...                 ...             ...                  ...
# 99995             False           False  2021-06-16 00:07:59
# 99996             False           False  2021-06-16 08:26:12
# 99997             False           False  2021-06-16 10:33:09
# 99998             False           False  2021-06-16 10:13:52
# 99999             False           False  2021-06-16 03:50:50
#
# [100000 rows x 15 columns]

# %% [markdown]
# #### Checking the duplicated rows in the data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Checking the null values

# %%
df.isnull().sum()
# Out:
# App Name                 0
# App Id                   0
# Category                 0
# Rating                1003
# Rating Count          1003
# Installs                 4
# Minimum Installs         4
# Maximum Installs         0
# Free                     0
# Price                    0
# Currency                 5
# Size                     9
# Minimum Android        297
# Developer Id             3
# Developer Website    32932
# Developer Email          2
# Released              3132
# Last Updated             0
# Content Rating           0
# Privacy Policy       18371
# Ad Supported             0
# In App Purchases         0
# Editors Choice           0
# Scraped Time             0
# dtype: int64

# %% [markdown]
# #### Dealing with the null values

# %%
df['Developer Id'].value_counts()
# Out:
# Developer Id
# ChowNow                            230
# TRAINERIZE                         213
# Subsplash Inc                      204
# BH App Development Ltd             131
# Phorest                            118
#                                   ...
# macrogen                             1
# JH Productions 9                     1
# Almosky Laundry                      1
# Dropit Inc                           1
# Wuanshinobi Gaming Studios, LLC      1
# Name: count, Length: 71667, dtype: int64

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
num_col = ['Rating','Rating Count','Minimum Installs','Maximum Installs']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for i in df.columns:
    if i in num_col:
        sns.boxplot(df[i])
        plt.show()

# %%
for i in df.columns:
    if i in num_col:
        df[i].fillna(df[i].median(),inplace=True)
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\762672441.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].median(),inplace=True)
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\762672441.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].median(),inplace=True)
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\762672441.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].median(),inplace=True)
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\762672441.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# App Name                 0
# App Id                   0
# Category                 0
# Rating                   0
# Rating Count             0
# Installs                 4
# Minimum Installs         0
# Maximum Installs         0
# Free                     0
# Price                    0
# Currency                 5
# Size                     9
# Minimum Android        297
# Developer Id             3
# Developer Website    32932
# Developer Email          2
# Released              3132
# Last Updated             0
# Content Rating           0
# Privacy Policy       18371
# Ad Supported             0
# In App Purchases         0
# Editors Choice           0
# Scraped Time             0
# dtype: int64

# %%
mode_col = []
for i in df.columns:
    if i not in num_col:
        mode_col.append(i)
print(mode_col)
# Out:
# ['App Name', 'App Id', 'Category', 'Installs', 'Free', 'Price', 'Currency', 'Size', 'Minimum Android', 'Developer Id', 'Developer Website', 'Developer Email', 'Released', 'Last Updated', 'Content Rating', 'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice', 'Scraped Time']

# %% [markdown]
# #### Filling rest columns with the mode

# %%
for i in df.columns:
    if i in mode_col:
        df[i].fillna(df[i].mode()[0],inplace=True)
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\1417563248.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# App Name             0
# App Id               0
# Category             0
# Rating               0
# Rating Count         0
# Installs             0
# Minimum Installs     0
# Maximum Installs     0
# Free                 0
# Price                0
# Currency             0
# Size                 0
# Minimum Android      0
# Developer Id         0
# Developer Website    0
# Developer Email      0
# Released             0
# Last Updated         0
# Content Rating       0
# Privacy Policy       0
# Ad Supported         0
# In App Purchases     0
# Editors Choice       0
# Scraped Time         0
# dtype: int64

# %%
df.head()
# Out:
#                                             App Name  \
# 0                      Universal Remote For Insignia
# 1                                  Revilla Domínguez
# 2                                            Polaris
# 3                                BioChem Euchre Deck
# 4  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     3.0
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0         646.0  100,000+          100000.0            102424  True    0.0
# 1           0.0        0+               0.0                 0  True    0.0
# 2           6.0       10+              10.0                12  True    0.0
# 3          44.0   10,000+           10000.0             12198  True    0.0
# 4          78.0   50,000+           50000.0             74811  True    0.0
#
#    ...          Developer Website                  Developer Email  \
# 0  ...  http://www.subsplash.com/              Daud19887@gmail.com
# 1  ...  http://www.subsplash.com/                      app@bewe.io
# 2  ...  http://www.subsplash.com/          support@polaris-vpn.com
# 3  ...    http://cmer.uoguelph.ca                 cmer@uoguelph.ca
# 4  ...  http://www.subsplash.com/  Yogendrakushwah151995@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Jan 21, 2019  Apr 08, 2021       Everyone
# 1   Jan 2, 2020  Feb 15, 2020       Everyone
# 2  Jul 28, 2020  Apr 21, 2021       Everyone
# 3  Dec 16, 2011  Feb 08, 2012       Everyone
# 4   Jul 8, 2018  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2             http://www.subsplash.com/legal/privacy        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 22:12:43
# 1            False          False  2021-06-15 22:09:38
# 2             True          False  2021-06-15 20:46:00
# 3            False          False  2021-06-16 01:57:28
# 4            False          False  2021-06-16 12:21:40
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Top 5 App Name with the maximum rating

# %%
df[['App Name','Rating']].sort_values(by = 'Rating').tail()
# Out:
#                      App Name  Rating
# 20491                Qtourist     5.0
# 40322          Ordenar Comida     5.0
# 73932  SUBODH EDUCATION DOONI     5.0
# 40355             Picz Winner     5.0
# 38793            Frac-Tac-Toe     5.0

# %% [markdown]
# ##### Top 5 App Name with the maximum average rating

# %%
df.groupby('App Name')['Rating'].mean().sort_values().tail()
# Out:
# App Name
# shalom radio tx                          5.0
# REVVL 4+ TMUSdemo                        5.0
# Motivational Quotes, Sayings & Status    5.0
# Save Your Heart - Lite                   5.0
# GPSTRAQER                                5.0
# Name: Rating, dtype: float64

# %% [markdown]
# #### Top 5 App Name with the maximum Rating count

# %%
df[['App Name','Rating Count']].sort_values(by ='Rating Count').tail(5)
# Out:
#                             App Name  Rating Count
# 40722             Dragon City Mobile     8424191.0
# 67264  ZEDGE™ Wallpapers & Ringtones     8798409.0
# 21701                     AliExpress    11805765.0
# 7635                    Clash Royale    31018623.0
# 55150                       Facebook   117850066.0

# %% [markdown]
# #### Top 5 name with the maximum installation

# %%
df[['App Name','Maximum Installs']].sort_values(by ='Maximum Installs').tail(5)
# Out:
#                             App Name  Maximum Installs
# 53025                  Samsung Notes        1020174726
# 73807  Google Keep - Notes and Lists        1241023726
# 12436    Google Play Services for AR        1459169211
# 53233               Samsung My Files        2063336389
# 55150                       Facebook        6782619635

# %% [markdown]
# #### Top 5 paid apps with the maximum average rating

# %%
df[['App Name','Rating']][df['Free']==False].sort_values(by='Rating').tail()
# Out:
#                                             App Name  Rating
# 16894                        Touch of  Impressionism     5.0
# 6889                          AppLock Master License     5.0
# 6640                                     KF Physique     5.0
# 83788                                 Unit Converter     5.0
# 37164  Writer's Dictionary - Offline. Simple. Handy.     5.0

# %% [markdown]
# #### Top 5 App Name with the maximum Price

# %%
df[['App Name','Price']].sort_values(by='Price').tail()
# Out:
#                                                App Name       Price
# 15065                     Early Literacy Skills Builder  149.990000
# 24032                                              rata  204.990000
# 96829  Royal Soccer Best Correct Score Betting Tips App  229.990000
# 49554                    Sonepar Automation PRO Premium  302.957633
# 40908                                           Why Not  399.990000

# %%
df.groupby('App Name')['Price'].max().sort_values().tail()
# Out:
# App Name
# Early Literacy Skills Builder                       149.990000
# rata                                                204.990000
# Royal Soccer Best Correct Score Betting Tips App    229.990000
# Sonepar Automation PRO Premium                      302.957633
# Why Not                                             399.990000
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#                                             App Name  \
# 0                      Universal Remote For Insignia
# 1                                  Revilla Domínguez
# 2                                            Polaris
# 3                                BioChem Euchre Deck
# 4  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     3.0
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0         646.0  100,000+          100000.0            102424  True    0.0
# 1           0.0        0+               0.0                 0  True    0.0
# 2           6.0       10+              10.0                12  True    0.0
# 3          44.0   10,000+           10000.0             12198  True    0.0
# 4          78.0   50,000+           50000.0             74811  True    0.0
#
#    ...          Developer Website                  Developer Email  \
# 0  ...  http://www.subsplash.com/              Daud19887@gmail.com
# 1  ...  http://www.subsplash.com/                      app@bewe.io
# 2  ...  http://www.subsplash.com/          support@polaris-vpn.com
# 3  ...    http://cmer.uoguelph.ca                 cmer@uoguelph.ca
# 4  ...  http://www.subsplash.com/  Yogendrakushwah151995@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Jan 21, 2019  Apr 08, 2021       Everyone
# 1   Jan 2, 2020  Feb 15, 2020       Everyone
# 2  Jul 28, 2020  Apr 21, 2021       Everyone
# 3  Dec 16, 2011  Feb 08, 2012       Everyone
# 4   Jul 8, 2018  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2             http://www.subsplash.com/legal/privacy        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 22:12:43
# 1            False          False  2021-06-15 22:09:38
# 2             True          False  2021-06-15 20:46:00
# 3            False          False  2021-06-16 01:57:28
# 4            False          False  2021-06-16 12:21:40
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Category wise average rating

# %%
df.groupby('Category')['Rating'].mean()
# Out:
# Category
# Action                     2.780932
# Adventure                  2.802866
# Arcade                     2.407134
# Art & Design               2.031902
# Auto & Vehicles            2.070668
# Beauty                     1.452505
# Board                      2.595143
# Books & Reference          2.494417
# Business                   1.442832
# Card                       3.129462
# Casino                     3.258883
# Casual                     2.483843
# Comics                     3.097241
# Communication              2.149591
# Dating                     2.442724
# Education                  2.252446
# Educational                2.447537
# Entertainment              2.436880
# Events                     1.374655
# Finance                    2.432037
# Food & Drink               1.285194
# Health & Fitness           1.644367
# House & Home               1.494491
# Libraries & Demo           2.118692
# Lifestyle                  1.897301
# Maps & Navigation          2.257937
# Medical                    1.909831
# Music                      2.791979
# Music & Audio              2.215886
# News & Magazines           2.484810
# Parenting                  2.253125
# Personalization            2.749921
# Photography                2.607405
# Productivity               1.976353
# Puzzle                     2.718820
# Racing                     3.035307
# Role Playing               3.460674
# Shopping                   1.872968
# Simulation                 3.192456
# Social                     2.461206
# Sports                     2.311095
# Strategy                   2.821774
# Tools                      2.354658
# Travel & Local             1.876385
# Trivia                     2.601359
# Video Players & Editors    2.886201
# Weather                    3.180714
# Word                       2.862565
# Name: Rating, dtype: float64

# %% [markdown]
# #### Top 5 category with their average rating

# %%
df.groupby('Category')['Rating'].mean().sort_values().tail()
# Out:
# Category
# Card            3.129462
# Weather         3.180714
# Simulation      3.192456
# Casino          3.258883
# Role Playing    3.460674
# Name: Rating, dtype: float64

# %% [markdown]
# #### Top 5 category with their total rating count

# %%
df.groupby('Category')['Rating Count'].sum().sort_values().tail()
# Out:
# Category
# Casual         12874685.0
# Simulation     16664293.0
# Shopping       18025643.0
# Strategy       41392272.0
# Social        121578062.0
# Name: Rating Count, dtype: float64

# %%
df.head()
# Out:
#                                             App Name  \
# 0                      Universal Remote For Insignia
# 1                                  Revilla Domínguez
# 2                                            Polaris
# 3                                BioChem Euchre Deck
# 4  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     3.0
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0         646.0  100,000+          100000.0            102424  True    0.0
# 1           0.0        0+               0.0                 0  True    0.0
# 2           6.0       10+              10.0                12  True    0.0
# 3          44.0   10,000+           10000.0             12198  True    0.0
# 4          78.0   50,000+           50000.0             74811  True    0.0
#
#    ...          Developer Website                  Developer Email  \
# 0  ...  http://www.subsplash.com/              Daud19887@gmail.com
# 1  ...  http://www.subsplash.com/                      app@bewe.io
# 2  ...  http://www.subsplash.com/          support@polaris-vpn.com
# 3  ...    http://cmer.uoguelph.ca                 cmer@uoguelph.ca
# 4  ...  http://www.subsplash.com/  Yogendrakushwah151995@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Jan 21, 2019  Apr 08, 2021       Everyone
# 1   Jan 2, 2020  Feb 15, 2020       Everyone
# 2  Jul 28, 2020  Apr 21, 2021       Everyone
# 3  Dec 16, 2011  Feb 08, 2012       Everyone
# 4   Jul 8, 2018  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2             http://www.subsplash.com/legal/privacy        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 22:12:43
# 1            False          False  2021-06-15 22:09:38
# 2             True          False  2021-06-15 20:46:00
# 3            False          False  2021-06-16 01:57:28
# 4            False          False  2021-06-16 12:21:40
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Category wise total No of apps

# %%
df.groupby('Category')['App Name'].count()
# Out:
# Category
# Action                      1180
# Adventure                   1012
# Arcade                      2369
# Art & Design                 815
# Auto & Vehicles              808
# Beauty                       499
# Board                        453
# Books & Reference           4926
# Business                    6306
# Card                         353
# Casino                       197
# Casual                      2191
# Comics                       145
# Communication               2077
# Dating                       323
# Education                  10403
# Educational                  934
# Entertainment               5930
# Events                       580
# Finance                     2700
# Food & Drink                3188
# Health & Fitness            3586
# House & Home                 599
# Libraries & Demo             214
# Lifestyle                   5076
# Maps & Navigation           1134
# Medical                     1424
# Music                        187
# Music & Audio               6597
# News & Magazines            1896
# Parenting                    160
# Personalization             3794
# Photography                 1553
# Productivity                3493
# Puzzle                      2237
# Racing                       456
# Role Playing                 445
# Shopping                    3285
# Simulation                  1034
# Social                      1923
# Sports                      2100
# Strategy                     372
# Tools                       6365
# Travel & Local              2888
# Trivia                       515
# Video Players & Editors      616
# Weather                      280
# Word                         382
# Name: App Name, dtype: int64

# %% [markdown]
# #### Top 5 category with the maximum no of apps

# %%
df.groupby('Category')['App Name'].count().sort_values().tail()
# Out:
# Category
# Entertainment     5930
# Business          6306
# Tools             6365
# Music & Audio     6597
# Education        10403
# Name: App Name, dtype: int64

# %% [markdown]
# #### Converting the Released column into the datetime data type

# %%
df['Released'] = pd.to_datetime(df['Released'])

# %%
df['Released_Year'] = df['Released'].dt.year

# %%
df['Released_Month'] = df['Released'].dt.month_name()

# %%
df['Released_Day'] = df['Released'].dt.day_name()

# %%
df.head()
# Out:
#                                             App Name  \
# 0                      Universal Remote For Insignia
# 1                                  Revilla Domínguez
# 2                                            Polaris
# 3                                BioChem Euchre Deck
# 4  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     3.0
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0         646.0  100,000+          100000.0            102424  True    0.0
# 1           0.0        0+               0.0                 0  True    0.0
# 2           6.0       10+              10.0                12  True    0.0
# 3          44.0   10,000+           10000.0             12198  True    0.0
# 4          78.0   50,000+           50000.0             74811  True    0.0
#
#    ...  Last Updated Content Rating  \
# 0  ...  Apr 08, 2021       Everyone
# 1  ...  Feb 15, 2020       Everyone
# 2  ...  Apr 21, 2021       Everyone
# 3  ...  Feb 08, 2012       Everyone
# 4  ...  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2             http://www.subsplash.com/legal/privacy        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time Released_Year  \
# 0            False          False  2021-06-15 22:12:43          2019
# 1            False          False  2021-06-15 22:09:38          2020
# 2             True          False  2021-06-15 20:46:00          2020
# 3            False          False  2021-06-16 01:57:28          2011
# 4            False          False  2021-06-16 12:21:40          2018
#
#   Released_Month Released_Day
# 0        January       Monday
# 1        January     Thursday
# 2           July      Tuesday
# 3       December       Friday
# 4           July       Sunday
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Year wise No of App Released

# %%
df.groupby('Released_Year')['App Name'].count()
# Out:
# Released_Year
# 2010      192
# 2011      596
# 2012     1121
# 2013     1850
# 2014     3137
# 2015     5065
# 2016     7041
# 2017    11123
# 2018    14611
# 2019    20836
# 2020    26667
# 2021     7761
# Name: App Name, dtype: int64

# %% [markdown]
# #### Month wise No of App Released

# %%
df.groupby('Released_Month')['App Name'].count()
# Out:
# Released_Month
# April         8439
# August        7567
# December      7783
# February      7841
# January       7980
# July         11148
# June          7849
# March         8606
# May           8959
# November      7752
# October       8240
# September     7836
# Name: App Name, dtype: int64

# %% [markdown]
# #### Day Name Wise No of App Released

# %%
df.groupby('Released_Day')['App Name'].count()
# Out:
# Released_Day
# Friday       14499
# Monday       15404
# Saturday      9442
# Sunday       10142
# Thursday     15602
# Tuesday      19084
# Wednesday    15827
# Name: App Name, dtype: int64

# %% [markdown]
# #### Year wise and Month wise total no of app released

# %%
df.pivot_table(index='Released_Year',columns='Released_Month',
               values='App Name',aggfunc='count')
# Out:
# Released_Month   April  August  December  February  January    July    June  \
# Released_Year
# 2010              11.0    22.0      35.0       8.0      1.0     9.0    13.0
# 2011              48.0    58.0      69.0      26.0     30.0    46.0    38.0
# 2012              83.0   112.0      98.0      74.0     61.0    93.0    78.0
# 2013             149.0   147.0     206.0     126.0    100.0   164.0   162.0
# 2014             222.0   274.0     368.0     229.0    175.0   255.0   242.0
# 2015             383.0   435.0     545.0     368.0    356.0   408.0   398.0
# 2016             546.0   591.0     728.0     478.0    498.0   514.0   553.0
# 2017             809.0  1054.0    1026.0     709.0    693.0   916.0   919.0
# 2018            1125.0  1224.0    1204.0    1020.0   1096.0  1339.0  1159.0
# 2019            1461.0  1818.0    1959.0    1304.0   1404.0  2004.0  1735.0
# 2020            2098.0  1832.0    1545.0    2012.0   2014.0  5400.0  2254.0
# 2021            1504.0     NaN       NaN    1487.0   1552.0     NaN   298.0
#
# Released_Month   March     May  November  October  September
# Released_Year
# 2010               9.0    14.0      26.0     20.0       24.0
# 2011              33.0    46.0      73.0     67.0       62.0
# 2012             105.0    91.0     127.0    111.0       88.0
# 2013             138.0   147.0     181.0    148.0      182.0
# 2014             231.0   234.0     300.0    329.0      278.0
# 2015             410.0   377.0     504.0    475.0      406.0
# 2016             603.0   591.0     668.0    676.0      595.0
# 2017             854.0  1027.0    1038.0   1045.0     1033.0
# 2018            1171.0  1283.0    1287.0   1388.0     1315.0
# 2019            1426.0  1620.0    1978.0   2096.0     2031.0
# 2020            2027.0  2208.0    1570.0   1885.0     1822.0
# 2021            1599.0  1321.0       NaN      NaN        NaN

# %% [markdown]
# #### Year wise and month wise avg rating

# %%
df.pivot_table(index='Released_Year',columns='Released_Month',
               values='Rating',aggfunc='mean')
# Out:
# Released_Month     April    August  December  February   January      July  \
# Released_Year
# 2010            4.009091  3.936364  3.845714  3.800000  3.600000  3.966667
# 2011            3.910417  3.703448  3.572464  3.788462  3.463333  3.719565
# 2012            3.579518  3.336607  3.295918  3.421622  3.636066  3.755914
# 2013            3.392617  3.390476  3.317476  3.535714  3.463000  3.442073
# 2014            3.438288  3.423723  3.412500  3.281223  3.272000  3.466275
# 2015            3.131854  3.050115  3.068624  3.263315  3.384270  3.105637
# 2016            2.723626  2.748731  2.753297  2.855230  2.798394  2.776654
# 2017            2.610260  2.416224  2.309064  2.525670  2.774459  2.508406
# 2018            2.168089  2.211111  2.153821  2.317353  2.424726  2.260269
# 2019            2.125394  1.731518  1.743798  2.156212  2.124359  1.864072
# 2020            1.987512  1.927838  1.904142  1.754324  1.818123  2.226130
# 2021            1.283843       NaN       NaN  1.419637  1.660374       NaN
#
# Released_Month      June     March       May  November   October  September
# Released_Year
# 2010            3.715385  3.877778  4.142857  3.619231  4.005000   3.633333
# 2011            3.473684  3.612121  3.617391  3.519178  3.700000   3.672581
# 2012            3.491026  3.559048  3.443956  3.363780  3.405405   3.781818
# 2013            3.312963  3.534058  3.551701  3.328729  3.498649   3.446703
# 2014            3.252893  3.436364  3.260684  3.459667  3.180851   3.307914
# 2015            3.215327  3.328049  3.180637  2.986508  3.039789   2.965025
# 2016            2.733092  2.810282  2.760914  2.673653  2.892751   2.793277
# 2017            2.425245  2.581733  2.407400  2.390173  2.238852   2.555663
# 2018            2.295858  2.289838  2.100624  2.098213  2.111167   2.225095
# 2019            1.830663  2.125806  2.062037  1.771132  1.750429   1.762038
# 2020            1.900311  1.915688  2.022464  1.920828  1.875650   1.891822
# 2021            0.676174  1.433771  1.018471       NaN       NaN        NaN

# %% [markdown]
# #### Month and Day wise totall rating count

# %%
df.pivot_table(index='Released_Month',columns='Released_Day',
               values='Rating Count',aggfunc='sum')
# Out:
# Released_Day       Friday     Monday   Saturday     Sunday    Thursday  \
# Released_Month
# April           4612338.0   899231.0   379483.0   958956.0   2482582.0
# August          1125807.0  2628617.0   984207.0  2294645.0   1682056.0
# December         738687.0  2469520.0  2140423.0   906791.0   3604126.0
# February        3883998.0   846221.0   813279.0  1079390.0   1553774.0
# January         1514451.0  1265743.0   771796.0   470674.0   3691237.0
# July            2205784.0  1428899.0   322676.0   654689.0   2502879.0
# June            1963013.0  1718052.0   744586.0   644224.0   2770720.0
# March           5463730.0  1285760.0   516421.0  1051007.0   6619460.0
# May              882281.0  1087127.0  1915431.0  1792709.0   1838413.0
# November        2373149.0  3642334.0   627332.0   629384.0   2252512.0
# October         1465198.0   889941.0   520650.0   592494.0   2040478.0
# September       1156733.0  1640196.0  1778922.0   859032.0  13256606.0
#
# Released_Day        Tuesday   Wednesday
# Released_Month
# April             1156304.0   1506741.0
# August            1496142.0   2587644.0
# December          2265451.0   3904424.0
# February          2911357.0   2800185.0
# January           4812411.0   2959368.0
# July            141159924.0  10613838.0
# June              1720689.0  14325091.0
# March            31982078.0   3763627.0
# May               4854487.0   3834756.0
# November          4714775.0   3781702.0
# October           3942610.0   1191253.0
# September         4664251.0   2895245.0

# %% [markdown]
# ### Univariate Analysis

# %%
sns.set(style="whitegrid")

# %% [markdown]
# #### The distribution of apps across different categories

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='Category', order=df['Category'].value_counts().index)
plt.title('App Count by Category')
plt.xlabel('Count')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The distribution of app ratings

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Rating'], kde=True, bins=30, color='skyblue')
plt.title('Distribution of App Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [58], in <cell line: 2>()
#       1 plt.figure(figsize=(8, 5))
# ----> 2 sns.histplot(df['Rating'], kde=True, bins=30, color='skyblue')
#       3 plt.title('Distribution of App Ratings')
#       4 plt.xlabel('Rating')
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:651, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     648     sticky_x, sticky_y = (0, np.inf), None
#     650 line_kws["color"] = to_rgba(sub_color, 1)
# --> 651 line, = ax.plot(
#     652     *line_args, **line_kws,
#     653 )
#     655 if sticky_x is not None:
#     656     line.sticky_edges.x[:] = sticky_x
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:487, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     484         kw[prop_name] = val
#     486 if len(xy) == 2:
# --> 487     x = _check_1d(xy[0])
#     488     y = _check_1d(xy[1])
#     489 else:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1327, in _check_1d(x)
#    1321 with warnings.catch_warnings(record=True) as w:
#    1322     warnings.filterwarnings(
#    1323         "always",
#    1324         category=Warning,
#    1325         message='Support for multi-dimensional indexing')
# -> 1327     ndim = x[:, None].ndim
#    1328     # we have definitely hit a pandas index or series object
#    1329     # cast to a numpy array.
#    1330     if len(w) > 0:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5419, in Index.__getitem__(self, key)
#    5417 # Because we ruled out integer above, we always get an arraylike here
#    5418 if result.ndim > 1:
# -> 5419     disallow_ndim_indexing(result)
#    5421 # NB: Using _constructor._simple_new would break if MultiIndex
#    5422 #  didn't override __getitem__
#    5423 return self._constructor._simple_new(result, name=self._name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexers\utils.py:341, in disallow_ndim_indexing(result)
#     333 """
#     334 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     335
#    (...)
#     338 in GH#30588.
#     339 """
#     340 if np.ndim(result) > 1:
# --> 341     raise ValueError(
#     342         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343         "supported. Convert to a numpy array before indexing instead."
#     344     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %% [markdown]
# #### No of app free versus paid

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Free', palette='Set2')
plt.title('Distribution of Free vs Paid Apps')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\3009524034.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Free', palette='Set2')

# %% [markdown]
# #### the most common app content ratings

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='Content Rating', order=df['Content Rating'].value_counts().index)
plt.title('Distribution of Content Ratings')
plt.xlabel('Content Rating')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distibution of App Sizes

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Size'].dropna(), bins=30, color='orange')
plt.title('Distribution of App Sizes')
plt.xlabel('Size (in MB)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### the distribution of number of reviews

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Reviews'].dropna(), bins=50, color='purple', log_scale=True)
plt.title('Distribution of Reviews')
plt.xlabel('Reviews')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### How ratings differ between free and paid apps

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='Free', y='Rating', palette='coolwarm')
plt.title('Rating by App Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\3713693500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Free', y='Rating', palette='coolwarm')

# %% [markdown]
# #### How does content rating affect average app rating

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Content Rating', y='Rating', palette='Set3')
plt.title('Rating Distribution Across Content Ratings')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\2457861665.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Content Rating', y='Rating', palette='Set3')

# %% [markdown]
# #### How does number of installs vary with price for paid apps

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df[df['Price'] > 0], x='Price', y='Installs', alpha=0.9)
plt.title('Price vs Installs (Paid Apps)')
plt.xlabel('Price ($)')
plt.ylabel('Installs')
plt.yscale('log')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Which app categories have the highest total installs

# %%
top_installs = df.groupby('Category')['Installs'].max().sort_values(ascending=False).head(5)
top_installs
# Out:
# Category
# Music & Audio    500,000,000+
# Tools            500,000,000+
# Business         500,000,000+
# Productivity     500,000,000+
# Communication    500,000,000+
# Name: Installs, dtype: object

# %% [markdown]
# #### How does app type (Free/Paid) vary across top categories?

# %%
top_cats = df['Category'].value_counts().head(6).index
plt.figure(figsize=(10, 6))
sns.countplot(data=df[df['Category'].isin(top_cats)], x='Category', hue='Free', palette='Set2')
plt.title('App Type Distribution in Top 6 Categories')
plt.ylabel('App Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### How does average rating vary with app type across content ratings

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Content Rating', y='Rating', hue='Free', ci=None, palette='pastel')
plt.title('Average Rating by Content Rating and Type')
plt.xlabel('Content Rating')
plt.ylabel('Average Rating')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\91854\AppData\Local\Temp\ipykernel_13308\2886760974.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Content Rating', y='Rating', hue='Free', ci=None, palette='pastel')

# %%
df.head()
# Out:
#                                             App Name  \
# 0                      Universal Remote For Insignia
# 1                                  Revilla Domínguez
# 2                                            Polaris
# 3                                BioChem Euchre Deck
# 4  TET EXAMS (TEACHER ELIGIBILITY TEST EXAM) IN H...
#
#                                          App Id   Category  Rating  \
# 0  com.illusions.insigniauniversalremotecontrol      Tools     3.2
# 1                              com.bewe.app1135  Lifestyle     0.0
# 2                            com.polarisvpn.vpn      Tools     3.0
# 3                              ca.uoguelph.cmer  Education     4.2
# 4           com.yogendrakushwah151995.TET_EXAMS  Education     4.2
#
#    Rating Count  Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0         646.0  100,000+          100000.0            102424  True    0.0
# 1           0.0        0+               0.0                 0  True    0.0
# 2           6.0       10+              10.0                12  True    0.0
# 3          44.0   10,000+           10000.0             12198  True    0.0
# 4          78.0   50,000+           50000.0             74811  True    0.0
#
#    ...  Last Updated Content Rating  \
# 0  ...  Apr 08, 2021       Everyone
# 1  ...  Feb 15, 2020       Everyone
# 2  ...  Apr 21, 2021       Everyone
# 3  ...  Feb 08, 2012       Everyone
# 4  ...  Oct 03, 2019       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0  https://privacy-policy-illution.blogspot.com/p...         True
# 1            https://bewe.io/mx/politica-privacidad/        False
# 2             http://www.subsplash.com/legal/privacy        False
# 3  https://www.uoguelph.ca/ccs/google-apps/privac...        False
# 4  http://apkprivacypolicy1.blogspot.com/p/privac...         True
#
#   In App Purchases Editors Choice         Scraped Time Released_Year  \
# 0            False          False  2021-06-15 22:12:43          2019
# 1            False          False  2021-06-15 22:09:38          2020
# 2             True          False  2021-06-15 20:46:00          2020
# 3            False          False  2021-06-16 01:57:28          2011
# 4            False          False  2021-06-16 12:21:40          2018
#
#   Released_Month Released_Day
# 0        January       Monday
# 1        January     Thursday
# 2           July      Tuesday
# 3       December       Friday
# 4           July       Sunday
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Multi-Variate Analysis

# %% [markdown]
# #### App Count by Category & Type

# %%
Top_cat = df['Category'].value_counts().head(8).index
Top_cat
# Out:
# Index(['Education', 'Music & Audio', 'Tools', 'Business', 'Entertainment',
#        'Lifestyle', 'Books & Reference', 'Personalization'],
#       dtype='object', name='Category')

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df[df['Category'].isin(Top_cat)],
              x='Category', hue='Free', palette='Set2')
plt.title('App Type Distribution in Top Categories')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Which combinations of category and content rating have the highest average ratings?

# %%
rating_pivot = df.pivot_table(index='Category', columns='Content Rating', values='Rating', aggfunc='mean')
rating_pivot
# Out:
# Content Rating           Adults only 18+  Everyone  Everyone 10+  Mature 17+  \
# Category
# Action                               NaN  2.409244      2.927108    3.379730
# Adventure                            NaN  2.531121      3.286567    3.350000
# Arcade                               NaN  2.343099      2.778571    3.028571
# Art & Design                         NaN  1.997574      1.366667    2.795238
# Auto & Vehicles                      NaN  2.052760      3.800000    3.066667
# Beauty                               NaN  1.417505      0.000000    2.866667
# Board                                NaN  2.519899      2.980000    2.700000
# Books & Reference                    NaN  2.541455      2.071545    3.360465
# Business                             NaN  1.451215      2.087500    1.591304
# Card                                 NaN  3.045249      2.420000    2.277778
# Casino                               NaN  1.507143           NaN    2.966667
# Casual                               NaN  2.421701      3.024096    2.363265
# Comics                               NaN  2.727160      4.100000    3.761538
# Communication                        NaN  2.121182      2.900000    2.810976
# Dating                               NaN  2.094118      2.700000    2.505861
# Education                            NaN  2.245133      2.302941    2.300000
# Educational                          NaN  2.445647      2.369231    2.420000
# Entertainment                        NaN  2.400146      2.473529    2.683815
# Events                               0.0  1.372421      0.756250    0.900000
# Finance                              NaN  2.435811      1.000000    3.036842
# Food & Drink                         NaN  1.255823      1.533333    1.943939
# Health & Fitness                     NaN  1.603845      2.856667    2.238298
# House & Home                         NaN  1.517832           NaN    0.528571
# Libraries & Demo                     NaN  2.011168           NaN    3.075000
# Lifestyle                            NaN  1.824170      2.886364    2.533333
# Maps & Navigation                    NaN  2.359074      0.050000    2.262500
# Medical                              NaN  1.918378      1.696154    2.223077
# Music                                NaN  2.755090      4.300000    2.114286
# Music & Audio                        NaN  2.506241      2.640299    1.932432
# News & Magazines                     NaN  2.436205      2.756849    3.066667
# Parenting                            NaN  2.200000      4.500000    4.533333
# Personalization                      NaN  2.738113      3.200000    2.859751
# Photography                          NaN  2.591326      2.466667    2.966667
# Productivity                         NaN  1.981009      1.533333    2.903125
# Puzzle                               NaN  2.700381      2.946154    2.633333
# Racing                               NaN  3.055500      2.763158    1.875000
# Role Playing                         NaN  3.164179      3.682278    3.460000
# Shopping                             NaN  1.905053      4.300000    1.271014
# Simulation                           NaN  3.132439      3.488462    3.564103
# Social                               NaN  2.451965      1.840000    2.777542
# Sports                               0.0  2.274074      2.825000    2.518750
# Strategy                             NaN  2.414865      3.526250    3.100000
# Tools                                NaN  2.354987      2.708333    2.203529
# Travel & Local                       NaN  1.869132      1.167742    1.800000
# Trivia                               NaN  2.603299      2.966667    2.612500
# Video Players & Editors              NaN  2.911796      2.150000    1.900000
# Weather                              NaN  3.070339      3.614286    4.333333
# Word                                 NaN  2.908169      2.050000    1.880000
#
# Content Rating               Teen   Unrated
# Category
# Action                   3.223188       NaN
# Adventure                3.372908       NaN
# Arcade                   2.863087  2.500000
# Art & Design             2.265306       NaN
# Auto & Vehicles          2.440000       NaN
# Beauty                   1.708571       NaN
# Board                    3.170833       NaN
# Books & Reference        1.885893       NaN
# Business                 1.185124       NaN
# Card                     3.382203       NaN
# Casino                   3.400000       NaN
# Casual                   3.048592       NaN
# Comics                   3.491837       NaN
# Communication            2.121555       NaN
# Dating                   1.969231       NaN
# Education                2.513793       NaN
# Educational              2.590000       NaN
# Entertainment            2.559889       NaN
# Events                   1.634545       NaN
# Finance                  1.817857       NaN
# Food & Drink             1.275758       NaN
# Health & Fitness         2.212500       NaN
# House & Home             1.165000       NaN
# Libraries & Demo         3.453846       NaN
# Lifestyle                2.556364       NaN
# Maps & Navigation        2.444444       NaN
# Medical                  1.665854       NaN
# Music                    3.509091       NaN
# Music & Audio            1.354169       NaN
# News & Magazines         2.614151       NaN
# Parenting                1.890000       NaN
# Personalization          2.757672  3.900000
# Photography              2.742593       NaN
# Productivity             1.317910       NaN
# Puzzle                   3.062626       NaN
# Racing                   3.087879       NaN
# Role Playing             3.741333       NaN
# Shopping                 1.757971       NaN
# Simulation               3.297484  3.600000
# Social                   2.395678       NaN
# Sports                   2.589809  3.366667
# Strategy                 3.337705       NaN
# Tools                    2.426087       NaN
# Travel & Local           2.247009       NaN
# Trivia                   2.489474       NaN
# Video Players & Editors  2.797222       NaN
# Weather                  3.755882       NaN
# Word                     2.546667       NaN

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(rating_pivot, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, linecolor='gray')
plt.title('Average Rating by Category and Content Rating', fontsize=14)
plt.xlabel('Content Rating')
plt.ylabel('Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### How do ratings vary across content ratings and app type (Free vs Paid)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Content Rating', y='Rating', hue='Free', palette='Set2')
plt.title('Rating Distribution by Content Rating and App Type', fontsize=14)
plt.xlabel('Content Rating')
plt.ylabel('Rating')
plt.tight_layout()
plt.show()

# %%
df.to_csv("Google_app_store_data_cleaned.csv")
