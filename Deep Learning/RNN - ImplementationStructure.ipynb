# %%
from keras import Sequential
from keras.layers import Dense,SimpleRNN

# %%
model = Sequential()
model.add(SimpleRNN(3, input_shape=(4,5), return_sequences=True))  
model.add(SimpleRNN(3))  
model.add(Dense(1, activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_8 (SimpleRNN)             │ (None, 4, 3)                │              27 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_9 (SimpleRNN)             │ (None, 3)                   │              21 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52 (208.00 B)
#  Trainable params: 52 (208.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)
model.get_weights()[0]
# Out:
# (5, 3)
# array([[-0.6456119 ,  0.6356824 ,  0.4434207 ],
#        [ 0.24895006,  0.6413401 , -0.81775594],
#        [ 0.8391642 ,  0.83370227, -0.42611453],
#        [-0.19569659,  0.5976121 ,  0.11168295],
#        [-0.6434697 , -0.16115099, -0.13500345]], dtype=float32)

# %%
print(model.get_weights()[1].shape)
model.get_weights()[1]
# Out:
# (3, 3)
# array([[ 0.25562978,  0.6451061 ,  0.7200636 ],
#        [-0.2719318 , -0.66676044,  0.6938902 ],
#        [-0.9277427 ,  0.37318718, -0.00498104]], dtype=float32)

# %%
print(model.get_weights()[2].shape)
model.get_weights()[2]
# Out:
# (3,)
# array([0., 0., 0.], dtype=float32)

# %%
print(model.get_weights()[3].shape)
model.get_weights()[3]
# Out:
# (3, 1)
# array([[ 0.32677233],
#        [-0.18707979],
#        [-0.7959906 ]], dtype=float32)

# %%
print(model.get_weights()[4].shape)
model.get_weights()[4]
# Out:
# (1,)
# array([0.], dtype=float32)

# %%
RNN can work with Embeddings
RNN can work without Embeddings

Embeddings ( embedding converts words into dense vector - embedding is provided by
keras to train model from scratch and convert words into word vectors).


we have many pre-trained embedding techniques word2vec , glove
We have advance embedding techniques like BERT, GPT, for Sentences vectors and context vectors
